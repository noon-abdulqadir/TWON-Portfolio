# %% [markdown]
# # ATTN: This script uses Google translate to detect job description language. Google translate will limit requests and take a very long time. Only run this script if redoing language detection.

# %% [markdown]
# ## Read from scraped data

# %%
import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

mod = sys.modules[__name__]

code_dir = None
code_dir_name = 'Code'
unwanted_subdir_name = 'Analysis'

if code_dir_name not in str(Path.cwd()).split('/')[-1]:
    for _ in range(5):

        parent_path = str(Path.cwd().parents[_]).split('/')[-1]

        if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

            code_dir = str(Path.cwd().parents[_])

            if code_dir is not None:
                break
else:
    code_dir = str(Path.cwd())
sys.path.append(code_dir)

# %load_ext autoreload
# %autoreload 2

# %%
from setup_module.imports import * # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# Out:
# /opt/homebrew/Caskroom/mambaforge/base/envs/Automating_Equity1/lib/python3.10/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.3, the latest is 0.5.4.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(
# Using MPS
# 0it [00:00, ?it/s]

# %% [markdown]
# #### Read paths

# %%
glob_paths = list(set(glob.glob(f'{os.getcwd()}/Coding Material/*Folder/*/Job ID -*- Codebook (Automating Equity).xlsx')))

# %%
# 244 xlsx files
len(glob_paths)
# Out:
# 244

# %% [markdown]
# #### Use paths to open files, fix keywords, and drop unneeded columns

# %%
# %%time
# columns
cols=['Sector',
      'Sector Code',
      'Gender',
      'Age',
      'Language',
      'Dutch Requirement in Sentence',
      'English Requirement in Sentence',
      'Gender_Female',
      'Gender_Mixed',
      'Gender_Male',
      'Age_Older',
      'Age_Mixed',
      'Age_Younger',
      'Gender_Num',
      'Age_Num',
      '% Female',
      '% Male',
      '% Older',
      '% Younger']

# Fix list catches all incorrect/faculty keyword search terms
fix_list = []

# Appended data catches all the fixed and cleaned dfs
appended_data = []

for glob_path in glob_paths:

    try:
        df_temp = pd.read_excel(glob_path)
    except ValueError:
        fix_list.append(glob_path)

    if len(df_temp) > 0 and isinstance(df_temp, pd.DataFrame):
        df_temp = df_temp
        df_temp = df_temp.drop(columns=cols, axis='columns', errors='ignore')
        df_temp = df_temp.drop(
        df_temp.columns[
                df_temp.columns.str.contains(
                    'unnamed|index|level', regex=True, case=False, flags=re.I
                )
            ],
            axis='columns',
            errors='ignore',
        )

        appended_data.append(df_temp)

# Concatonate list of dfs into one large df_manual
df_manual = pd.concat(appended_data, axis='index')

# Save df_manual to file
assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
df_manual.to_pickle(f'{df_save_dir}df_manual_raw.pkl')
df_manual.to_csv(f'{df_save_dir}df_manual_raw.csv')
# Out:
# CPU times: user 6.71 s, sys: 268 ms, total: 6.98 s
# Wall time: 12.8 s

# %%
# If we couldn't fix some keywords, we add them to list fix_list and write to file
if len(fix_list) != 0:
    print('Some keywords to fix!')
    with open(f'{data_dir}fix_list.txt', 'w') as f:
        json.dump(fix_list, f)

# %%
# List of dfs, len = 244
len(appended_data)
# Out:
# 244

# %%
# Concatonate list of dfs into one large df_manual
df_manual = pd.concat(appended_data, axis='index')

# %%
# len = 12400
len(df_manual)
# Out:
# 12400

# %%
# Save df_manual to file
assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
df_manual.to_pickle(f'{df_save_dir}df_manual_raw.pkl')
df_manual.to_csv(f'{df_save_dir}df_manual_raw.csv')

# %% [markdown]
# ## Drop duplicated and missing data

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_RAW
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %%
import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

mod = sys.modules[__name__]

code_dir = None
code_dir_name = 'Code'
unwanted_subdir_name = 'Analysis'

if code_dir_name not in str(Path.cwd()).split('/')[-1]:
    for _ in range(5):

        parent_path = str(Path.cwd().parents[_]).split('/')[-1]

        if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

            code_dir = str(Path.cwd().parents[_])

            if code_dir is not None:
                break
else:
    code_dir = str(Path.cwd())
sys.path.append(code_dir)

# %load_ext autoreload
# %autoreload 2

# %%
from setup_module.imports import * # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# %%
df_manual = pd.read_pickle(f'{df_save_dir}df_manual_raw.pkl')

# %%
get_df_info(df_manual, ivs_all=dvs)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 12400 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Job ID           12400 non-null  object
#  1   Sentence         12396 non-null  object
#  2   Warmth           12398 non-null  float64
#  3   Competence       12400 non-null  int64
#  4   Task_Mentioned   12398 non-null  float64
#  5   Task_Warmth      12398 non-null  float64
#  6   Task_Competence  12398 non-null  float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 775.0+ KB
# ====================
# Warmth:
# --------------------
# Warmth Counts:
# Warmth
# 0.000    9572
# 1.000    2826
# Name: count, dtype: int64
# --------------------
# Warmth Percentages:
# Warmth
# 0.000   77.200
# 1.000   22.800
# Name: proportion, dtype: float64
# --------------------
# Min Warmth value: 0.0
# Max Warmth value: 1.0
# --------------------
# Warmth Mean: 0.228
# --------------------
# Warmth Standard Deviation: 0.42
# ====================
# Competence:
# --------------------
# Competence Counts:
# Competence
# 0    7334
# 1    5066
# Name: count, dtype: int64
# --------------------
# Competence Percentages:
# Competence
# 0   59.100
# 1   40.900
# Name: proportion, dtype: float64
# --------------------
# Min Competence value: 0.0
# Max Competence value: 1.0
# --------------------
# Competence Mean: 0.409
# --------------------
# Competence Standard Deviation: 0.492

# %%
# len = 12400
len(df_manual)
# Out:
# 12400

# %%
df_manual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12400 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Job ID           12400 non-null  object
#  1   Sentence         12396 non-null  object
#  2   Warmth           12398 non-null  float64
#  3   Competence       12400 non-null  int64
#  4   Task_Mentioned   12398 non-null  float64
#  5   Task_Warmth      12398 non-null  float64
#  6   Task_Competence  12398 non-null  float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 775.0+ KB

# %%
# Clean columns
df_manual.columns = df_manual.columns.to_series().progress_apply(lambda x: str(x).strip())
# Out:
# progress-bar:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
df_manual['Sentence'].head()
# Out:
# 0    Bunge (NYSE: BG) is a world leader in sourcing...
# 1    Founded in 1818, Bunge’s expansive network fee...
# 2                  The company is headquartered in St.
# 3     Louis, Missouri and has 25,000 employees worl...
# 4    “Be the technical linking pin between our Key ...
# Name: Sentence, dtype: object

# %%
# Remove columns 'Task_Mentioned', 'Task_Warmth', 'Task_Competence'
df_manual = df_manual.drop(
    columns=['Task_Mentioned', 'Task_Warmth', 'Task_Competence'],
    axis='columns',
    errors='ignore'
)

# %%
df_manual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12400 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Job ID      12400 non-null  object
#  1   Sentence    12396 non-null  object
#  2   Warmth      12398 non-null  float64
#  3   Competence  12400 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 484.4+ KB

# %%
# Missing values: Sentence = 4, Warmth = 2, Competence = 0
df_manual.isna().sum()
# Out:
# Job ID        0
# Sentence      4
# Warmth        2
# Competence    0
# dtype: int64

# %%
# Drop NA and non ut8 characters
df_manual = df_manual.dropna(axis='index', how='all')
df_manual = df_manual.dropna(axis='columns', how='all')
df_manual = df_manual.dropna(
    subset = ['Sentence', 'Warmth', 'Competence'],
)
df_manual = df_manual.sort_values(
    ['Warmth', 'Competence'], ascending=False
).drop_duplicates(
    subset=['Job ID', 'Sentence', 'Warmth', 'Competence']
)
df_manual = df_manual.loc[df_manual['Sentence'].str.len() > 2]
df_manual['Sentence'] = df_manual['Sentence'].progress_apply(lambda x: unicodedata.normalize('NFKD', x.encode('ascii', 'ignore').decode('utf-8', 'ignore')))
df_manual = df_manual.reset_index(drop=True)
# Out:
# progress-bar:   0%|          | 0/6966 [00:00<?, ?it/s]

# %%
# len=6966
len(df_manual)
# Out:
# 6966

# %%
df_manual['Sentence'].head()
# Out:
# 0    Through daily contact, as a partner of sales a...
# 1                 This role is truly cross functional.
# 2    The other part of your time would be spent as ...
# 3    Being the expert on your product also means yo...
# 4    Your mindset is commercial, result oriented an...
# Name: Sentence, dtype: object

# %%
# No na values
df_manual.isna().sum()
# Out:
# Job ID        0
# Sentence      0
# Warmth        0
# Competence    0
# dtype: int64

# %%
get_df_info(df_manual, ivs_all=dvs)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6966 entries, 0 to 6965
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Job ID      6966 non-null   object
#  1   Sentence    6966 non-null   object
#  2   Warmth      6966 non-null   float64
#  3   Competence  6966 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 217.8+ KB
# ====================
# Warmth:
# --------------------
# Warmth Counts:
# Warmth
# 0.000    5225
# 1.000    1741
# Name: count, dtype: int64
# --------------------
# Warmth Percentages:
# Warmth
# 0.000   75.000
# 1.000   25.000
# Name: proportion, dtype: float64
# --------------------
# Min Warmth value: 0.0
# Max Warmth value: 1.0
# --------------------
# Warmth Mean: 0.25
# --------------------
# Warmth Standard Deviation: 0.433
# ====================
# Competence:
# --------------------
# Competence Counts:
# Competence
# 0    3923
# 1    3043
# Name: count, dtype: int64
# --------------------
# Competence Percentages:
# Competence
# 0   56.300
# 1   43.700
# Name: proportion, dtype: float64
# --------------------
# Min Competence value: 0.0
# Max Competence value: 1.0
# --------------------
# Competence Mean: 0.437
# --------------------
# Competence Standard Deviation: 0.496

# %%
df_manual.columns
# Out:
# Index(['Job ID', 'Sentence', 'Warmth', 'Competence'], dtype='object')

# %%
df_manual['Sentence'].head()
# Out:
# 0    Through daily contact, as a partner of sales a...
# 1                 This role is truly cross functional.
# 2    The other part of your time would be spent as ...
# 3    Being the expert on your product also means yo...
# 4    Your mindset is commercial, result oriented an...
# Name: Sentence, dtype: object

# %%
# Convert Warmth and Competence to int
# Warmth 1 = 1741, Competence 1 = 3043
int_cols = [
    'Warmth',
    'Competence',
]

for col in int_cols:
    df_manual[col] = df_manual[col].astype(np.int64, errors='ignore')
    print(f'{col} converted to int.' if all(df_manual[col].progress_apply(lambda x: isinstance(x, int))) else f'{col} NOT converted to int.')
    print(f'{col} value counts:\n{df_manual[col].value_counts()}')
# Out:
# progress-bar:   0%|          | 0/6966 [00:00<?, ?it/s]
# Warmth converted to int.
# Warmth value counts:
# Warmth
# 0    5225
# 1    1741
# Name: count, dtype: int64
# progress-bar:   0%|          | 0/6966 [00:00<?, ?it/s]
# Competence converted to int.
# Competence value counts:
# Competence
# 0    3923
# 1    3043
# Name: count, dtype: int64

# %%
df_manual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6966 entries, 0 to 6965
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Job ID      6966 non-null   object
#  1   Sentence    6966 non-null   object
#  2   Warmth      6966 non-null   int64
#  3   Competence  6966 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 217.8+ KB

# %%
df_manual['Sentence'].head()
# Out:
# 0    Through daily contact, as a partner of sales a...
# 1                 This role is truly cross functional.
# 2    The other part of your time would be spent as ...
# 3    Being the expert on your product also means yo...
# 4    Your mindset is commercial, result oriented an...
# Name: Sentence, dtype: object

# %%
# %%time
# Conver Job ID and Sentence to str
str_cols = [
    'Job ID',
    'Sentence',
]

for col in str_cols:
    df_manual[col] = df_manual[col].astype(str, errors='ignore').progress_apply(lambda x: x.strip().replace('[', '').replace(']', ''))
    df_manual[col] = df_manual[col].progress_apply(lambda x: x.strip())
    df_manual[col] = df_manual[col].progress_apply(lambda x: unicodedata.normalize('NFKD', x.encode('ascii', 'ignore').decode('utf-8', 'ignore')))
    print(f'{col} converted to str.' if all(df_manual[col].progress_apply(lambda x: isinstance(x, str))) else f'{col} NOT converted to str.')
# Out:
# progress-bar:   0%|          | 0/6966 [00:00<?, ?it/s]
# progress-bar:   0%|          | 0/6966 [00:00<?, ?it/s]
# progress-bar:   0%|          | 0/6966 [00:00<?, ?it/s]
# progress-bar:   0%|          | 0/6966 [00:00<?, ?it/s]
# Job ID converted to str.
# progress-bar:   0%|          | 0/6966 [00:00<?, ?it/s]
# progress-bar:   0%|          | 0/6966 [00:00<?, ?it/s]
# progress-bar:   0%|          | 0/6966 [00:00<?, ?it/s]
# progress-bar:   0%|          | 0/6966 [00:00<?, ?it/s]
# Sentence converted to str.
# CPU times: user 70.2 ms, sys: 6.41 ms, total: 76.6 ms
# Wall time: 73.7 ms

# %%
# len = 6966
len(df_manual)
# Out:
# 6966

# %%
df_manual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6966 entries, 0 to 6965
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Job ID      6966 non-null   object
#  1   Sentence    6966 non-null   object
#  2   Warmth      6966 non-null   int64
#  3   Competence  6966 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 217.8+ KB

# %%
df_manual['Sentence'].head()
# Out:
# 0    Through daily contact, as a partner of sales a...
# 1                 This role is truly cross functional.
# 2    The other part of your time would be spent as ...
# 3    Being the expert on your product also means yo...
# 4    Your mindset is commercial, result oriented an...
# Name: Sentence, dtype: object

# %%
# Rename Sentence to 'Job Description spacy_sentencized'
df_manual = df_manual.rename(
    columns = {
        'Sentence': 'Job Description spacy_sentencized'
    },
    errors='ignore'
)

# %%
df_manual.columns
# Out:
# Index(['Job ID', 'Job Description spacy_sentencized', 'Warmth', 'Competence'], dtype='object')

# %%
df_manual['Job Description spacy_sentencized'].head()
# Out:
# 0    Through daily contact, as a partner of sales a...
# 1                 This role is truly cross functional.
# 2    The other part of your time would be spent as ...
# 3    Being the expert on your product also means yo...
# 4    Your mindset is commercial, result oriented an...
# Name: Job Description spacy_sentencized, dtype: object

# %%
# count=6966, unique=5662
df_manual['Job Description spacy_sentencized'].describe()
# Out:
# count                6966
# unique               5662
# top       Job Description
# freq                   12
# Name: Job Description spacy_sentencized, dtype: object

# %%
# Drop NA
df_manual = df_manual.dropna(axis='index', how='all')
df_manual = df_manual.dropna(axis='columns', how='all')
df_manual = df_manual.dropna(
    subset = ['Job Description spacy_sentencized', 'Warmth', 'Competence'],
)
df_manual = df_manual.sort_values(
    ['Warmth', 'Competence'], ascending=False
).drop_duplicates(
    subset=['Job ID', 'Job Description spacy_sentencized', 'Warmth', 'Competence']
)
df_manual = df_manual.loc[df_manual['Job Description spacy_sentencized'].str.len() > 2]
df_manual['Job Description spacy_sentencized'] = df_manual['Job Description spacy_sentencized'].progress_apply(lambda x: unicodedata.normalize('NFKD', x.encode('ascii', 'ignore').decode('utf-8', 'ignore')))
df_manual = df_manual
# Out:
# progress-bar:   0%|          | 0/6966 [00:00<?, ?it/s]

# %%
# Drop na, empty strings, punctuations, and keep only sentences of length more than 0
with open(f'{data_dir}punctuations.txt', 'rb') as f:
    custom_punct_chars = pickle.load(f)

df_manual = df_manual.dropna(subset=['Job Description spacy_sentencized'])
df_manual = df_manual.loc[
    (df_manual['Job Description spacy_sentencized'].isnull() == False)
    & (df_manual['Job Description spacy_sentencized'].isna() == False)
    & (df_manual['Job Description spacy_sentencized'].notnull() == True)
    & (df_manual['Job Description spacy_sentencized'].notna() == True)
    & (df_manual['Job Description spacy_sentencized'].astype(str).progress_apply(len) > 0)
    & (df_manual['Job Description spacy_sentencized'].astype(bool) == True)
    & (pd.isna(df_manual['Job Description spacy_sentencized']) == False)
    & (df_manual['Job Description spacy_sentencized'].astype(str).isin(custom_punct_chars) == False)
    & (df_manual['Job Description spacy_sentencized'].astype(str).isin(non_whitespace_nan_list) == False)
    & (df_manual['Job Description spacy_sentencized'].astype(str).isin(list(string.punctuation)) == False)
    & (df_manual['Job Description spacy_sentencized'].astype(str).isin(list(string.whitespace)) == False)
]
df_manual = df_manual.dropna(subset=['Job Description spacy_sentencized'])
# Out:
# progress-bar:   0%|          | 0/6966 [00:00<?, ?it/s]

# %%
df_manual['Job Description spacy_sentencized'].head()
# Out:
# 0    Through daily contact, as a partner of sales a...
# 1                 This role is truly cross functional.
# 2    The other part of your time would be spent as ...
# 3    Being the expert on your product also means yo...
# 4    Your mindset is commercial, result oriented an...
# Name: Job Description spacy_sentencized, dtype: object

# %%
# count=6966, unique=5662
df_manual['Job Description spacy_sentencized'].describe()
# Out:
# count                6966
# unique               5662
# top       Job Description
# freq                   12
# Name: Job Description spacy_sentencized, dtype: object

# %%
# Get the longest sentence
df_manual['Job Description spacy_sentencized'].loc[df_manual['Job Description spacy_sentencized'].progress_apply(len).idxmax()]
# Out:
# progress-bar:   0%|          | 0/6966 [00:00<?, ?it/s]
# 'This requires a clear business focus and interaction with the Business (division) controllers;Responsible for monthly closing & reporting and quarterly disclosures towards several stakeholders and the annual reports (Dutch GAAP);Co-lead the transition project from Dutch GAAP to IFRS;Administer, develop and improve the accuracy of FCCS (cloud version of Oracles HFM) alongside training users on best practice use of the system;Responsible for upload and consolidation of P&L budgets and cashflow forecasts;Developing and implementing best practice processes and systems across the Group;Prepare Group Consolidated Financial Statements;Technical accounting support to operating businesses;Perform balance sheet reviews and lead specific periodic accounting tests; assure compliance with Dutch GAAP (future IFRS) and the guidelines of the company;Act as the responsible controller for Royal Reesink BV;Manage process improvements and improvements to the ERP system.'

# %%
# len=964
df_manual['Job Description spacy_sentencized'].progress_apply(len).max()
# Out:
# progress-bar:   0%|          | 0/6966 [00:00<?, ?it/s]
# 964

# %%
# Get the shortest sentence
df_manual['Job Description spacy_sentencized'].loc[df_manual['Job Description spacy_sentencized'].progress_apply(len).idxmin()]
# Out:
# progress-bar:   0%|          | 0/6966 [00:00<?, ?it/s]
# 'Mac'

# %%
# len=3
df_manual['Job Description spacy_sentencized'].progress_apply(len).min()
# Out:
# progress-bar:   0%|          | 0/6966 [00:00<?, ?it/s]
# 3

# %%
# len = 6966
len(df_manual)
# Out:
# 6966

# %%
# len = 133
len(df_manual.groupby(['Job ID'])['Job ID'].unique())
# Out:
# 133

# %%
# Drop duplicates on subset of 'Job ID' and 'Sentence' after sorting by 'Warmth' and 'Competence' (to keep order)
random.seed(random_state)
np.random.seed(random_state)
df_manual = df_manual.sort_values(
    ['Warmth', 'Competence'], ascending=False
).drop_duplicates(
    subset=['Job ID', 'Job Description spacy_sentencized'], keep='first'
)

# %%
# len = 6376
len(df_manual)
# Out:
# 6376

# %%
# Remove any rows with missing 'Job ID'
df_manual = df_manual.drop(
    df_manual[
        (df_manual['Job ID'].isin(nan_list)) |
        (df_manual['Job ID'].isnull()) |
        (df_manual['Job ID'].isna())
    ].index,
    axis='index',
)

# %%
# len = 6376
len(df_manual)
# Out:
# 6376

# %%
# Warmth 1 = 1567 (24.90%), Competence 1 = 2827 (44.30%)
get_df_info(df_manual, ivs_all=dvs)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 6376 entries, 0 to 6965
# Data columns (total 4 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Job ID                             6376 non-null   object
#  1   Job Description spacy_sentencized  6376 non-null   object
#  2   Warmth                             6376 non-null   int64
#  3   Competence                         6376 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 249.1+ KB
# ====================
# Warmth:
# --------------------
# Warmth Counts:
# Warmth
# 0    4682
# 1    1694
# Name: count, dtype: int64
# --------------------
# Warmth Percentages:
# Warmth
# 0   73.400
# 1   26.600
# Name: proportion, dtype: float64
# --------------------
# Min Warmth value: 0.0
# Max Warmth value: 1.0
# --------------------
# Warmth Mean: 0.266
# --------------------
# Warmth Standard Deviation: 0.442
# ====================
# Competence:
# --------------------
# Competence Counts:
# Competence
# 0    3451
# 1    2925
# Name: count, dtype: int64
# --------------------
# Competence Percentages:
# Competence
# 0   54.100
# 1   45.900
# Name: proportion, dtype: float64
# --------------------
# Min Competence value: 0.0
# Max Competence value: 1.0
# --------------------
# Competence Mean: 0.459
# --------------------
# Competence Standard Deviation: 0.498

# %%
# Save df_manual to file
assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
df_manual.to_pickle(f'{df_save_dir}df_manual_raw_dropped.pkl')
df_manual.to_csv(f'{df_save_dir}df_manual_raw_dropped.csv')

# %% [markdown]
# ## Add English and Dutch language requirement columns

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_RAW_DROPPED
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %%
import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

mod = sys.modules[__name__]

code_dir = None
code_dir_name = 'Code'
unwanted_subdir_name = 'Analysis'

if code_dir_name not in str(Path.cwd()).split('/')[-1]:
    for _ in range(5):

        parent_path = str(Path.cwd().parents[_]).split('/')[-1]

        if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

            code_dir = str(Path.cwd().parents[_])

            if code_dir is not None:
                break
else:
    code_dir = str(Path.cwd())
sys.path.append(code_dir)

# %load_ext autoreload
# %autoreload 2

# %%
from setup_module.imports import * # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# %%
df_manual = pd.read_pickle(f'{df_save_dir}df_manual_raw_dropped.pkl')#

# %%
# Warmth 1 = 1577 (24.90%), Competence 1 = 2821 (44.30%)
get_df_info(df_manual, ivs_all=dvs)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 6376 entries, 0 to 6965
# Data columns (total 4 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Job ID                             6376 non-null   object
#  1   Job Description spacy_sentencized  6376 non-null   object
#  2   Warmth                             6376 non-null   int64
#  3   Competence                         6376 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 249.1+ KB
# ====================
# Warmth:
# --------------------
# Warmth Counts:
# Warmth
# 0    4682
# 1    1694
# Name: count, dtype: int64
# --------------------
# Warmth Percentages:
# Warmth
# 0   73.400
# 1   26.600
# Name: proportion, dtype: float64
# --------------------
# Min Warmth value: 0.0
# Max Warmth value: 1.0
# --------------------
# Warmth Mean: 0.266
# --------------------
# Warmth Standard Deviation: 0.442
# ====================
# Competence:
# --------------------
# Competence Counts:
# Competence
# 0    3451
# 1    2925
# Name: count, dtype: int64
# --------------------
# Competence Percentages:
# Competence
# 0   54.100
# 1   45.900
# Name: proportion, dtype: float64
# --------------------
# Min Competence value: 0.0
# Max Competence value: 1.0
# --------------------
# Competence Mean: 0.459
# --------------------
# Competence Standard Deviation: 0.498

# %%
# 6376
len(df_manual)
# Out:
# 6376

# %%
df_manual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6376 entries, 0 to 6965
# Data columns (total 4 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Job ID                             6376 non-null   object
#  1   Job Description spacy_sentencized  6376 non-null   object
#  2   Warmth                             6376 non-null   int64
#  3   Competence                         6376 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 249.1+ KB

# %%
# %%time
# Add language requirement column
# Use regex to find language requirement
lang_requirements = {
    'Dutch Requirement in Sentence': dutch_requirement_pattern, 'English Requirement in Sentence': english_requirement_pattern
}

for lang_req, lang_req_pattern in lang_requirements.items():
    if lang_req in df_manual.columns:
        df_manual = df_manual.drop(columns=[lang_req])
    df_manual[lang_req] = np.where(
        df_manual['Job Description spacy_sentencized'].str.contains(lang_req_pattern),
        'Yes',
        'No',
    )

    df_manual[lang_req] = df_manual[lang_req].astype('category').cat.reorder_categories(['No', 'Yes'], ordered=True)
    df_manual[lang_req] = pd.Categorical(df_manual[lang_req], categories=['No', 'Yes'], ordered=True)

assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
df_manual.to_pickle(f'{df_save_dir}df_manual_raw_language_requirement.pkl')
df_manual.to_csv(f'{df_save_dir}df_manual_raw_english_requirement.csv')
# Out:
# CPU times: user 97.2 ms, sys: 4.24 ms, total: 101 ms
# Wall time: 107 ms

# %%
# Yes = 7
df_manual['Dutch Requirement in Sentence'].value_counts()
# Out:
# Dutch Requirement in Sentence
# No     6370
# Yes       6
# Name: count, dtype: int64

# %%
# Yes = 8
df_manual['English Requirement in Sentence'].value_counts()
# Out:
# English Requirement in Sentence
# No     6366
# Yes      10
# Name: count, dtype: int64

# %%
# Dummy coding for language requirement
df_manual = df_manual.join(pd.get_dummies(df_manual[['Dutch Requirement in Sentence', 'English Requirement in Sentence']], dtype='int64'))

# %%
# Yes = 7
df_manual['Dutch Requirement in Sentence_Yes'].value_counts()
# Out:
# Dutch Requirement in Sentence_Yes
# 0    6370
# 1       6
# Name: count, dtype: int64

# %%
df_manual['English Requirement in Sentence_Yes'].value_counts()
# Out:
# English Requirement in Sentence_Yes
# 0    6366
# 1      10
# Name: count, dtype: int64

# %%
assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
df_manual.to_pickle(f'{df_save_dir}df_manual_raw_language_requirement.pkl')
df_manual.to_csv(f'{df_save_dir}df_manual_raw_language_requirement.csv')

# %% [markdown]
# ## Add data from Sectors dataframe (see CBS directory under '1. Scraping' directory) and Categorical data

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_RAW_LANGUAGE_REQUIREMENT
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %%
import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

mod = sys.modules[__name__]

code_dir = None
code_dir_name = 'Code'
unwanted_subdir_name = 'Analysis'

if code_dir_name not in str(Path.cwd()).split('/')[-1]:
    for _ in range(5):

        parent_path = str(Path.cwd().parents[_]).split('/')[-1]

        if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

            code_dir = str(Path.cwd().parents[_])

            if code_dir is not None:
                break
else:
    code_dir = str(Path.cwd())
sys.path.append(code_dir)

# %load_ext autoreload
# %autoreload 2

# %%
from setup_module.imports import * # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# %%
df_manual = pd.read_pickle(f'{df_save_dir}df_manual_raw_language_requirement.pkl')

# %%
# Warmth 1 = 1567 (24.90%), Competence 1 = 2827 (44.30%)
get_df_info(df_manual, ivs_all=dvs)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 6376 entries, 0 to 6965
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Job ID                               6376 non-null   object
#  1   Job Description spacy_sentencized    6376 non-null   object
#  2   Warmth                               6376 non-null   int64
#  3   Competence                           6376 non-null   int64
#  4   Dutch Requirement in Sentence        6376 non-null   category
#  5   English Requirement in Sentence      6376 non-null   category
#  6   Dutch Requirement in Sentence_No     6376 non-null   int64
#  7   Dutch Requirement in Sentence_Yes    6376 non-null   int64
#  8   English Requirement in Sentence_No   6376 non-null   int64
#  9   English Requirement in Sentence_Yes  6376 non-null   int64
# dtypes: category(2), int64(6), object(2)
# memory usage: 460.8+ KB
# ====================
# Warmth:
# --------------------
# Warmth Counts:
# Warmth
# 0    4682
# 1    1694
# Name: count, dtype: int64
# --------------------
# Warmth Percentages:
# Warmth
# 0   73.400
# 1   26.600
# Name: proportion, dtype: float64
# --------------------
# Min Warmth value: 0.0
# Max Warmth value: 1.0
# --------------------
# Warmth Mean: 0.266
# --------------------
# Warmth Standard Deviation: 0.442
# ====================
# Competence:
# --------------------
# Competence Counts:
# Competence
# 0    3451
# 1    2925
# Name: count, dtype: int64
# --------------------
# Competence Percentages:
# Competence
# 0   54.100
# 1   45.900
# Name: proportion, dtype: float64
# --------------------
# Min Competence value: 0.0
# Max Competence value: 1.0
# --------------------
# Competence Mean: 0.459
# --------------------
# Competence Standard Deviation: 0.498

# %%
df_manual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6376 entries, 0 to 6965
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Job ID                               6376 non-null   object
#  1   Job Description spacy_sentencized    6376 non-null   object
#  2   Warmth                               6376 non-null   int64
#  3   Competence                           6376 non-null   int64
#  4   Dutch Requirement in Sentence        6376 non-null   category
#  5   English Requirement in Sentence      6376 non-null   category
#  6   Dutch Requirement in Sentence_No     6376 non-null   int64
#  7   Dutch Requirement in Sentence_Yes    6376 non-null   int64
#  8   English Requirement in Sentence_No   6376 non-null   int64
#  9   English Requirement in Sentence_Yes  6376 non-null   int64
# dtypes: category(2), int64(6), object(2)
# memory usage: 460.8+ KB

# %%
df_manual['Job ID'] = df_manual['Job ID'].progress_apply(lambda x: str(x).lower().strip())
# Out:
# progress-bar:   0%|          | 0/6376 [00:00<?, ?it/s]

# %%
df_jobs = pd.read_pickle(f'{df_save_dir}df_jobs_including_sector_genage_data.pkl')

# %%
df_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17593 entries, 0 to 17592
# Data columns (total 68 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Search Keyword                                     17593 non-null  object
#  1   Platform                                           17593 non-null  category
#  2   Job ID                                             17593 non-null  object
#  3   Job Title                                          17593 non-null  object
#  4   Company Name                                       17591 non-null  object
#  5   Location                                           17593 non-null  object
#  6   Job Description                                    17593 non-null  object
#  7   Rating                                             3780 non-null   float64
#  8   Employment Type                                    17011 non-null  object
#  9   Company URL                                        15954 non-null  object
#  10  Job URL                                            17593 non-null  object
#  11  Job Age                                            17593 non-null  object
#  12  Job Age Number                                     17593 non-null  object
#  13  Collection Date                                    17593 non-null  object
#  14  Data Row                                           13810 non-null  float64
#  15  Tracking ID                                        13810 non-null  object
#  16  Industry                                           14395 non-null  object
#  17  Job Date                                           13813 non-null  object
#  18  Type of ownership                                  582 non-null    object
#  19  Language                                           17593 non-null  object
#  20  Dutch Requirement in Job Ad                        17593 non-null  category
#  21  English Requirement in Job Ad                      17593 non-null  category
#  22  Dutch Requirement in Job Ad_No                     17593 non-null  int64
#  23  Dutch Requirement in Job Ad_Yes                    17593 non-null  int64
#  24  English Requirement in Job Ad_No                   17593 non-null  int64
#  25  English Requirement in Job Ad_Yes                  17593 non-null  int64
#  26  Sector Code                                        17593 non-null  object
#  27  Sector                                             17593 non-null  object
#  28  Keywords Count                                     17593 non-null  float64
#  29  Gender_Female_n                                    17593 non-null  float64
#  30  Gender_Female_% per Sector                         17593 non-null  float64
#  31  Gender_Female_% per Social Category                17593 non-null  float64
#  32  Gender_Female_% per Workforce                      17593 non-null  float64
#  33  Gender_Male_n                                      17593 non-null  float64
#  34  Gender_Male_% per Sector                           17593 non-null  float64
#  35  Gender_Male_% per Social Category                  17593 non-null  float64
#  36  Gender_Male_% per Workforce                        17593 non-null  float64
#  37  Gender                                             17593 non-null  category
#  38  Age_Older_n                                        17593 non-null  float64
#  39  Age_Older_% per Sector                             17593 non-null  float64
#  40  Age_Older_% per Social Category                    17593 non-null  float64
#  41  Age_Older_% per Workforce                          17593 non-null  float64
#  42  Age_Younger_n                                      17593 non-null  float64
#  43  Age_Younger_% per Sector                           17593 non-null  float64
#  44  Age_Younger_% per Social Category                  17593 non-null  float64
#  45  Age_Younger_% per Workforce                        17593 non-null  float64
#  46  Age                                                17593 non-null  category
#  47  Sector_n                                           17593 non-null  float64
#  48  % Sector per Workforce                             17593 non-null  float64
#  49  Sector Job Advertisement Count                     17593 non-null  int64
#  50  Sector Gender Designation Job Advertisement Count  17593 non-null  int64
#  51  Sector Age Designation Job Advertisement Count     17593 non-null  int64
#  52  Gender_Female                                      17593 non-null  int64
#  53  Gender_Male                                        17593 non-null  int64
#  54  Gender_Mixed                                       17593 non-null  int64
#  55  Age_Mixed                                          17593 non-null  int64
#  56  Age_Older                                          17593 non-null  int64
#  57  Age_Younger                                        17593 non-null  int64
#  58  Gender_Num                                         17593 non-null  int64
#  59  Age_Num                                            17593 non-null  int64
#  60  Interaction_Female_Older_% per Sector              17593 non-null  float64
#  61  Interaction_Female_Younger_% per Sector            17593 non-null  float64
#  62  Interaction_Male_Older_% per Sector                17593 non-null  float64
#  63  Interaction_Male_Younger_% per Sector              17593 non-null  float64
#  64  Platform_Num                                       17593 non-null  int64
#  65  Platform_LinkedIn                                  17593 non-null  int64
#  66  Platform_Indeed                                    17593 non-null  int64
#  67  Platform_Glassdoor                                 17593 non-null  int64
# dtypes: category(5), float64(25), int64(19), object(19)
# memory usage: 8.5+ MB

# %%
df_jobs['Job ID'] = df_jobs['Job ID'].progress_apply(lambda x: str(x).lower().strip())
# Out:
# progress-bar:   0%|          | 0/17593 [00:00<?, ?it/s]

# %%
df_jobs.columns
# Out:
# Index(['Search Keyword', 'Platform', 'Job ID', 'Job Title', 'Company Name', 'Location', 'Job Description', 'Rating', 'Employment Type', 'Company URL', 'Job URL', 'Job Age', 'Job Age Number', 'Collection Date', 'Data Row', 'Tracking ID', 'Industry', 'Job Date', 'Type of ownership', 'Language', 'Dutch Requirement in Job Ad', 'English Requirement in Job Ad', 'Dutch Requirement in Job Ad_No', 'Dutch Requirement in Job Ad_Yes', 'English Requirement in Job Ad_No', 'English Requirement in Job Ad_Yes', 'Sector Code', 'Sector', 'Keywords Count', 'Gender_Female_n', 'Gender_Female_% per Sector', 'Gender_Female_% per Social Category', 'Gender_Female_% per Workforce', 'Gender_Male_n', 'Gender_Male_% per Sector', 'Gender_Male_% per Social Category', 'Gender_Male_% per Workforce', 'Gender', 'Age_Older_n', 'Age_Older_% per Sector', 'Age_Older_% per Social Category', 'Age_Older_% per Workforce', 'Age_Younger_n', 'Age_Younger_% per Sector', 'Age_Younger_% per Social Category', 'Age_Younger_% per Workforce', 'Age', 'Sector_n', '% Sector per Workforce', 'Sector Job Advertisement Count', 'Sector Gender Designation Job Advertisement Count', 'Sector Age Designation Job Advertisement Count', 'Gender_Female', 'Gender_Male', 'Gender_Mixed', 'Age_Mixed', 'Age_Older', 'Age_Younger', 'Gender_Num', 'Age_Num', 'Interaction_Female_Older_% per Sector', 'Interaction_Female_Younger_% per Sector', 'Interaction_Male_Older_% per Sector', 'Interaction_Male_Younger_% per Sector', 'Platform_Num', 'Platform_LinkedIn', 'Platform_Indeed', 'Platform_Glassdoor'], dtype='object')

# %%
df_jobs = df_jobs.drop(
    columns = [
        'Job Description', 'Rating', 'Employment Type',
        'Company URL', 'Job URL', 'Job Age', 'Job Age Number',
        'Collection Date', 'Data Row', 'Tracking ID', 'Job Date',
        'Type of ownership', 'Language', 'Dutch Requirement in Sentence', 'English Requirement in Sentence',
    ],
    errors='ignore'
)

# %%
df_jobs.columns
# Out:
# Index(['Search Keyword', 'Platform', 'Job ID', 'Job Title', 'Company Name', 'Location', 'Industry', 'Dutch Requirement in Job Ad', 'English Requirement in Job Ad', 'Dutch Requirement in Job Ad_No', 'Dutch Requirement in Job Ad_Yes', 'English Requirement in Job Ad_No', 'English Requirement in Job Ad_Yes', 'Sector Code', 'Sector', 'Keywords Count', 'Gender_Female_n', 'Gender_Female_% per Sector', 'Gender_Female_% per Social Category', 'Gender_Female_% per Workforce', 'Gender_Male_n', 'Gender_Male_% per Sector', 'Gender_Male_% per Social Category', 'Gender_Male_% per Workforce', 'Gender', 'Age_Older_n', 'Age_Older_% per Sector', 'Age_Older_% per Social Category', 'Age_Older_% per Workforce', 'Age_Younger_n', 'Age_Younger_% per Sector', 'Age_Younger_% per Social Category', 'Age_Younger_% per Workforce', 'Age', 'Sector_n', '% Sector per Workforce', 'Sector Job Advertisement Count', 'Sector Gender Designation Job Advertisement Count', 'Sector Age Designation Job Advertisement Count', 'Gender_Female', 'Gender_Male', 'Gender_Mixed', 'Age_Mixed', 'Age_Older', 'Age_Younger', 'Gender_Num', 'Age_Num', 'Interaction_Female_Older_% per Sector', 'Interaction_Female_Younger_% per Sector', 'Interaction_Male_Older_% per Sector', 'Interaction_Male_Younger_% per Sector', 'Platform_Num', 'Platform_LinkedIn', 'Platform_Indeed', 'Platform_Glassdoor'], dtype='object')

# %%
# Add sector and categorical data from df_jobs
df_manual = df_manual.merge(df_jobs, on='Job ID', how='inner')

# %%
# len = 5955
len(df_manual)
# Out:
# 5955

# %%
df_manual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5955 entries, 0 to 5954
# Data columns (total 64 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Job ID                                             5955 non-null   object
#  1   Job Description spacy_sentencized                  5955 non-null   object
#  2   Warmth                                             5955 non-null   int64
#  3   Competence                                         5955 non-null   int64
#  4   Dutch Requirement in Sentence                      5955 non-null   category
#  5   English Requirement in Sentence                    5955 non-null   category
#  6   Dutch Requirement in Sentence_No                   5955 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                  5955 non-null   int64
#  8   English Requirement in Sentence_No                 5955 non-null   int64
#  9   English Requirement in Sentence_Yes                5955 non-null   int64
#  10  Search Keyword                                     5955 non-null   object
#  11  Platform                                           5955 non-null   category
#  12  Job Title                                          5955 non-null   object
#  13  Company Name                                       5955 non-null   object
#  14  Location                                           5955 non-null   object
#  15  Industry                                           290 non-null    object
#  16  Dutch Requirement in Job Ad                        5955 non-null   category
#  17  English Requirement in Job Ad                      5955 non-null   category
#  18  Dutch Requirement in Job Ad_No                     5955 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                    5955 non-null   int64
#  20  English Requirement in Job Ad_No                   5955 non-null   int64
#  21  English Requirement in Job Ad_Yes                  5955 non-null   int64
#  22  Sector Code                                        5955 non-null   object
#  23  Sector                                             5955 non-null   object
#  24  Keywords Count                                     5955 non-null   float64
#  25  Gender_Female_n                                    5955 non-null   float64
#  26  Gender_Female_% per Sector                         5955 non-null   float64
#  27  Gender_Female_% per Social Category                5955 non-null   float64
#  28  Gender_Female_% per Workforce                      5955 non-null   float64
#  29  Gender_Male_n                                      5955 non-null   float64
#  30  Gender_Male_% per Sector                           5955 non-null   float64
#  31  Gender_Male_% per Social Category                  5955 non-null   float64
#  32  Gender_Male_% per Workforce                        5955 non-null   float64
#  33  Gender                                             5955 non-null   category
#  34  Age_Older_n                                        5955 non-null   float64
#  35  Age_Older_% per Sector                             5955 non-null   float64
#  36  Age_Older_% per Social Category                    5955 non-null   float64
#  37  Age_Older_% per Workforce                          5955 non-null   float64
#  38  Age_Younger_n                                      5955 non-null   float64
#  39  Age_Younger_% per Sector                           5955 non-null   float64
#  40  Age_Younger_% per Social Category                  5955 non-null   float64
#  41  Age_Younger_% per Workforce                        5955 non-null   float64
#  42  Age                                                5955 non-null   category
#  43  Sector_n                                           5955 non-null   float64
#  44  % Sector per Workforce                             5955 non-null   float64
#  45  Sector Job Advertisement Count                     5955 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count  5955 non-null   int64
#  47  Sector Age Designation Job Advertisement Count     5955 non-null   int64
#  48  Gender_Female                                      5955 non-null   int64
#  49  Gender_Male                                        5955 non-null   int64
#  50  Gender_Mixed                                       5955 non-null   int64
#  51  Age_Mixed                                          5955 non-null   int64
#  52  Age_Older                                          5955 non-null   int64
#  53  Age_Younger                                        5955 non-null   int64
#  54  Gender_Num                                         5955 non-null   int64
#  55  Age_Num                                            5955 non-null   int64
#  56  Interaction_Female_Older_% per Sector              5955 non-null   float64
#  57  Interaction_Female_Younger_% per Sector            5955 non-null   float64
#  58  Interaction_Male_Older_% per Sector                5955 non-null   float64
#  59  Interaction_Male_Younger_% per Sector              5955 non-null   float64
#  60  Platform_Num                                       5955 non-null   int64
#  61  Platform_LinkedIn                                  5955 non-null   int64
#  62  Platform_Indeed                                    5955 non-null   int64
#  63  Platform_Glassdoor                                 5955 non-null   int64
# dtypes: category(7), float64(23), int64(25), object(9)
# memory usage: 2.6+ MB

# %%
df_manual.head()
# Out:
#          Job ID               Job Description spacy_sentencized           Warmth  Competence Dutch Requirement in Sentence English Requirement in Sentence  Dutch Requirement in Sentence_No  Dutch Requirement in Sentence_Yes  English Requirement in Sentence_No  English Requirement in Sentence_Yes         Search Keyword         Platform                     Job Title                      Company Name   Location   Industry Dutch Requirement in Job Ad English Requirement in Job Ad  Dutch Requirement in Job Ad_No  Dutch Requirement in Job Ad_Yes  English Requirement in Job Ad_No  English Requirement in Job Ad_Yes Sector Code                Sector                Keywords Count  Gender_Female_n  Gender_Female_% per Sector  Gender_Female_% per Social Category  Gender_Female_% per Workforce  Gender_Male_n  Gender_Male_% per Sector  Gender_Male_% per Social Category  Gender_Male_% per Workforce     Gender     Age_Older_n  Age_Older_% per Sector  Age_Older_% per Social Category  Age_Older_% per Workforce  Age_Younger_n  Age_Younger_% per Sector  Age_Younger_% per Social Category  Age_Younger_% per Workforce   Age     Sector_n  % Sector per Workforce  Sector Job Advertisement Count  Sector Gender Designation Job Advertisement Count  Sector Age Designation Job Advertisement Count  Gender_Female  Gender_Male  Gender_Mixed  Age_Mixed  Age_Older  Age_Younger  Gender_Num  Age_Num  Interaction_Female_Older_% per Sector  Interaction_Female_Younger_% per Sector  Interaction_Male_Older_% per Sector  Interaction_Male_Younger_% per Sector  Platform_Num  Platform_LinkedIn  Platform_Indeed  Platform_Glassdoor
# 0  p_8436b3cd1a61d239  Through daily contact, as a partner of sales a...     1         1                   No                             No                                1                                 0                                   1                                   0                   career development specialist  Indeed   Application and Technical Support Manager - Ba...     Bunge      Wormerveer    NaN                No                           No                              1                               0                                 1                                 0                       N      Renting and other business support      8.000          416.000                 42.754                          3.462                             1.646                 557.000               57.246                        4.204                           2.204              Mixed Gender   311.000             31.963                      2.925                         1.231               660.000               67.831                        4.511                           2.612              Younger  973.000           3.850                        1064                                     6664                                              2351                             0             0             1           0          0           1            1         2                   1366.558                                2900.091                               1829.742                              3883.054                       1               0                 1                  0
# 1  p_8436b3cd1a61d239               This role is truly cross functional.     1         1                   No                             No                                1                                 0                                   1                                   0                   career development specialist  Indeed   Application and Technical Support Manager - Ba...     Bunge      Wormerveer    NaN                No                           No                              1                               0                                 1                                 0                       N      Renting and other business support      8.000          416.000                 42.754                          3.462                             1.646                 557.000               57.246                        4.204                           2.204              Mixed Gender   311.000             31.963                      2.925                         1.231               660.000               67.831                        4.511                           2.612              Younger  973.000           3.850                        1064                                     6664                                              2351                             0             0             1           0          0           1            1         2                   1366.558                                2900.091                               1829.742                              3883.054                       1               0                 1                  0
# 2  p_8436b3cd1a61d239  The other part of your time would be spent as ...     1         1                   No                             No                                1                                 0                                   1                                   0                   career development specialist  Indeed   Application and Technical Support Manager - Ba...     Bunge      Wormerveer    NaN                No                           No                              1                               0                                 1                                 0                       N      Renting and other business support      8.000          416.000                 42.754                          3.462                             1.646                 557.000               57.246                        4.204                           2.204              Mixed Gender   311.000             31.963                      2.925                         1.231               660.000               67.831                        4.511                           2.612              Younger  973.000           3.850                        1064                                     6664                                              2351                             0             0             1           0          0           1            1         2                   1366.558                                2900.091                               1829.742                              3883.054                       1               0                 1                  0
# 3  p_8436b3cd1a61d239  Being the expert on your product also means yo...     1         1                   No                             No                                1                                 0                                   1                                   0                   career development specialist  Indeed   Application and Technical Support Manager - Ba...     Bunge      Wormerveer    NaN                No                           No                              1                               0                                 1                                 0                       N      Renting and other business support      8.000          416.000                 42.754                          3.462                             1.646                 557.000               57.246                        4.204                           2.204              Mixed Gender   311.000             31.963                      2.925                         1.231               660.000               67.831                        4.511                           2.612              Younger  973.000           3.850                        1064                                     6664                                              2351                             0             0             1           0          0           1            1         2                   1366.558                                2900.091                               1829.742                              3883.054                       1               0                 1                  0
# 4  p_8436b3cd1a61d239  Your mindset is commercial, result oriented an...     1         1                   No                             No                                1                                 0                                   1                                   0                   career development specialist  Indeed   Application and Technical Support Manager - Ba...     Bunge      Wormerveer    NaN                No                           No                              1                               0                                 1                                 0                       N      Renting and other business support      8.000          416.000                 42.754                          3.462                             1.646                 557.000               57.246                        4.204                           2.204              Mixed Gender   311.000             31.963                      2.925                         1.231               660.000               67.831                        4.511                           2.612              Younger  973.000           3.850                        1064                                     6664                                              2351                             0             0             1           0          0           1            1         2                   1366.558                                2900.091                               1829.742                              3883.054                       1               0                 1                  0

# %% [markdown]
# #### Check if there is any missing sector data in the merged dataframe

# %%
df_manual['Sector'].isna().sum()
# Out:
# 0

# %%
if df_manual['Sector'].isna().sum() != 0:
    print('Some search keywords did not match a sector. Fixing')
    print(set(df_manual['Search Keyword'].loc[df_manual['Sector'].isna()].to_list()))
    print(len(df_manual['Search Keyword'].loc[df_manual['Search Keyword'].isin(list(keyword_trans_dict.keys()))]))
    df_manual = fix_keywords(df_manual)
    print(set(df_manual['Search Keyword'].loc[df_manual['Sector'].isna()].to_list()))
    print(len(df_manual['Search Keyword'].loc[df_manual['Search Keyword'].isin(list(keyword_trans_dict.keys()))]))

# %%
# Manual Job Ad info, len = 117
get_df_info(df_manual.groupby(['Job ID']).first(), ivs_all=ivs_all)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 117 entries, 3768944208 to pj_a4ac3e531abef752
# Data columns (total 63 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Job Description spacy_sentencized                  117 non-null    object
#  1   Warmth                                             117 non-null    int64
#  2   Competence                                         117 non-null    int64
#  3   Dutch Requirement in Sentence                      117 non-null    category
#  4   English Requirement in Sentence                    117 non-null    category
#  5   Dutch Requirement in Sentence_No                   117 non-null    int64
#  6   Dutch Requirement in Sentence_Yes                  117 non-null    int64
#  7   English Requirement in Sentence_No                 117 non-null    int64
#  8   English Requirement in Sentence_Yes                117 non-null    int64
#  9   Search Keyword                                     117 non-null    object
#  10  Platform                                           117 non-null    category
#  11  Job Title                                          117 non-null    object
#  12  Company Name                                       117 non-null    object
#  13  Location                                           117 non-null    object
#  14  Industry                                           5 non-null      object
#  15  Dutch Requirement in Job Ad                        117 non-null    category
#  16  English Requirement in Job Ad                      117 non-null    category
#  17  Dutch Requirement in Job Ad_No                     117 non-null    int64
#  18  Dutch Requirement in Job Ad_Yes                    117 non-null    int64
#  19  English Requirement in Job Ad_No                   117 non-null    int64
#  20  English Requirement in Job Ad_Yes                  117 non-null    int64
#  21  Sector Code                                        117 non-null    object
#  22  Sector                                             117 non-null    object
#  23  Keywords Count                                     117 non-null    float64
#  24  Gender_Female_n                                    117 non-null    float64
#  25  Gender_Female_% per Sector                         117 non-null    float64
#  26  Gender_Female_% per Social Category                117 non-null    float64
#  27  Gender_Female_% per Workforce                      117 non-null    float64
#  28  Gender_Male_n                                      117 non-null    float64
#  29  Gender_Male_% per Sector                           117 non-null    float64
#  30  Gender_Male_% per Social Category                  117 non-null    float64
#  31  Gender_Male_% per Workforce                        117 non-null    float64
#  32  Gender                                             117 non-null    category
#  33  Age_Older_n                                        117 non-null    float64
#  34  Age_Older_% per Sector                             117 non-null    float64
#  35  Age_Older_% per Social Category                    117 non-null    float64
#  36  Age_Older_% per Workforce                          117 non-null    float64
#  37  Age_Younger_n                                      117 non-null    float64
#  38  Age_Younger_% per Sector                           117 non-null    float64
#  39  Age_Younger_% per Social Category                  117 non-null    float64
#  40  Age_Younger_% per Workforce                        117 non-null    float64
#  41  Age                                                117 non-null    category
#  42  Sector_n                                           117 non-null    float64
#  43  % Sector per Workforce                             117 non-null    float64
#  44  Sector Job Advertisement Count                     117 non-null    int64
#  45  Sector Gender Designation Job Advertisement Count  117 non-null    int64
#  46  Sector Age Designation Job Advertisement Count     117 non-null    int64
#  47  Gender_Female                                      117 non-null    int64
#  48  Gender_Male                                        117 non-null    int64
#  49  Gender_Mixed                                       117 non-null    int64
#  50  Age_Mixed                                          117 non-null    int64
#  51  Age_Older                                          117 non-null    int64
#  52  Age_Younger                                        117 non-null    int64
#  53  Gender_Num                                         117 non-null    int64
#  54  Age_Num                                            117 non-null    int64
#  55  Interaction_Female_Older_% per Sector              117 non-null    float64
#  56  Interaction_Female_Younger_% per Sector            117 non-null    float64
#  57  Interaction_Male_Older_% per Sector                117 non-null    float64
#  58  Interaction_Male_Younger_% per Sector              117 non-null    float64
#  59  Platform_Num                                       117 non-null    int64
#  60  Platform_LinkedIn                                  117 non-null    int64
#  61  Platform_Indeed                                    117 non-null    int64
#  62  Platform_Glassdoor                                 117 non-null    int64
# dtypes: category(7), float64(23), int64(25), object(8)
# memory usage: 53.0+ KB
# ====================
# Gender:
# --------------------
# Gender Counts:
# Gender
# Mixed Gender    72
# Male            27
# Female          18
# Name: count, dtype: int64
# --------------------
# Gender Percentages:
# Gender
# Mixed Gender   61.500
# Male           23.100
# Female         15.400
# Name: proportion, dtype: float64
# --------------------
# Gender not available.
# ====================
# Gender_Num:
# --------------------
# Gender_Num Counts:
# Gender_Num
# 1    72
# 2    27
# 0    18
# Name: count, dtype: int64
# --------------------
# Gender_Num Percentages:
# Gender_Num
# 1   61.500
# 2   23.100
# 0   15.400
# Name: proportion, dtype: float64
# --------------------
# Min Gender_Num value: 0.0
# Max Gender_Num value: 2.0
# --------------------
# Gender_Num Mean: 1.077
# --------------------
# Gender_Num Standard Deviation: 0.618
# ====================
# Gender_Female:
# --------------------
# Gender_Female Counts:
# Gender_Female
# 0    99
# 1    18
# Name: count, dtype: int64
# --------------------
# Gender_Female Percentages:
# Gender_Female
# 0   84.600
# 1   15.400
# Name: proportion, dtype: float64
# --------------------
# Min Gender_Female value: 0.0
# Max Gender_Female value: 1.0
# --------------------
# Gender_Female Mean: 0.154
# --------------------
# Gender_Female Standard Deviation: 0.362
# ====================
# Gender_Mixed:
# --------------------
# Gender_Mixed Counts:
# Gender_Mixed
# 1    72
# 0    45
# Name: count, dtype: int64
# --------------------
# Gender_Mixed Percentages:
# Gender_Mixed
# 1   61.500
# 0   38.500
# Name: proportion, dtype: float64
# --------------------
# Min Gender_Mixed value: 0.0
# Max Gender_Mixed value: 1.0
# --------------------
# Gender_Mixed Mean: 0.615
# --------------------
# Gender_Mixed Standard Deviation: 0.489
# ====================
# Gender_Male:
# --------------------
# Gender_Male Counts:
# Gender_Male
# 0    90
# 1    27
# Name: count, dtype: int64
# --------------------
# Gender_Male Percentages:
# Gender_Male
# 0   76.900
# 1   23.100
# Name: proportion, dtype: float64
# --------------------
# Min Gender_Male value: 0.0
# Max Gender_Male value: 1.0
# --------------------
# Gender_Male Mean: 0.231
# --------------------
# Gender_Male Standard Deviation: 0.423
# ====================
# Gender_Female_n:
# --------------------
# Min Gender_Female_n value: 7.0
# Max Gender_Female_n value: 3970.0
# --------------------
# Gender_Female_n Mean: 555.513
# --------------------
# Gender_Female_n Standard Deviation: 785.266
# ====================
# Gender_Male_n:
# --------------------
# Min Gender_Male_n value: 21.0
# Max Gender_Male_n value: 4510.0
# --------------------
# Gender_Male_n Mean: 586.632
# --------------------
# Gender_Male_n Standard Deviation: 728.089
# ====================
# Gender_Female_% per Sector:
# --------------------
# Min Gender_Female_% per Sector value: 19.444
# Max Gender_Female_% per Sector value: 84.299
# --------------------
# Gender_Female_% per Sector Mean: 44.39
# --------------------
# Gender_Female_% per Sector Standard Deviation: 16.167
# ====================
# Gender_Male_% per Sector:
# --------------------
# Min Gender_Male_% per Sector value: 15.632
# Max Gender_Male_% per Sector value: 80.556
# --------------------
# Gender_Male_% per Sector Mean: 55.588
# --------------------
# Gender_Male_% per Sector Standard Deviation: 16.192
# ====================
# Age:
# --------------------
# Age Counts:
# Age
# Younger      60
# Mixed Age    42
# Older        15
# Name: count, dtype: int64
# --------------------
# Age Percentages:
# Age
# Younger     51.300
# Mixed Age   35.900
# Older       12.800
# Name: proportion, dtype: float64
# --------------------
# Age not available.
# ====================
# Age_Num:
# --------------------
# Age_Num Counts:
# Age_Num
# 2    60
# 1    42
# 0    15
# Name: count, dtype: int64
# --------------------
# Age_Num Percentages:
# Age_Num
# 2   51.300
# 1   35.900
# 0   12.800
# Name: proportion, dtype: float64
# --------------------
# Min Age_Num value: 0.0
# Max Age_Num value: 2.0
# --------------------
# Age_Num Mean: 1.385
# --------------------
# Age_Num Standard Deviation: 0.705
# ====================
# Age_Older:
# --------------------
# Age_Older Counts:
# Age_Older
# 0    102
# 1     15
# Name: count, dtype: int64
# --------------------
# Age_Older Percentages:
# Age_Older
# 0   87.200
# 1   12.800
# Name: proportion, dtype: float64
# --------------------
# Min Age_Older value: 0.0
# Max Age_Older value: 1.0
# --------------------
# Age_Older Mean: 0.128
# --------------------
# Age_Older Standard Deviation: 0.336
# ====================
# Age_Mixed:
# --------------------
# Age_Mixed Counts:
# Age_Mixed
# 0    75
# 1    42
# Name: count, dtype: int64
# --------------------
# Age_Mixed Percentages:
# Age_Mixed
# 0   64.100
# 1   35.900
# Name: proportion, dtype: float64
# --------------------
# Min Age_Mixed value: 0.0
# Max Age_Mixed value: 1.0
# --------------------
# Age_Mixed Mean: 0.359
# --------------------
# Age_Mixed Standard Deviation: 0.482
# ====================
# Age_Younger:
# --------------------
# Age_Younger Counts:
# Age_Younger
# 1    60
# 0    57
# Name: count, dtype: int64
# --------------------
# Age_Younger Percentages:
# Age_Younger
# 1   51.300
# 0   48.700
# Name: proportion, dtype: float64
# --------------------
# Min Age_Younger value: 0.0
# Max Age_Younger value: 1.0
# --------------------
# Age_Younger Mean: 0.513
# --------------------
# Age_Younger Standard Deviation: 0.502
# ====================
# Age_Older_n:
# --------------------
# Min Age_Older_n value: 15.0
# Max Age_Older_n value: 2844.0
# --------------------
# Age_Older_n Mean: 440.051
# --------------------
# Age_Older_n Standard Deviation: 576.531
# ====================
# Age_Younger_n:
# --------------------
# Min Age_Younger_n value: 13.0
# Max Age_Younger_n value: 5228.0
# --------------------
# Age_Younger_n Mean: 700.863
# --------------------
# Age_Younger_n Standard Deviation: 868.109
# ====================
# Age_Older_% per Sector:
# --------------------
# Min Age_Older_% per Sector value: 18.939
# Max Age_Older_% per Sector value: 58.333
# --------------------
# Age_Older_% per Sector Mean: 38.676
# --------------------
# Age_Older_% per Sector Standard Deviation: 9.053
# ====================
# Age_Younger_% per Sector:
# --------------------
# Min Age_Younger_% per Sector value: 44.444
# Max Age_Younger_% per Sector value: 80.808
# --------------------
# Age_Younger_% per Sector Mean: 61.047
# --------------------
# Age_Younger_% per Sector Standard Deviation: 9.179
# ====================
# Interaction_Female_Older_% per Sector:
# --------------------
# Min Interaction_Female_Older_% per Sector value: 903.686
# Max Interaction_Female_Older_% per Sector value: 3888.445
# --------------------
# Interaction_Female_Older_% per Sector Mean: 1711.385
# --------------------
# Interaction_Female_Older_% per Sector Standard Deviation: 829.445
# ====================
# Interaction_Female_Younger_% per Sector:
# --------------------
# Min Interaction_Female_Younger_% per Sector value: 864.198
# Max Interaction_Female_Younger_% per Sector value: 4529.657
# --------------------
# Interaction_Female_Younger_% per Sector Mean: 2716.419
# --------------------
# Interaction_Female_Younger_% per Sector Standard Deviation: 944.027
# ====================
# Interaction_Male_Older_% per Sector:
# --------------------
# Min Interaction_Male_Older_% per Sector value: 721.036
# Max Interaction_Male_Older_% per Sector value: 4699.074
# --------------------
# Interaction_Male_Older_% per Sector Mean: 2155.349
# --------------------
# Interaction_Male_Older_% per Sector Standard Deviation: 956.961
# ====================
# Interaction_Male_Younger_% per Sector:
# --------------------
# Min Interaction_Male_Younger_% per Sector value: 839.936
# Max Interaction_Male_Younger_% per Sector value: 4869.203
# --------------------
# Interaction_Male_Younger_% per Sector Mean: 3386.861
# --------------------
# Interaction_Male_Younger_% per Sector Standard Deviation: 1003.506

# %%
# Manual Job Sentence info
get_df_info(df_manual, ivs_all=ivs_all)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5955 entries, 0 to 5954
# Data columns (total 64 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Job ID                                             5955 non-null   object
#  1   Job Description spacy_sentencized                  5955 non-null   object
#  2   Warmth                                             5955 non-null   int64
#  3   Competence                                         5955 non-null   int64
#  4   Dutch Requirement in Sentence                      5955 non-null   category
#  5   English Requirement in Sentence                    5955 non-null   category
#  6   Dutch Requirement in Sentence_No                   5955 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                  5955 non-null   int64
#  8   English Requirement in Sentence_No                 5955 non-null   int64
#  9   English Requirement in Sentence_Yes                5955 non-null   int64
#  10  Search Keyword                                     5955 non-null   object
#  11  Platform                                           5955 non-null   category
#  12  Job Title                                          5955 non-null   object
#  13  Company Name                                       5955 non-null   object
#  14  Location                                           5955 non-null   object
#  15  Industry                                           290 non-null    object
#  16  Dutch Requirement in Job Ad                        5955 non-null   category
#  17  English Requirement in Job Ad                      5955 non-null   category
#  18  Dutch Requirement in Job Ad_No                     5955 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                    5955 non-null   int64
#  20  English Requirement in Job Ad_No                   5955 non-null   int64
#  21  English Requirement in Job Ad_Yes                  5955 non-null   int64
#  22  Sector Code                                        5955 non-null   object
#  23  Sector                                             5955 non-null   object
#  24  Keywords Count                                     5955 non-null   float64
#  25  Gender_Female_n                                    5955 non-null   float64
#  26  Gender_Female_% per Sector                         5955 non-null   float64
#  27  Gender_Female_% per Social Category                5955 non-null   float64
#  28  Gender_Female_% per Workforce                      5955 non-null   float64
#  29  Gender_Male_n                                      5955 non-null   float64
#  30  Gender_Male_% per Sector                           5955 non-null   float64
#  31  Gender_Male_% per Social Category                  5955 non-null   float64
#  32  Gender_Male_% per Workforce                        5955 non-null   float64
#  33  Gender                                             5955 non-null   category
#  34  Age_Older_n                                        5955 non-null   float64
#  35  Age_Older_% per Sector                             5955 non-null   float64
#  36  Age_Older_% per Social Category                    5955 non-null   float64
#  37  Age_Older_% per Workforce                          5955 non-null   float64
#  38  Age_Younger_n                                      5955 non-null   float64
#  39  Age_Younger_% per Sector                           5955 non-null   float64
#  40  Age_Younger_% per Social Category                  5955 non-null   float64
#  41  Age_Younger_% per Workforce                        5955 non-null   float64
#  42  Age                                                5955 non-null   category
#  43  Sector_n                                           5955 non-null   float64
#  44  % Sector per Workforce                             5955 non-null   float64
#  45  Sector Job Advertisement Count                     5955 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count  5955 non-null   int64
#  47  Sector Age Designation Job Advertisement Count     5955 non-null   int64
#  48  Gender_Female                                      5955 non-null   int64
#  49  Gender_Male                                        5955 non-null   int64
#  50  Gender_Mixed                                       5955 non-null   int64
#  51  Age_Mixed                                          5955 non-null   int64
#  52  Age_Older                                          5955 non-null   int64
#  53  Age_Younger                                        5955 non-null   int64
#  54  Gender_Num                                         5955 non-null   int64
#  55  Age_Num                                            5955 non-null   int64
#  56  Interaction_Female_Older_% per Sector              5955 non-null   float64
#  57  Interaction_Female_Younger_% per Sector            5955 non-null   float64
#  58  Interaction_Male_Older_% per Sector                5955 non-null   float64
#  59  Interaction_Male_Younger_% per Sector              5955 non-null   float64
#  60  Platform_Num                                       5955 non-null   int64
#  61  Platform_LinkedIn                                  5955 non-null   int64
#  62  Platform_Indeed                                    5955 non-null   int64
#  63  Platform_Glassdoor                                 5955 non-null   int64
# dtypes: category(7), float64(23), int64(25), object(9)
# memory usage: 2.6+ MB
# ====================
# Gender:
# --------------------
# Gender Counts:
# Gender
# Mixed Gender    3841
# Male            1152
# Female           962
# Name: count, dtype: int64
# --------------------
# Gender Percentages:
# Gender
# Mixed Gender   64.500
# Male           19.300
# Female         16.200
# Name: proportion, dtype: float64
# --------------------
# Gender not available.
# ====================
# Gender_Num:
# --------------------
# Gender_Num Counts:
# Gender_Num
# 1    3841
# 2    1152
# 0     962
# Name: count, dtype: int64
# --------------------
# Gender_Num Percentages:
# Gender_Num
# 1   64.500
# 2   19.300
# 0   16.200
# Name: proportion, dtype: float64
# --------------------
# Min Gender_Num value: 0.0
# Max Gender_Num value: 2.0
# --------------------
# Gender_Num Mean: 1.032
# --------------------
# Gender_Num Standard Deviation: 0.595
# ====================
# Gender_Female:
# --------------------
# Gender_Female Counts:
# Gender_Female
# 0    4993
# 1     962
# Name: count, dtype: int64
# --------------------
# Gender_Female Percentages:
# Gender_Female
# 0   83.800
# 1   16.200
# Name: proportion, dtype: float64
# --------------------
# Min Gender_Female value: 0.0
# Max Gender_Female value: 1.0
# --------------------
# Gender_Female Mean: 0.162
# --------------------
# Gender_Female Standard Deviation: 0.368
# ====================
# Gender_Mixed:
# --------------------
# Gender_Mixed Counts:
# Gender_Mixed
# 1    3841
# 0    2114
# Name: count, dtype: int64
# --------------------
# Gender_Mixed Percentages:
# Gender_Mixed
# 1   64.500
# 0   35.500
# Name: proportion, dtype: float64
# --------------------
# Min Gender_Mixed value: 0.0
# Max Gender_Mixed value: 1.0
# --------------------
# Gender_Mixed Mean: 0.645
# --------------------
# Gender_Mixed Standard Deviation: 0.479
# ====================
# Gender_Male:
# --------------------
# Gender_Male Counts:
# Gender_Male
# 0    4803
# 1    1152
# Name: count, dtype: int64
# --------------------
# Gender_Male Percentages:
# Gender_Male
# 0   80.700
# 1   19.300
# Name: proportion, dtype: float64
# --------------------
# Min Gender_Male value: 0.0
# Max Gender_Male value: 1.0
# --------------------
# Gender_Male Mean: 0.193
# --------------------
# Gender_Male Standard Deviation: 0.395
# ====================
# Gender_Female_n:
# --------------------
# Min Gender_Female_n value: 7.0
# Max Gender_Female_n value: 3970.0
# --------------------
# Gender_Female_n Mean: 550.622
# --------------------
# Gender_Female_n Standard Deviation: 748.204
# ====================
# Gender_Male_n:
# --------------------
# Min Gender_Male_n value: 21.0
# Max Gender_Male_n value: 4510.0
# --------------------
# Gender_Male_n Mean: 579.467
# --------------------
# Gender_Male_n Standard Deviation: 685.825
# ====================
# Gender_Female_% per Sector:
# --------------------
# Min Gender_Female_% per Sector value: 19.444
# Max Gender_Female_% per Sector value: 84.299
# --------------------
# Gender_Female_% per Sector Mean: 45.148
# --------------------
# Gender_Female_% per Sector Standard Deviation: 15.88
# ====================
# Gender_Male_% per Sector:
# --------------------
# Min Gender_Male_% per Sector value: 15.632
# Max Gender_Male_% per Sector value: 80.556
# --------------------
# Gender_Male_% per Sector Mean: 54.831
# --------------------
# Gender_Male_% per Sector Standard Deviation: 15.904
# ====================
# Age:
# --------------------
# Age Counts:
# Age
# Younger      3226
# Mixed Age    2048
# Older         681
# Name: count, dtype: int64
# --------------------
# Age Percentages:
# Age
# Younger     54.200
# Mixed Age   34.400
# Older       11.400
# Name: proportion, dtype: float64
# --------------------
# Age not available.
# ====================
# Age_Num:
# --------------------
# Age_Num Counts:
# Age_Num
# 2    3226
# 1    2048
# 0     681
# Name: count, dtype: int64
# --------------------
# Age_Num Percentages:
# Age_Num
# 2   54.200
# 1   34.400
# 0   11.400
# Name: proportion, dtype: float64
# --------------------
# Min Age_Num value: 0.0
# Max Age_Num value: 2.0
# --------------------
# Age_Num Mean: 1.427
# --------------------
# Age_Num Standard Deviation: 0.688
# ====================
# Age_Older:
# --------------------
# Age_Older Counts:
# Age_Older
# 0    5274
# 1     681
# Name: count, dtype: int64
# --------------------
# Age_Older Percentages:
# Age_Older
# 0   88.600
# 1   11.400
# Name: proportion, dtype: float64
# --------------------
# Min Age_Older value: 0.0
# Max Age_Older value: 1.0
# --------------------
# Age_Older Mean: 0.114
# --------------------
# Age_Older Standard Deviation: 0.318
# ====================
# Age_Mixed:
# --------------------
# Age_Mixed Counts:
# Age_Mixed
# 0    3907
# 1    2048
# Name: count, dtype: int64
# --------------------
# Age_Mixed Percentages:
# Age_Mixed
# 0   65.600
# 1   34.400
# Name: proportion, dtype: float64
# --------------------
# Min Age_Mixed value: 0.0
# Max Age_Mixed value: 1.0
# --------------------
# Age_Mixed Mean: 0.344
# --------------------
# Age_Mixed Standard Deviation: 0.475
# ====================
# Age_Younger:
# --------------------
# Age_Younger Counts:
# Age_Younger
# 1    3226
# 0    2729
# Name: count, dtype: int64
# --------------------
# Age_Younger Percentages:
# Age_Younger
# 1   54.200
# 0   45.800
# Name: proportion, dtype: float64
# --------------------
# Min Age_Younger value: 0.0
# Max Age_Younger value: 1.0
# --------------------
# Age_Younger Mean: 0.542
# --------------------
# Age_Younger Standard Deviation: 0.498
# ====================
# Age_Older_n:
# --------------------
# Min Age_Older_n value: 15.0
# Max Age_Older_n value: 2844.0
# --------------------
# Age_Older_n Mean: 433.039
# --------------------
# Age_Older_n Standard Deviation: 549.041
# ====================
# Age_Younger_n:
# --------------------
# Min Age_Younger_n value: 13.0
# Max Age_Younger_n value: 5228.0
# --------------------
# Age_Younger_n Mean: 695.75
# --------------------
# Age_Younger_n Standard Deviation: 814.093
# ====================
# Age_Older_% per Sector:
# --------------------
# Min Age_Older_% per Sector value: 18.939
# Max Age_Older_% per Sector value: 58.333
# --------------------
# Age_Older_% per Sector Mean: 38.12
# --------------------
# Age_Older_% per Sector Standard Deviation: 8.739
# ====================
# Age_Younger_% per Sector:
# --------------------
# Min Age_Younger_% per Sector value: 44.444
# Max Age_Younger_% per Sector value: 80.808
# --------------------
# Age_Younger_% per Sector Mean: 61.626
# --------------------
# Age_Younger_% per Sector Standard Deviation: 8.819
# ====================
# Interaction_Female_Older_% per Sector:
# --------------------
# Min Interaction_Female_Older_% per Sector value: 903.686
# Max Interaction_Female_Older_% per Sector value: 3888.445
# --------------------
# Interaction_Female_Older_% per Sector Mean: 1726.654
# --------------------
# Interaction_Female_Older_% per Sector Standard Deviation: 834.455
# ====================
# Interaction_Female_Younger_% per Sector:
# --------------------
# Min Interaction_Female_Younger_% per Sector value: 864.198
# Max Interaction_Female_Younger_% per Sector value: 4529.657
# --------------------
# Interaction_Female_Younger_% per Sector Mean: 2777.047
# --------------------
# Interaction_Female_Younger_% per Sector Standard Deviation: 901.964
# ====================
# Interaction_Male_Older_% per Sector:
# --------------------
# Min Interaction_Male_Older_% per Sector value: 721.036
# Max Interaction_Male_Older_% per Sector value: 4699.074
# --------------------
# Interaction_Male_Older_% per Sector Mean: 2084.604
# --------------------
# Interaction_Male_Older_% per Sector Standard Deviation: 896.827
# ====================
# Interaction_Male_Younger_% per Sector:
# --------------------
# Min Interaction_Male_Younger_% per Sector value: 839.936
# Max Interaction_Male_Younger_% per Sector value: 4869.203
# --------------------
# Interaction_Male_Younger_% per Sector Mean: 3384.194
# --------------------
# Interaction_Male_Younger_% per Sector Standard Deviation: 1017.652

# %%
get_df_info(df_manual, ivs_all=ivs_perc_interactions)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5955 entries, 0 to 5954
# Data columns (total 64 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Job ID                                             5955 non-null   object
#  1   Job Description spacy_sentencized                  5955 non-null   object
#  2   Warmth                                             5955 non-null   int64
#  3   Competence                                         5955 non-null   int64
#  4   Dutch Requirement in Sentence                      5955 non-null   category
#  5   English Requirement in Sentence                    5955 non-null   category
#  6   Dutch Requirement in Sentence_No                   5955 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                  5955 non-null   int64
#  8   English Requirement in Sentence_No                 5955 non-null   int64
#  9   English Requirement in Sentence_Yes                5955 non-null   int64
#  10  Search Keyword                                     5955 non-null   object
#  11  Platform                                           5955 non-null   category
#  12  Job Title                                          5955 non-null   object
#  13  Company Name                                       5955 non-null   object
#  14  Location                                           5955 non-null   object
#  15  Industry                                           290 non-null    object
#  16  Dutch Requirement in Job Ad                        5955 non-null   category
#  17  English Requirement in Job Ad                      5955 non-null   category
#  18  Dutch Requirement in Job Ad_No                     5955 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                    5955 non-null   int64
#  20  English Requirement in Job Ad_No                   5955 non-null   int64
#  21  English Requirement in Job Ad_Yes                  5955 non-null   int64
#  22  Sector Code                                        5955 non-null   object
#  23  Sector                                             5955 non-null   object
#  24  Keywords Count                                     5955 non-null   float64
#  25  Gender_Female_n                                    5955 non-null   float64
#  26  Gender_Female_% per Sector                         5955 non-null   float64
#  27  Gender_Female_% per Social Category                5955 non-null   float64
#  28  Gender_Female_% per Workforce                      5955 non-null   float64
#  29  Gender_Male_n                                      5955 non-null   float64
#  30  Gender_Male_% per Sector                           5955 non-null   float64
#  31  Gender_Male_% per Social Category                  5955 non-null   float64
#  32  Gender_Male_% per Workforce                        5955 non-null   float64
#  33  Gender                                             5955 non-null   category
#  34  Age_Older_n                                        5955 non-null   float64
#  35  Age_Older_% per Sector                             5955 non-null   float64
#  36  Age_Older_% per Social Category                    5955 non-null   float64
#  37  Age_Older_% per Workforce                          5955 non-null   float64
#  38  Age_Younger_n                                      5955 non-null   float64
#  39  Age_Younger_% per Sector                           5955 non-null   float64
#  40  Age_Younger_% per Social Category                  5955 non-null   float64
#  41  Age_Younger_% per Workforce                        5955 non-null   float64
#  42  Age                                                5955 non-null   category
#  43  Sector_n                                           5955 non-null   float64
#  44  % Sector per Workforce                             5955 non-null   float64
#  45  Sector Job Advertisement Count                     5955 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count  5955 non-null   int64
#  47  Sector Age Designation Job Advertisement Count     5955 non-null   int64
#  48  Gender_Female                                      5955 non-null   int64
#  49  Gender_Male                                        5955 non-null   int64
#  50  Gender_Mixed                                       5955 non-null   int64
#  51  Age_Mixed                                          5955 non-null   int64
#  52  Age_Older                                          5955 non-null   int64
#  53  Age_Younger                                        5955 non-null   int64
#  54  Gender_Num                                         5955 non-null   int64
#  55  Age_Num                                            5955 non-null   int64
#  56  Interaction_Female_Older_% per Sector              5955 non-null   float64
#  57  Interaction_Female_Younger_% per Sector            5955 non-null   float64
#  58  Interaction_Male_Older_% per Sector                5955 non-null   float64
#  59  Interaction_Male_Younger_% per Sector              5955 non-null   float64
#  60  Platform_Num                                       5955 non-null   int64
#  61  Platform_LinkedIn                                  5955 non-null   int64
#  62  Platform_Indeed                                    5955 non-null   int64
#  63  Platform_Glassdoor                                 5955 non-null   int64
# dtypes: category(7), float64(23), int64(25), object(9)
# memory usage: 2.6+ MB
# ====================
# Interaction_Female_Older_% per Sector:
# --------------------
# Min Interaction_Female_Older_% per Sector value: 903.686
# Max Interaction_Female_Older_% per Sector value: 3888.445
# --------------------
# Interaction_Female_Older_% per Sector Mean: 1726.654
# --------------------
# Interaction_Female_Older_% per Sector Standard Deviation: 834.455
# ====================
# Interaction_Female_Younger_% per Sector:
# --------------------
# Min Interaction_Female_Younger_% per Sector value: 864.198
# Max Interaction_Female_Younger_% per Sector value: 4529.657
# --------------------
# Interaction_Female_Younger_% per Sector Mean: 2777.047
# --------------------
# Interaction_Female_Younger_% per Sector Standard Deviation: 901.964
# ====================
# Interaction_Male_Older_% per Sector:
# --------------------
# Min Interaction_Male_Older_% per Sector value: 721.036
# Max Interaction_Male_Older_% per Sector value: 4699.074
# --------------------
# Interaction_Male_Older_% per Sector Mean: 2084.604
# --------------------
# Interaction_Male_Older_% per Sector Standard Deviation: 896.827
# ====================
# Interaction_Male_Younger_% per Sector:
# --------------------
# Min Interaction_Male_Younger_% per Sector value: 839.936
# Max Interaction_Male_Younger_% per Sector value: 4869.203
# --------------------
# Interaction_Male_Younger_% per Sector Mean: 3384.194
# --------------------
# Interaction_Male_Younger_% per Sector Standard Deviation: 1017.652

# %%
# Warmth 1 = 1489 (24.90%), Competence 1 = 2667 (44.30%)
get_df_info(df_manual, ivs_all=dvs)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5955 entries, 0 to 5954
# Data columns (total 64 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Job ID                                             5955 non-null   object
#  1   Job Description spacy_sentencized                  5955 non-null   object
#  2   Warmth                                             5955 non-null   int64
#  3   Competence                                         5955 non-null   int64
#  4   Dutch Requirement in Sentence                      5955 non-null   category
#  5   English Requirement in Sentence                    5955 non-null   category
#  6   Dutch Requirement in Sentence_No                   5955 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                  5955 non-null   int64
#  8   English Requirement in Sentence_No                 5955 non-null   int64
#  9   English Requirement in Sentence_Yes                5955 non-null   int64
#  10  Search Keyword                                     5955 non-null   object
#  11  Platform                                           5955 non-null   category
#  12  Job Title                                          5955 non-null   object
#  13  Company Name                                       5955 non-null   object
#  14  Location                                           5955 non-null   object
#  15  Industry                                           290 non-null    object
#  16  Dutch Requirement in Job Ad                        5955 non-null   category
#  17  English Requirement in Job Ad                      5955 non-null   category
#  18  Dutch Requirement in Job Ad_No                     5955 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                    5955 non-null   int64
#  20  English Requirement in Job Ad_No                   5955 non-null   int64
#  21  English Requirement in Job Ad_Yes                  5955 non-null   int64
#  22  Sector Code                                        5955 non-null   object
#  23  Sector                                             5955 non-null   object
#  24  Keywords Count                                     5955 non-null   float64
#  25  Gender_Female_n                                    5955 non-null   float64
#  26  Gender_Female_% per Sector                         5955 non-null   float64
#  27  Gender_Female_% per Social Category                5955 non-null   float64
#  28  Gender_Female_% per Workforce                      5955 non-null   float64
#  29  Gender_Male_n                                      5955 non-null   float64
#  30  Gender_Male_% per Sector                           5955 non-null   float64
#  31  Gender_Male_% per Social Category                  5955 non-null   float64
#  32  Gender_Male_% per Workforce                        5955 non-null   float64
#  33  Gender                                             5955 non-null   category
#  34  Age_Older_n                                        5955 non-null   float64
#  35  Age_Older_% per Sector                             5955 non-null   float64
#  36  Age_Older_% per Social Category                    5955 non-null   float64
#  37  Age_Older_% per Workforce                          5955 non-null   float64
#  38  Age_Younger_n                                      5955 non-null   float64
#  39  Age_Younger_% per Sector                           5955 non-null   float64
#  40  Age_Younger_% per Social Category                  5955 non-null   float64
#  41  Age_Younger_% per Workforce                        5955 non-null   float64
#  42  Age                                                5955 non-null   category
#  43  Sector_n                                           5955 non-null   float64
#  44  % Sector per Workforce                             5955 non-null   float64
#  45  Sector Job Advertisement Count                     5955 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count  5955 non-null   int64
#  47  Sector Age Designation Job Advertisement Count     5955 non-null   int64
#  48  Gender_Female                                      5955 non-null   int64
#  49  Gender_Male                                        5955 non-null   int64
#  50  Gender_Mixed                                       5955 non-null   int64
#  51  Age_Mixed                                          5955 non-null   int64
#  52  Age_Older                                          5955 non-null   int64
#  53  Age_Younger                                        5955 non-null   int64
#  54  Gender_Num                                         5955 non-null   int64
#  55  Age_Num                                            5955 non-null   int64
#  56  Interaction_Female_Older_% per Sector              5955 non-null   float64
#  57  Interaction_Female_Younger_% per Sector            5955 non-null   float64
#  58  Interaction_Male_Older_% per Sector                5955 non-null   float64
#  59  Interaction_Male_Younger_% per Sector              5955 non-null   float64
#  60  Platform_Num                                       5955 non-null   int64
#  61  Platform_LinkedIn                                  5955 non-null   int64
#  62  Platform_Indeed                                    5955 non-null   int64
#  63  Platform_Glassdoor                                 5955 non-null   int64
# dtypes: category(7), float64(23), int64(25), object(9)
# memory usage: 2.6+ MB
# ====================
# Warmth:
# --------------------
# Warmth Counts:
# Warmth
# 0    4340
# 1    1615
# Name: count, dtype: int64
# --------------------
# Warmth Percentages:
# Warmth
# 0   72.900
# 1   27.100
# Name: proportion, dtype: float64
# --------------------
# Min Warmth value: 0.0
# Max Warmth value: 1.0
# --------------------
# Warmth Mean: 0.271
# --------------------
# Warmth Standard Deviation: 0.445
# ====================
# Competence:
# --------------------
# Competence Counts:
# Competence
# 0    3188
# 1    2767
# Name: count, dtype: int64
# --------------------
# Competence Percentages:
# Competence
# 0   53.500
# 1   46.500
# Name: proportion, dtype: float64
# --------------------
# Min Competence value: 0.0
# Max Competence value: 1.0
# --------------------
# Competence Mean: 0.465
# --------------------
# Competence Standard Deviation: 0.499

# %%
if df_manual['Sector'].isna().sum() == 0:
    assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
    df_manual.to_pickle(f'{df_save_dir}df_manual_including_sector_genage_data.pkl')
    df_manual.to_csv(f'{df_save_dir}df_manual_including_sector_genage_data.csv')
else:
    print(f"MISSING SECTOR DATA: COUNT {df_manual['Sector'].isna().sum()}")

# %% [markdown]
# # ATTN: This script should be run AFTER spacy sentence splitting is completed.

# %% [markdown]
# ## Use spacy to tokenize sentences

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_SENTENCIZED
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %%
import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

mod = sys.modules[__name__]

code_dir = None
code_dir_name = 'Code'
unwanted_subdir_name = 'Analysis'

if code_dir_name not in str(Path.cwd()).split('/')[-1]:
    for _ in range(5):

        parent_path = str(Path.cwd().parents[_]).split('/')[-1]

        if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

            code_dir = str(Path.cwd().parents[_])

            if code_dir is not None:
                break
else:
    code_dir = str(Path.cwd())
sys.path.append(code_dir)

# %load_ext autoreload
# %autoreload 2

# %%
from setup_module.imports import * # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# %%
def get_word_num_and_frequency(row, text_col):

    with open(f'{data_dir}punctuations.txt', 'rb') as f:
        custom_punct_chars = pickle.load(f)
    row[f'{text_col}_num_words'] = len(str(row[text_col]).split())
    row[f'{text_col}_num_unique_words'] = len(set(str(row[text_col]).split()))
    row[f'{text_col}_num_chars'] = len(str(row[text_col]))
    row[f'{text_col}_num_chars_no_whitespact_and_punt'] = len(
        [
            c
            for c in str(row[text_col])
            if c not in custom_punct_chars and c not in list(string.punctuation) and c in list(string.printable) and c not in list(string.whitespace) and c != ' '
        ]
    )
    row[f'{text_col}_num_punctuations'] = len(
        [
            c
            for c in str(row[text_col])
            if c in custom_punct_chars and c in list(string.punctuation) and c in list(string.printable) and c not in list(string.whitespace) and c != ' '
        ]
    )

    return row

# %%
df_manual = pd.read_pickle(f'{df_save_dir}df_manual_including_sector_genage_data.pkl')

# %%
df_manual['Job Description spacy_sentencized'] = df_manual['Job Description spacy_sentencized'].progress_apply(lambda x: unicodedata.normalize('NFKD', x.encode('ascii', 'ignore').decode('utf-8', 'ignore')))
df_manual = df_manual.reset_index(drop=True)
# Out:
# progress-bar:   0%|          | 0/5955 [00:00<?, ?it/s]

# %%
# Warmth 1 = 1489 (24.90%), Competence 1 = 2667 (44.30%)
get_df_info(df_manual, ivs_all=dvs)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5955 entries, 0 to 5954
# Data columns (total 64 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Job ID                                             5955 non-null   object
#  1   Job Description spacy_sentencized                  5955 non-null   object
#  2   Warmth                                             5955 non-null   int64
#  3   Competence                                         5955 non-null   int64
#  4   Dutch Requirement in Sentence                      5955 non-null   category
#  5   English Requirement in Sentence                    5955 non-null   category
#  6   Dutch Requirement in Sentence_No                   5955 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                  5955 non-null   int64
#  8   English Requirement in Sentence_No                 5955 non-null   int64
#  9   English Requirement in Sentence_Yes                5955 non-null   int64
#  10  Search Keyword                                     5955 non-null   object
#  11  Platform                                           5955 non-null   category
#  12  Job Title                                          5955 non-null   object
#  13  Company Name                                       5955 non-null   object
#  14  Location                                           5955 non-null   object
#  15  Industry                                           290 non-null    object
#  16  Dutch Requirement in Job Ad                        5955 non-null   category
#  17  English Requirement in Job Ad                      5955 non-null   category
#  18  Dutch Requirement in Job Ad_No                     5955 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                    5955 non-null   int64
#  20  English Requirement in Job Ad_No                   5955 non-null   int64
#  21  English Requirement in Job Ad_Yes                  5955 non-null   int64
#  22  Sector Code                                        5955 non-null   object
#  23  Sector                                             5955 non-null   object
#  24  Keywords Count                                     5955 non-null   float64
#  25  Gender_Female_n                                    5955 non-null   float64
#  26  Gender_Female_% per Sector                         5955 non-null   float64
#  27  Gender_Female_% per Social Category                5955 non-null   float64
#  28  Gender_Female_% per Workforce                      5955 non-null   float64
#  29  Gender_Male_n                                      5955 non-null   float64
#  30  Gender_Male_% per Sector                           5955 non-null   float64
#  31  Gender_Male_% per Social Category                  5955 non-null   float64
#  32  Gender_Male_% per Workforce                        5955 non-null   float64
#  33  Gender                                             5955 non-null   category
#  34  Age_Older_n                                        5955 non-null   float64
#  35  Age_Older_% per Sector                             5955 non-null   float64
#  36  Age_Older_% per Social Category                    5955 non-null   float64
#  37  Age_Older_% per Workforce                          5955 non-null   float64
#  38  Age_Younger_n                                      5955 non-null   float64
#  39  Age_Younger_% per Sector                           5955 non-null   float64
#  40  Age_Younger_% per Social Category                  5955 non-null   float64
#  41  Age_Younger_% per Workforce                        5955 non-null   float64
#  42  Age                                                5955 non-null   category
#  43  Sector_n                                           5955 non-null   float64
#  44  % Sector per Workforce                             5955 non-null   float64
#  45  Sector Job Advertisement Count                     5955 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count  5955 non-null   int64
#  47  Sector Age Designation Job Advertisement Count     5955 non-null   int64
#  48  Gender_Female                                      5955 non-null   int64
#  49  Gender_Male                                        5955 non-null   int64
#  50  Gender_Mixed                                       5955 non-null   int64
#  51  Age_Mixed                                          5955 non-null   int64
#  52  Age_Older                                          5955 non-null   int64
#  53  Age_Younger                                        5955 non-null   int64
#  54  Gender_Num                                         5955 non-null   int64
#  55  Age_Num                                            5955 non-null   int64
#  56  Interaction_Female_Older_% per Sector              5955 non-null   float64
#  57  Interaction_Female_Younger_% per Sector            5955 non-null   float64
#  58  Interaction_Male_Older_% per Sector                5955 non-null   float64
#  59  Interaction_Male_Younger_% per Sector              5955 non-null   float64
#  60  Platform_Num                                       5955 non-null   int64
#  61  Platform_LinkedIn                                  5955 non-null   int64
#  62  Platform_Indeed                                    5955 non-null   int64
#  63  Platform_Glassdoor                                 5955 non-null   int64
# dtypes: category(7), float64(23), int64(25), object(9)
# memory usage: 2.6+ MB
# ====================
# Warmth:
# --------------------
# Warmth Counts:
# Warmth
# 0    4340
# 1    1615
# Name: count, dtype: int64
# --------------------
# Warmth Percentages:
# Warmth
# 0   72.900
# 1   27.100
# Name: proportion, dtype: float64
# --------------------
# Min Warmth value: 0.0
# Max Warmth value: 1.0
# --------------------
# Warmth Mean: 0.271
# --------------------
# Warmth Standard Deviation: 0.445
# ====================
# Competence:
# --------------------
# Competence Counts:
# Competence
# 0    3188
# 1    2767
# Name: count, dtype: int64
# --------------------
# Competence Percentages:
# Competence
# 0   53.500
# 1   46.500
# Name: proportion, dtype: float64
# --------------------
# Min Competence value: 0.0
# Max Competence value: 1.0
# --------------------
# Competence Mean: 0.465
# --------------------
# Competence Standard Deviation: 0.499

# %%
df_manual['Job Description spacy_sentencized_lower'] = df_manual['Job Description spacy_sentencized'].progress_apply(
    lambda job_sentence: job_sentence.strip().lower()
)
# Out:
# progress-bar:   0%|          | 0/5955 [00:00<?, ?it/s]

# %%
df_manual[['Job Description spacy_sentencized', 'Job Description spacy_sentencized_lower']].head()
# Out:
#           Job Description spacy_sentencized               Job Description spacy_sentencized_lower
# 0  Through daily contact, as a partner of sales a...  through daily contact, as a partner of sales a...
# 1               This role is truly cross functional.               this role is truly cross functional.
# 2  The other part of your time would be spent as ...  the other part of your time would be spent as ...
# 3  Being the expert on your product also means yo...  being the expert on your product also means yo...
# 4  Your mindset is commercial, result oriented an...  your mindset is commercial, result oriented an...

# %%
df_manual[['Job Description spacy_sentencized', 'Job Description spacy_sentencized_lower']].describe()
# Out:
#        Job Description spacy_sentencized Job Description spacy_sentencized_lower
# count                       5955                                 5955
# unique                      5117                                 5090
# top              Job Description                      job description
# freq                          12                                   17

# %%
# %%time
# Spacy tokenize
with open(f'{data_dir}punctuations.txt', 'rb') as f:
    custom_punct_chars = pickle.load(f)

df_manual['Job Description spacy_tokenized'] = df_manual[
    'Job Description spacy_sentencized'
].progress_apply(
    lambda job_sentence: [
        str(token.text.strip().lower())
        for token in nlp.tokenizer(job_sentence)
        if token.text is not None
        and len(token) != 0
        and len(token.text) != 0
        and bool(token)
        and bool(token.text)
        and token.text != '...'
        and not token.is_space
        and not token.is_punct
        and not token.is_quote
        and not token.is_bracket
        and not token.like_email
    ]
)

assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
df_manual.to_pickle(f'{df_save_dir}df_manual_tokenized_spacy.pkl')
df_manual.to_csv(f'{df_save_dir}df_manual_tokenized_spacy.csv')
# Out:
# progress-bar:   0%|          | 0/5955 [00:00<?, ?it/s]
# CPU times: user 661 ms, sys: 37.2 ms, total: 698 ms
# Wall time: 1.34 s

# %%
df_manual[['Job Description spacy_sentencized', 'Job Description spacy_tokenized']].head()
# Out:
#           Job Description spacy_sentencized                   Job Description spacy_tokenized
# 0  Through daily contact, as a partner of sales a...  [through, daily, contact, as, a, partner, of, ...
# 1               This role is truly cross functional.         [this, role, is, truly, cross, functional]
# 2  The other part of your time would be spent as ...  [the, other, part, of, your, time, would, be, ...
# 3  Being the expert on your product also means yo...  [being, the, expert, on, your, product, also, ...
# 4  Your mindset is commercial, result oriented an...  [your, mindset, is, commercial, result, orient...

# %%
df_manual[['Job Description spacy_sentencized', 'Job Description spacy_tokenized']].describe()
# Out:
#        Job Description spacy_sentencized Job Description spacy_tokenized
# count                       5955                              5955
# unique                      5117                              5031
# top              Job Description                [job, description]
# freq                          12                                19

# %%
# These are all emails
df_manual = df_manual.loc[df_manual['Job Description spacy_tokenized'].progress_apply(lambda c: c!=[])]
# Out:
# progress-bar:   0%|          | 0/5955 [00:00<?, ?it/s]

# %%
# len=5948
len(df_manual)
# Out:
# 5948

# %%
df_manual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5948 entries, 0 to 5954
# Data columns (total 66 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Job ID                                             5948 non-null   object
#  1   Job Description spacy_sentencized                  5948 non-null   object
#  2   Warmth                                             5948 non-null   int64
#  3   Competence                                         5948 non-null   int64
#  4   Dutch Requirement in Sentence                      5948 non-null   category
#  5   English Requirement in Sentence                    5948 non-null   category
#  6   Dutch Requirement in Sentence_No                   5948 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                  5948 non-null   int64
#  8   English Requirement in Sentence_No                 5948 non-null   int64
#  9   English Requirement in Sentence_Yes                5948 non-null   int64
#  10  Search Keyword                                     5948 non-null   object
#  11  Platform                                           5948 non-null   category
#  12  Job Title                                          5948 non-null   object
#  13  Company Name                                       5948 non-null   object
#  14  Location                                           5948 non-null   object
#  15  Industry                                           290 non-null    object
#  16  Dutch Requirement in Job Ad                        5948 non-null   category
#  17  English Requirement in Job Ad                      5948 non-null   category
#  18  Dutch Requirement in Job Ad_No                     5948 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                    5948 non-null   int64
#  20  English Requirement in Job Ad_No                   5948 non-null   int64
#  21  English Requirement in Job Ad_Yes                  5948 non-null   int64
#  22  Sector Code                                        5948 non-null   object
#  23  Sector                                             5948 non-null   object
#  24  Keywords Count                                     5948 non-null   float64
#  25  Gender_Female_n                                    5948 non-null   float64
#  26  Gender_Female_% per Sector                         5948 non-null   float64
#  27  Gender_Female_% per Social Category                5948 non-null   float64
#  28  Gender_Female_% per Workforce                      5948 non-null   float64
#  29  Gender_Male_n                                      5948 non-null   float64
#  30  Gender_Male_% per Sector                           5948 non-null   float64
#  31  Gender_Male_% per Social Category                  5948 non-null   float64
#  32  Gender_Male_% per Workforce                        5948 non-null   float64
#  33  Gender                                             5948 non-null   category
#  34  Age_Older_n                                        5948 non-null   float64
#  35  Age_Older_% per Sector                             5948 non-null   float64
#  36  Age_Older_% per Social Category                    5948 non-null   float64
#  37  Age_Older_% per Workforce                          5948 non-null   float64
#  38  Age_Younger_n                                      5948 non-null   float64
#  39  Age_Younger_% per Sector                           5948 non-null   float64
#  40  Age_Younger_% per Social Category                  5948 non-null   float64
#  41  Age_Younger_% per Workforce                        5948 non-null   float64
#  42  Age                                                5948 non-null   category
#  43  Sector_n                                           5948 non-null   float64
#  44  % Sector per Workforce                             5948 non-null   float64
#  45  Sector Job Advertisement Count                     5948 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count  5948 non-null   int64
#  47  Sector Age Designation Job Advertisement Count     5948 non-null   int64
#  48  Gender_Female                                      5948 non-null   int64
#  49  Gender_Male                                        5948 non-null   int64
#  50  Gender_Mixed                                       5948 non-null   int64
#  51  Age_Mixed                                          5948 non-null   int64
#  52  Age_Older                                          5948 non-null   int64
#  53  Age_Younger                                        5948 non-null   int64
#  54  Gender_Num                                         5948 non-null   int64
#  55  Age_Num                                            5948 non-null   int64
#  56  Interaction_Female_Older_% per Sector              5948 non-null   float64
#  57  Interaction_Female_Younger_% per Sector            5948 non-null   float64
#  58  Interaction_Male_Older_% per Sector                5948 non-null   float64
#  59  Interaction_Male_Younger_% per Sector              5948 non-null   float64
#  60  Platform_Num                                       5948 non-null   int64
#  61  Platform_LinkedIn                                  5948 non-null   int64
#  62  Platform_Indeed                                    5948 non-null   int64
#  63  Platform_Glassdoor                                 5948 non-null   int64
#  64  Job Description spacy_sentencized_lower            5948 non-null   object
#  65  Job Description spacy_tokenized                    5948 non-null   object
# dtypes: category(7), float64(23), int64(25), object(11)
# memory usage: 2.8+ MB

# %%
get_df_info(df_manual, ivs_all=ivs_all)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 5948 entries, 0 to 5954
# Data columns (total 66 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Job ID                                             5948 non-null   object
#  1   Job Description spacy_sentencized                  5948 non-null   object
#  2   Warmth                                             5948 non-null   int64
#  3   Competence                                         5948 non-null   int64
#  4   Dutch Requirement in Sentence                      5948 non-null   category
#  5   English Requirement in Sentence                    5948 non-null   category
#  6   Dutch Requirement in Sentence_No                   5948 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                  5948 non-null   int64
#  8   English Requirement in Sentence_No                 5948 non-null   int64
#  9   English Requirement in Sentence_Yes                5948 non-null   int64
#  10  Search Keyword                                     5948 non-null   object
#  11  Platform                                           5948 non-null   category
#  12  Job Title                                          5948 non-null   object
#  13  Company Name                                       5948 non-null   object
#  14  Location                                           5948 non-null   object
#  15  Industry                                           290 non-null    object
#  16  Dutch Requirement in Job Ad                        5948 non-null   category
#  17  English Requirement in Job Ad                      5948 non-null   category
#  18  Dutch Requirement in Job Ad_No                     5948 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                    5948 non-null   int64
#  20  English Requirement in Job Ad_No                   5948 non-null   int64
#  21  English Requirement in Job Ad_Yes                  5948 non-null   int64
#  22  Sector Code                                        5948 non-null   object
#  23  Sector                                             5948 non-null   object
#  24  Keywords Count                                     5948 non-null   float64
#  25  Gender_Female_n                                    5948 non-null   float64
#  26  Gender_Female_% per Sector                         5948 non-null   float64
#  27  Gender_Female_% per Social Category                5948 non-null   float64
#  28  Gender_Female_% per Workforce                      5948 non-null   float64
#  29  Gender_Male_n                                      5948 non-null   float64
#  30  Gender_Male_% per Sector                           5948 non-null   float64
#  31  Gender_Male_% per Social Category                  5948 non-null   float64
#  32  Gender_Male_% per Workforce                        5948 non-null   float64
#  33  Gender                                             5948 non-null   category
#  34  Age_Older_n                                        5948 non-null   float64
#  35  Age_Older_% per Sector                             5948 non-null   float64
#  36  Age_Older_% per Social Category                    5948 non-null   float64
#  37  Age_Older_% per Workforce                          5948 non-null   float64
#  38  Age_Younger_n                                      5948 non-null   float64
#  39  Age_Younger_% per Sector                           5948 non-null   float64
#  40  Age_Younger_% per Social Category                  5948 non-null   float64
#  41  Age_Younger_% per Workforce                        5948 non-null   float64
#  42  Age                                                5948 non-null   category
#  43  Sector_n                                           5948 non-null   float64
#  44  % Sector per Workforce                             5948 non-null   float64
#  45  Sector Job Advertisement Count                     5948 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count  5948 non-null   int64
#  47  Sector Age Designation Job Advertisement Count     5948 non-null   int64
#  48  Gender_Female                                      5948 non-null   int64
#  49  Gender_Male                                        5948 non-null   int64
#  50  Gender_Mixed                                       5948 non-null   int64
#  51  Age_Mixed                                          5948 non-null   int64
#  52  Age_Older                                          5948 non-null   int64
#  53  Age_Younger                                        5948 non-null   int64
#  54  Gender_Num                                         5948 non-null   int64
#  55  Age_Num                                            5948 non-null   int64
#  56  Interaction_Female_Older_% per Sector              5948 non-null   float64
#  57  Interaction_Female_Younger_% per Sector            5948 non-null   float64
#  58  Interaction_Male_Older_% per Sector                5948 non-null   float64
#  59  Interaction_Male_Younger_% per Sector              5948 non-null   float64
#  60  Platform_Num                                       5948 non-null   int64
#  61  Platform_LinkedIn                                  5948 non-null   int64
#  62  Platform_Indeed                                    5948 non-null   int64
#  63  Platform_Glassdoor                                 5948 non-null   int64
#  64  Job Description spacy_sentencized_lower            5948 non-null   object
#  65  Job Description spacy_tokenized                    5948 non-null   object
# dtypes: category(7), float64(23), int64(25), object(11)
# memory usage: 2.8+ MB
# ====================
# Gender:
# --------------------
# Gender Counts:
# Gender
# Mixed Gender    3836
# Male            1151
# Female           961
# Name: count, dtype: int64
# --------------------
# Gender Percentages:
# Gender
# Mixed Gender   64.500
# Male           19.400
# Female         16.200
# Name: proportion, dtype: float64
# --------------------
# Gender not available.
# ====================
# Gender_Num:
# --------------------
# Gender_Num Counts:
# Gender_Num
# 1    3836
# 2    1151
# 0     961
# Name: count, dtype: int64
# --------------------
# Gender_Num Percentages:
# Gender_Num
# 1   64.500
# 2   19.400
# 0   16.200
# Name: proportion, dtype: float64
# --------------------
# Min Gender_Num value: 0.0
# Max Gender_Num value: 2.0
# --------------------
# Gender_Num Mean: 1.032
# --------------------
# Gender_Num Standard Deviation: 0.595
# ====================
# Gender_Female:
# --------------------
# Gender_Female Counts:
# Gender_Female
# 0    4987
# 1     961
# Name: count, dtype: int64
# --------------------
# Gender_Female Percentages:
# Gender_Female
# 0   83.800
# 1   16.200
# Name: proportion, dtype: float64
# --------------------
# Min Gender_Female value: 0.0
# Max Gender_Female value: 1.0
# --------------------
# Gender_Female Mean: 0.162
# --------------------
# Gender_Female Standard Deviation: 0.368
# ====================
# Gender_Mixed:
# --------------------
# Gender_Mixed Counts:
# Gender_Mixed
# 1    3836
# 0    2112
# Name: count, dtype: int64
# --------------------
# Gender_Mixed Percentages:
# Gender_Mixed
# 1   64.500
# 0   35.500
# Name: proportion, dtype: float64
# --------------------
# Min Gender_Mixed value: 0.0
# Max Gender_Mixed value: 1.0
# --------------------
# Gender_Mixed Mean: 0.645
# --------------------
# Gender_Mixed Standard Deviation: 0.479
# ====================
# Gender_Male:
# --------------------
# Gender_Male Counts:
# Gender_Male
# 0    4797
# 1    1151
# Name: count, dtype: int64
# --------------------
# Gender_Male Percentages:
# Gender_Male
# 0   80.600
# 1   19.400
# Name: proportion, dtype: float64
# --------------------
# Min Gender_Male value: 0.0
# Max Gender_Male value: 1.0
# --------------------
# Gender_Male Mean: 0.194
# --------------------
# Gender_Male Standard Deviation: 0.395
# ====================
# Gender_Female_n:
# --------------------
# Min Gender_Female_n value: 7.0
# Max Gender_Female_n value: 3970.0
# --------------------
# Gender_Female_n Mean: 550.809
# --------------------
# Gender_Female_n Standard Deviation: 748.623
# ====================
# Gender_Male_n:
# --------------------
# Min Gender_Male_n value: 21.0
# Max Gender_Male_n value: 4510.0
# --------------------
# Gender_Male_n Mean: 579.466
# --------------------
# Gender_Male_n Standard Deviation: 686.178
# ====================
# Gender_Female_% per Sector:
# --------------------
# Min Gender_Female_% per Sector value: 19.444
# Max Gender_Female_% per Sector value: 84.299
# --------------------
# Gender_Female_% per Sector Mean: 45.151
# --------------------
# Gender_Female_% per Sector Standard Deviation: 15.885
# ====================
# Gender_Male_% per Sector:
# --------------------
# Min Gender_Male_% per Sector value: 15.632
# Max Gender_Male_% per Sector value: 80.556
# --------------------
# Gender_Male_% per Sector Mean: 54.828
# --------------------
# Gender_Male_% per Sector Standard Deviation: 15.908
# ====================
# Age:
# --------------------
# Age Counts:
# Age
# Younger      3221
# Mixed Age    2046
# Older         681
# Name: count, dtype: int64
# --------------------
# Age Percentages:
# Age
# Younger     54.200
# Mixed Age   34.400
# Older       11.400
# Name: proportion, dtype: float64
# --------------------
# Age not available.
# ====================
# Age_Num:
# --------------------
# Age_Num Counts:
# Age_Num
# 2    3221
# 1    2046
# 0     681
# Name: count, dtype: int64
# --------------------
# Age_Num Percentages:
# Age_Num
# 2   54.200
# 1   34.400
# 0   11.400
# Name: proportion, dtype: float64
# --------------------
# Min Age_Num value: 0.0
# Max Age_Num value: 2.0
# --------------------
# Age_Num Mean: 1.427
# --------------------
# Age_Num Standard Deviation: 0.688
# ====================
# Age_Older:
# --------------------
# Age_Older Counts:
# Age_Older
# 0    5267
# 1     681
# Name: count, dtype: int64
# --------------------
# Age_Older Percentages:
# Age_Older
# 0   88.600
# 1   11.400
# Name: proportion, dtype: float64
# --------------------
# Min Age_Older value: 0.0
# Max Age_Older value: 1.0
# --------------------
# Age_Older Mean: 0.114
# --------------------
# Age_Older Standard Deviation: 0.318
# ====================
# Age_Mixed:
# --------------------
# Age_Mixed Counts:
# Age_Mixed
# 0    3902
# 1    2046
# Name: count, dtype: int64
# --------------------
# Age_Mixed Percentages:
# Age_Mixed
# 0   65.600
# 1   34.400
# Name: proportion, dtype: float64
# --------------------
# Min Age_Mixed value: 0.0
# Max Age_Mixed value: 1.0
# --------------------
# Age_Mixed Mean: 0.344
# --------------------
# Age_Mixed Standard Deviation: 0.475
# ====================
# Age_Younger:
# --------------------
# Age_Younger Counts:
# Age_Younger
# 1    3221
# 0    2727
# Name: count, dtype: int64
# --------------------
# Age_Younger Percentages:
# Age_Younger
# 1   54.200
# 0   45.800
# Name: proportion, dtype: float64
# --------------------
# Min Age_Younger value: 0.0
# Max Age_Younger value: 1.0
# --------------------
# Age_Younger Mean: 0.542
# --------------------
# Age_Younger Standard Deviation: 0.498
# ====================
# Age_Older_n:
# --------------------
# Min Age_Older_n value: 15.0
# Max Age_Older_n value: 2844.0
# --------------------
# Age_Older_n Mean: 433.128
# --------------------
# Age_Older_n Standard Deviation: 549.337
# ====================
# Age_Younger_n:
# --------------------
# Min Age_Younger_n value: 13.0
# Max Age_Younger_n value: 5228.0
# --------------------
# Age_Younger_n Mean: 695.847
# --------------------
# Age_Younger_n Standard Deviation: 814.554
# ====================
# Age_Older_% per Sector:
# --------------------
# Min Age_Older_% per Sector value: 18.939
# Max Age_Older_% per Sector value: 58.333
# --------------------
# Age_Older_% per Sector Mean: 38.122
# --------------------
# Age_Older_% per Sector Standard Deviation: 8.74
# ====================
# Age_Younger_% per Sector:
# --------------------
# Min Age_Younger_% per Sector value: 44.444
# Max Age_Younger_% per Sector value: 80.808
# --------------------
# Age_Younger_% per Sector Mean: 61.624
# --------------------
# Age_Younger_% per Sector Standard Deviation: 8.821
# ====================
# Interaction_Female_Older_% per Sector:
# --------------------
# Min Interaction_Female_Older_% per Sector value: 903.686
# Max Interaction_Female_Older_% per Sector value: 3888.445
# --------------------
# Interaction_Female_Older_% per Sector Mean: 1726.843
# --------------------
# Interaction_Female_Older_% per Sector Standard Deviation: 834.667
# ====================
# Interaction_Female_Younger_% per Sector:
# --------------------
# Min Interaction_Female_Younger_% per Sector value: 864.198
# Max Interaction_Female_Younger_% per Sector value: 4529.657
# --------------------
# Interaction_Female_Younger_% per Sector Mean: 2777.107
# --------------------
# Interaction_Female_Younger_% per Sector Standard Deviation: 902.189
# ====================
# Interaction_Male_Older_% per Sector:
# --------------------
# Min Interaction_Male_Older_% per Sector value: 721.036
# Max Interaction_Male_Older_% per Sector value: 4699.074
# --------------------
# Interaction_Male_Older_% per Sector Mean: 2084.6
# --------------------
# Interaction_Male_Older_% per Sector Standard Deviation: 897.017
# ====================
# Interaction_Male_Younger_% per Sector:
# --------------------
# Min Interaction_Male_Younger_% per Sector value: 839.936
# Max Interaction_Male_Younger_% per Sector value: 4869.203
# --------------------
# Interaction_Male_Younger_% per Sector Mean: 3383.939
# --------------------
# Interaction_Male_Younger_% per Sector Standard Deviation: 1017.928

# %%
# Warmth 1 = 1489 (25.1%), Competence 1 = 2667 (44.4%)
get_df_info(df_manual, ivs_all=dvs)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 5948 entries, 0 to 5954
# Data columns (total 66 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Job ID                                             5948 non-null   object
#  1   Job Description spacy_sentencized                  5948 non-null   object
#  2   Warmth                                             5948 non-null   int64
#  3   Competence                                         5948 non-null   int64
#  4   Dutch Requirement in Sentence                      5948 non-null   category
#  5   English Requirement in Sentence                    5948 non-null   category
#  6   Dutch Requirement in Sentence_No                   5948 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                  5948 non-null   int64
#  8   English Requirement in Sentence_No                 5948 non-null   int64
#  9   English Requirement in Sentence_Yes                5948 non-null   int64
#  10  Search Keyword                                     5948 non-null   object
#  11  Platform                                           5948 non-null   category
#  12  Job Title                                          5948 non-null   object
#  13  Company Name                                       5948 non-null   object
#  14  Location                                           5948 non-null   object
#  15  Industry                                           290 non-null    object
#  16  Dutch Requirement in Job Ad                        5948 non-null   category
#  17  English Requirement in Job Ad                      5948 non-null   category
#  18  Dutch Requirement in Job Ad_No                     5948 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                    5948 non-null   int64
#  20  English Requirement in Job Ad_No                   5948 non-null   int64
#  21  English Requirement in Job Ad_Yes                  5948 non-null   int64
#  22  Sector Code                                        5948 non-null   object
#  23  Sector                                             5948 non-null   object
#  24  Keywords Count                                     5948 non-null   float64
#  25  Gender_Female_n                                    5948 non-null   float64
#  26  Gender_Female_% per Sector                         5948 non-null   float64
#  27  Gender_Female_% per Social Category                5948 non-null   float64
#  28  Gender_Female_% per Workforce                      5948 non-null   float64
#  29  Gender_Male_n                                      5948 non-null   float64
#  30  Gender_Male_% per Sector                           5948 non-null   float64
#  31  Gender_Male_% per Social Category                  5948 non-null   float64
#  32  Gender_Male_% per Workforce                        5948 non-null   float64
#  33  Gender                                             5948 non-null   category
#  34  Age_Older_n                                        5948 non-null   float64
#  35  Age_Older_% per Sector                             5948 non-null   float64
#  36  Age_Older_% per Social Category                    5948 non-null   float64
#  37  Age_Older_% per Workforce                          5948 non-null   float64
#  38  Age_Younger_n                                      5948 non-null   float64
#  39  Age_Younger_% per Sector                           5948 non-null   float64
#  40  Age_Younger_% per Social Category                  5948 non-null   float64
#  41  Age_Younger_% per Workforce                        5948 non-null   float64
#  42  Age                                                5948 non-null   category
#  43  Sector_n                                           5948 non-null   float64
#  44  % Sector per Workforce                             5948 non-null   float64
#  45  Sector Job Advertisement Count                     5948 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count  5948 non-null   int64
#  47  Sector Age Designation Job Advertisement Count     5948 non-null   int64
#  48  Gender_Female                                      5948 non-null   int64
#  49  Gender_Male                                        5948 non-null   int64
#  50  Gender_Mixed                                       5948 non-null   int64
#  51  Age_Mixed                                          5948 non-null   int64
#  52  Age_Older                                          5948 non-null   int64
#  53  Age_Younger                                        5948 non-null   int64
#  54  Gender_Num                                         5948 non-null   int64
#  55  Age_Num                                            5948 non-null   int64
#  56  Interaction_Female_Older_% per Sector              5948 non-null   float64
#  57  Interaction_Female_Younger_% per Sector            5948 non-null   float64
#  58  Interaction_Male_Older_% per Sector                5948 non-null   float64
#  59  Interaction_Male_Younger_% per Sector              5948 non-null   float64
#  60  Platform_Num                                       5948 non-null   int64
#  61  Platform_LinkedIn                                  5948 non-null   int64
#  62  Platform_Indeed                                    5948 non-null   int64
#  63  Platform_Glassdoor                                 5948 non-null   int64
#  64  Job Description spacy_sentencized_lower            5948 non-null   object
#  65  Job Description spacy_tokenized                    5948 non-null   object
# dtypes: category(7), float64(23), int64(25), object(11)
# memory usage: 2.8+ MB
# ====================
# Warmth:
# --------------------
# Warmth Counts:
# Warmth
# 0    4333
# 1    1615
# Name: count, dtype: int64
# --------------------
# Warmth Percentages:
# Warmth
# 0   72.800
# 1   27.200
# Name: proportion, dtype: float64
# --------------------
# Min Warmth value: 0.0
# Max Warmth value: 1.0
# --------------------
# Warmth Mean: 0.272
# --------------------
# Warmth Standard Deviation: 0.445
# ====================
# Competence:
# --------------------
# Competence Counts:
# Competence
# 0    3181
# 1    2767
# Name: count, dtype: int64
# --------------------
# Competence Percentages:
# Competence
# 0   53.500
# 1   46.500
# Name: proportion, dtype: float64
# --------------------
# Min Competence value: 0.0
# Max Competence value: 1.0
# --------------------
# Competence Mean: 0.465
# --------------------
# Competence Standard Deviation: 0.499

# %%
df_manual['Job Description spacy_sentencized_cleaned'] = df_manual['Job Description spacy_tokenized'].str.join(' ')

# %%
# %%time
# Get sentence word frequencies
df_manual = df_manual.progress_apply(
    lambda row: get_word_num_and_frequency(
        row=row, text_col='Job Description spacy_sentencized'
    ),
    axis='columns',
)
# Out:
# progress-bar:   0%|          | 0/5948 [00:00<?, ?it/s]
# CPU times: user 8.48 s, sys: 467 ms, total: 8.95 s
# Wall time: 16.8 s

# %%
df_manual[
    [
        'Job Description spacy_sentencized',
        'Job Description spacy_sentencized_num_words', 'Job Description spacy_sentencized_num_unique_words',
        'Job Description spacy_sentencized_num_chars', 'Job Description spacy_sentencized_num_chars_no_whitespact_and_punt'
    ]
].head()
# Out:
#           Job Description spacy_sentencized           Job Description spacy_sentencized_num_words  Job Description spacy_sentencized_num_unique_words  Job Description spacy_sentencized_num_chars  Job Description spacy_sentencized_num_chars_no_whitespact_and_punt
# 0  Through daily contact, as a partner of sales a...                      45                                              36                                               319                                             270
# 1               This role is truly cross functional.                       6                                               6                                                36                                              30
# 2  The other part of your time would be spent as ...                      50                                              45                                               345                                             291
# 3  Being the expert on your product also means yo...                      47                                              38                                               326                                             274
# 4  Your mindset is commercial, result oriented an...                      30                                              28                                               207                                             175

# %%
df_manual[
    [
        'Job Description spacy_sentencized',
        'Job Description spacy_sentencized_num_words', 'Job Description spacy_sentencized_num_unique_words',
        'Job Description spacy_sentencized_num_chars', 'Job Description spacy_sentencized_num_chars_no_whitespact_and_punt'
    ]
].describe()
# Out:
#        Job Description spacy_sentencized_num_words  Job Description spacy_sentencized_num_unique_words  Job Description spacy_sentencized_num_chars  Job Description spacy_sentencized_num_chars_no_whitespact_and_punt
# count                   5948.000                                        5948.000                                         5948.000                                        5948.000
# mean                      13.817                                          12.822                                           91.202                                          76.285
# std                       10.614                                           8.996                                           71.805                                          59.880
# min                        1.000                                           1.000                                            3.000                                           2.000
# 25%                        6.000                                           6.000                                           40.000                                          33.000
# 50%                       12.000                                          11.000                                           78.000                                          65.000
# 75%                       19.000                                          18.000                                          124.000                                         104.000
# max                      131.000                                          95.000                                          964.000                                         814.000

# %%
# Get the highest num_words
# len=131
df_manual['Job Description spacy_sentencized_num_words'].max()
# Out:
# 131

# %%
# Get the Job Description spacy_sentencized row with the highest num_words value
df_manual['Job Description spacy_sentencized'].loc[df_manual['Job Description spacy_sentencized_num_words'].idxmax()]
# Out:
# 'The ideal candidate has the following education, experience and skills:Master degree, a Post Master degree RA/CPA/ACCA or equivalent would be considered to be a plus;Relevant experience in a corporate, internationally challenging environment; experience or strong affinity with Private Equity is an advantage;Strong experience in working with ERP-systems and consolidation packages, preferably Tagetik;Excellent communication skills, both in Dutch and English;Solid technical knowledge of IFRS and Dutch GAAP;You collaborate easily as a team player up and down the organization;You are comfortable in conveying a financial message to all kinds of stakeholders, including the Executive and Supervisory Board and Private Equity shareholder;You have a can do no nonsense mentality; you are hands on, self-starting and like to get things done;You are entrepreneurial and resilient, and not the typical corporate character;You are fluent in English.'

# %%
# Get the lowest num_words
# len=1
df_manual['Job Description spacy_sentencized_num_words'].min()
# Out:
# 1

# %%
# Get the Job Description spacy_sentencized row with the lowest num_words value
df_manual['Job Description spacy_sentencized'].loc[df_manual['Job Description spacy_sentencized_num_words'].idxmin()]
# Out:
# '#RM-LI'

# %%
df_manual.columns
# Out:
# Index(['Job ID', 'Job Description spacy_sentencized', 'Warmth', 'Competence', 'Dutch Requirement in Sentence', 'English Requirement in Sentence', 'Dutch Requirement in Sentence_No', 'Dutch Requirement in Sentence_Yes', 'English Requirement in Sentence_No', 'English Requirement in Sentence_Yes', 'Search Keyword', 'Platform', 'Job Title', 'Company Name', 'Location', 'Industry', 'Dutch Requirement in Job Ad', 'English Requirement in Job Ad', 'Dutch Requirement in Job Ad_No', 'Dutch Requirement in Job Ad_Yes', 'English Requirement in Job Ad_No', 'English Requirement in Job Ad_Yes', 'Sector Code', 'Sector', 'Keywords Count', 'Gender_Female_n', 'Gender_Female_% per Sector', 'Gender_Female_% per Social Category', 'Gender_Female_% per Workforce', 'Gender_Male_n', 'Gender_Male_% per Sector', 'Gender_Male_% per Social Category', 'Gender_Male_% per Workforce', 'Gender', 'Age_Older_n', 'Age_Older_% per Sector', 'Age_Older_% per Social Category', 'Age_Older_% per Workforce', 'Age_Younger_n', 'Age_Younger_% per Sector', 'Age_Younger_% per Social Category', 'Age_Younger_% per Workforce', 'Age', 'Sector_n', '% Sector per Workforce', 'Sector Job Advertisement Count', 'Sector Gender Designation Job Advertisement Count', 'Sector Age Designation Job Advertisement Count', 'Gender_Female', 'Gender_Male', 'Gender_Mixed', 'Age_Mixed', 'Age_Older', 'Age_Younger', 'Gender_Num', 'Age_Num', 'Interaction_Female_Older_% per Sector', 'Interaction_Female_Younger_% per Sector', 'Interaction_Male_Older_% per Sector', 'Interaction_Male_Younger_% per Sector', 'Platform_Num', 'Platform_LinkedIn', 'Platform_Indeed', 'Platform_Glassdoor', 'Job Description spacy_sentencized_lower', 'Job Description spacy_tokenized', 'Job Description spacy_sentencized_cleaned', 'Job Description spacy_sentencized_num_words', 'Job Description spacy_sentencized_num_unique_words', 'Job Description spacy_sentencized_num_chars', 'Job Description spacy_sentencized_num_chars_no_whitespact_and_punt', 'Job Description spacy_sentencized_num_punctuations'], dtype='object')

# %%
get_df_info(df_manual, ivs_all=ivs_all)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 5948 entries, 0 to 5954
# Data columns (total 72 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Job ID                                                              5948 non-null   object
#  1   Job Description spacy_sentencized                                   5948 non-null   object
#  2   Warmth                                                              5948 non-null   int64
#  3   Competence                                                          5948 non-null   int64
#  4   Dutch Requirement in Sentence                                       5948 non-null   object
#  5   English Requirement in Sentence                                     5948 non-null   object
#  6   Dutch Requirement in Sentence_No                                    5948 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                                   5948 non-null   int64
#  8   English Requirement in Sentence_No                                  5948 non-null   int64
#  9   English Requirement in Sentence_Yes                                 5948 non-null   int64
#  10  Search Keyword                                                      5948 non-null   object
#  11  Platform                                                            5948 non-null   object
#  12  Job Title                                                           5948 non-null   object
#  13  Company Name                                                        5948 non-null   object
#  14  Location                                                            5948 non-null   object
#  15  Industry                                                            290 non-null    object
#  16  Dutch Requirement in Job Ad                                         5948 non-null   object
#  17  English Requirement in Job Ad                                       5948 non-null   object
#  18  Dutch Requirement in Job Ad_No                                      5948 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                                     5948 non-null   int64
#  20  English Requirement in Job Ad_No                                    5948 non-null   int64
#  21  English Requirement in Job Ad_Yes                                   5948 non-null   int64
#  22  Sector Code                                                         5948 non-null   object
#  23  Sector                                                              5948 non-null   object
#  24  Keywords Count                                                      5948 non-null   float64
#  25  Gender_Female_n                                                     5948 non-null   float64
#  26  Gender_Female_% per Sector                                          5948 non-null   float64
#  27  Gender_Female_% per Social Category                                 5948 non-null   float64
#  28  Gender_Female_% per Workforce                                       5948 non-null   float64
#  29  Gender_Male_n                                                       5948 non-null   float64
#  30  Gender_Male_% per Sector                                            5948 non-null   float64
#  31  Gender_Male_% per Social Category                                   5948 non-null   float64
#  32  Gender_Male_% per Workforce                                         5948 non-null   float64
#  33  Gender                                                              5948 non-null   object
#  34  Age_Older_n                                                         5948 non-null   float64
#  35  Age_Older_% per Sector                                              5948 non-null   float64
#  36  Age_Older_% per Social Category                                     5948 non-null   float64
#  37  Age_Older_% per Workforce                                           5948 non-null   float64
#  38  Age_Younger_n                                                       5948 non-null   float64
#  39  Age_Younger_% per Sector                                            5948 non-null   float64
#  40  Age_Younger_% per Social Category                                   5948 non-null   float64
#  41  Age_Younger_% per Workforce                                         5948 non-null   float64
#  42  Age                                                                 5948 non-null   object
#  43  Sector_n                                                            5948 non-null   float64
#  44  % Sector per Workforce                                              5948 non-null   float64
#  45  Sector Job Advertisement Count                                      5948 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count                   5948 non-null   int64
#  47  Sector Age Designation Job Advertisement Count                      5948 non-null   int64
#  48  Gender_Female                                                       5948 non-null   int64
#  49  Gender_Male                                                         5948 non-null   int64
#  50  Gender_Mixed                                                        5948 non-null   int64
#  51  Age_Mixed                                                           5948 non-null   int64
#  52  Age_Older                                                           5948 non-null   int64
#  53  Age_Younger                                                         5948 non-null   int64
#  54  Gender_Num                                                          5948 non-null   int64
#  55  Age_Num                                                             5948 non-null   int64
#  56  Interaction_Female_Older_% per Sector                               5948 non-null   float64
#  57  Interaction_Female_Younger_% per Sector                             5948 non-null   float64
#  58  Interaction_Male_Older_% per Sector                                 5948 non-null   float64
#  59  Interaction_Male_Younger_% per Sector                               5948 non-null   float64
#  60  Platform_Num                                                        5948 non-null   int64
#  61  Platform_LinkedIn                                                   5948 non-null   int64
#  62  Platform_Indeed                                                     5948 non-null   int64
#  63  Platform_Glassdoor                                                  5948 non-null   int64
#  64  Job Description spacy_sentencized_lower                             5948 non-null   object
#  65  Job Description spacy_tokenized                                     5948 non-null   object
#  66  Job Description spacy_sentencized_cleaned                           5948 non-null   object
#  67  Job Description spacy_sentencized_num_words                         5948 non-null   int64
#  68  Job Description spacy_sentencized_num_unique_words                  5948 non-null   int64
#  69  Job Description spacy_sentencized_num_chars                         5948 non-null   int64
#  70  Job Description spacy_sentencized_num_chars_no_whitespact_and_punt  5948 non-null   int64
#  71  Job Description spacy_sentencized_num_punctuations                  5948 non-null   int64
# dtypes: float64(23), int64(30), object(19)
# memory usage: 3.4+ MB
# ====================
# Gender:
# --------------------
# Gender Counts:
# Gender
# Mixed Gender    3836
# Male            1151
# Female           961
# Name: count, dtype: int64
# --------------------
# Gender Percentages:
# Gender
# Mixed Gender   64.500
# Male           19.400
# Female         16.200
# Name: proportion, dtype: float64
# --------------------
# Gender not available.
# ====================
# Gender_Num:
# --------------------
# Gender_Num Counts:
# Gender_Num
# 1    3836
# 2    1151
# 0     961
# Name: count, dtype: int64
# --------------------
# Gender_Num Percentages:
# Gender_Num
# 1   64.500
# 2   19.400
# 0   16.200
# Name: proportion, dtype: float64
# --------------------
# Min Gender_Num value: 0.0
# Max Gender_Num value: 2.0
# --------------------
# Gender_Num Mean: 1.032
# --------------------
# Gender_Num Standard Deviation: 0.595
# ====================
# Gender_Female:
# --------------------
# Gender_Female Counts:
# Gender_Female
# 0    4987
# 1     961
# Name: count, dtype: int64
# --------------------
# Gender_Female Percentages:
# Gender_Female
# 0   83.800
# 1   16.200
# Name: proportion, dtype: float64
# --------------------
# Min Gender_Female value: 0.0
# Max Gender_Female value: 1.0
# --------------------
# Gender_Female Mean: 0.162
# --------------------
# Gender_Female Standard Deviation: 0.368
# ====================
# Gender_Mixed:
# --------------------
# Gender_Mixed Counts:
# Gender_Mixed
# 1    3836
# 0    2112
# Name: count, dtype: int64
# --------------------
# Gender_Mixed Percentages:
# Gender_Mixed
# 1   64.500
# 0   35.500
# Name: proportion, dtype: float64
# --------------------
# Min Gender_Mixed value: 0.0
# Max Gender_Mixed value: 1.0
# --------------------
# Gender_Mixed Mean: 0.645
# --------------------
# Gender_Mixed Standard Deviation: 0.479
# ====================
# Gender_Male:
# --------------------
# Gender_Male Counts:
# Gender_Male
# 0    4797
# 1    1151
# Name: count, dtype: int64
# --------------------
# Gender_Male Percentages:
# Gender_Male
# 0   80.600
# 1   19.400
# Name: proportion, dtype: float64
# --------------------
# Min Gender_Male value: 0.0
# Max Gender_Male value: 1.0
# --------------------
# Gender_Male Mean: 0.194
# --------------------
# Gender_Male Standard Deviation: 0.395
# ====================
# Gender_Female_n:
# --------------------
# Min Gender_Female_n value: 7.0
# Max Gender_Female_n value: 3970.0
# --------------------
# Gender_Female_n Mean: 550.809
# --------------------
# Gender_Female_n Standard Deviation: 748.623
# ====================
# Gender_Male_n:
# --------------------
# Min Gender_Male_n value: 21.0
# Max Gender_Male_n value: 4510.0
# --------------------
# Gender_Male_n Mean: 579.466
# --------------------
# Gender_Male_n Standard Deviation: 686.178
# ====================
# Gender_Female_% per Sector:
# --------------------
# Min Gender_Female_% per Sector value: 19.444
# Max Gender_Female_% per Sector value: 84.299
# --------------------
# Gender_Female_% per Sector Mean: 45.151
# --------------------
# Gender_Female_% per Sector Standard Deviation: 15.885
# ====================
# Gender_Male_% per Sector:
# --------------------
# Min Gender_Male_% per Sector value: 15.632
# Max Gender_Male_% per Sector value: 80.556
# --------------------
# Gender_Male_% per Sector Mean: 54.828
# --------------------
# Gender_Male_% per Sector Standard Deviation: 15.908
# ====================
# Age:
# --------------------
# Age Counts:
# Age
# Younger      3221
# Mixed Age    2046
# Older         681
# Name: count, dtype: int64
# --------------------
# Age Percentages:
# Age
# Younger     54.200
# Mixed Age   34.400
# Older       11.400
# Name: proportion, dtype: float64
# --------------------
# Age not available.
# ====================
# Age_Num:
# --------------------
# Age_Num Counts:
# Age_Num
# 2    3221
# 1    2046
# 0     681
# Name: count, dtype: int64
# --------------------
# Age_Num Percentages:
# Age_Num
# 2   54.200
# 1   34.400
# 0   11.400
# Name: proportion, dtype: float64
# --------------------
# Min Age_Num value: 0.0
# Max Age_Num value: 2.0
# --------------------
# Age_Num Mean: 1.427
# --------------------
# Age_Num Standard Deviation: 0.688
# ====================
# Age_Older:
# --------------------
# Age_Older Counts:
# Age_Older
# 0    5267
# 1     681
# Name: count, dtype: int64
# --------------------
# Age_Older Percentages:
# Age_Older
# 0   88.600
# 1   11.400
# Name: proportion, dtype: float64
# --------------------
# Min Age_Older value: 0.0
# Max Age_Older value: 1.0
# --------------------
# Age_Older Mean: 0.114
# --------------------
# Age_Older Standard Deviation: 0.318
# ====================
# Age_Mixed:
# --------------------
# Age_Mixed Counts:
# Age_Mixed
# 0    3902
# 1    2046
# Name: count, dtype: int64
# --------------------
# Age_Mixed Percentages:
# Age_Mixed
# 0   65.600
# 1   34.400
# Name: proportion, dtype: float64
# --------------------
# Min Age_Mixed value: 0.0
# Max Age_Mixed value: 1.0
# --------------------
# Age_Mixed Mean: 0.344
# --------------------
# Age_Mixed Standard Deviation: 0.475
# ====================
# Age_Younger:
# --------------------
# Age_Younger Counts:
# Age_Younger
# 1    3221
# 0    2727
# Name: count, dtype: int64
# --------------------
# Age_Younger Percentages:
# Age_Younger
# 1   54.200
# 0   45.800
# Name: proportion, dtype: float64
# --------------------
# Min Age_Younger value: 0.0
# Max Age_Younger value: 1.0
# --------------------
# Age_Younger Mean: 0.542
# --------------------
# Age_Younger Standard Deviation: 0.498
# ====================
# Age_Older_n:
# --------------------
# Min Age_Older_n value: 15.0
# Max Age_Older_n value: 2844.0
# --------------------
# Age_Older_n Mean: 433.128
# --------------------
# Age_Older_n Standard Deviation: 549.337
# ====================
# Age_Younger_n:
# --------------------
# Min Age_Younger_n value: 13.0
# Max Age_Younger_n value: 5228.0
# --------------------
# Age_Younger_n Mean: 695.847
# --------------------
# Age_Younger_n Standard Deviation: 814.554
# ====================
# Age_Older_% per Sector:
# --------------------
# Min Age_Older_% per Sector value: 18.939
# Max Age_Older_% per Sector value: 58.333
# --------------------
# Age_Older_% per Sector Mean: 38.122
# --------------------
# Age_Older_% per Sector Standard Deviation: 8.74
# ====================
# Age_Younger_% per Sector:
# --------------------
# Min Age_Younger_% per Sector value: 44.444
# Max Age_Younger_% per Sector value: 80.808
# --------------------
# Age_Younger_% per Sector Mean: 61.624
# --------------------
# Age_Younger_% per Sector Standard Deviation: 8.821
# ====================
# Interaction_Female_Older_% per Sector:
# --------------------
# Min Interaction_Female_Older_% per Sector value: 903.686
# Max Interaction_Female_Older_% per Sector value: 3888.445
# --------------------
# Interaction_Female_Older_% per Sector Mean: 1726.843
# --------------------
# Interaction_Female_Older_% per Sector Standard Deviation: 834.667
# ====================
# Interaction_Female_Younger_% per Sector:
# --------------------
# Min Interaction_Female_Younger_% per Sector value: 864.198
# Max Interaction_Female_Younger_% per Sector value: 4529.657
# --------------------
# Interaction_Female_Younger_% per Sector Mean: 2777.107
# --------------------
# Interaction_Female_Younger_% per Sector Standard Deviation: 902.189
# ====================
# Interaction_Male_Older_% per Sector:
# --------------------
# Min Interaction_Male_Older_% per Sector value: 721.036
# Max Interaction_Male_Older_% per Sector value: 4699.074
# --------------------
# Interaction_Male_Older_% per Sector Mean: 2084.6
# --------------------
# Interaction_Male_Older_% per Sector Standard Deviation: 897.017
# ====================
# Interaction_Male_Younger_% per Sector:
# --------------------
# Min Interaction_Male_Younger_% per Sector value: 839.936
# Max Interaction_Male_Younger_% per Sector value: 4869.203
# --------------------
# Interaction_Male_Younger_% per Sector Mean: 3383.939
# --------------------
# Interaction_Male_Younger_% per Sector Standard Deviation: 1017.928

# %%
# Warmth 1 = 1499 (25.1%), Competence 1 = 2649 (44.4%)
get_df_info(df_manual, ivs_all=dvs)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 5948 entries, 0 to 5954
# Data columns (total 72 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Job ID                                                              5948 non-null   object
#  1   Job Description spacy_sentencized                                   5948 non-null   object
#  2   Warmth                                                              5948 non-null   int64
#  3   Competence                                                          5948 non-null   int64
#  4   Dutch Requirement in Sentence                                       5948 non-null   object
#  5   English Requirement in Sentence                                     5948 non-null   object
#  6   Dutch Requirement in Sentence_No                                    5948 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                                   5948 non-null   int64
#  8   English Requirement in Sentence_No                                  5948 non-null   int64
#  9   English Requirement in Sentence_Yes                                 5948 non-null   int64
#  10  Search Keyword                                                      5948 non-null   object
#  11  Platform                                                            5948 non-null   object
#  12  Job Title                                                           5948 non-null   object
#  13  Company Name                                                        5948 non-null   object
#  14  Location                                                            5948 non-null   object
#  15  Industry                                                            290 non-null    object
#  16  Dutch Requirement in Job Ad                                         5948 non-null   object
#  17  English Requirement in Job Ad                                       5948 non-null   object
#  18  Dutch Requirement in Job Ad_No                                      5948 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                                     5948 non-null   int64
#  20  English Requirement in Job Ad_No                                    5948 non-null   int64
#  21  English Requirement in Job Ad_Yes                                   5948 non-null   int64
#  22  Sector Code                                                         5948 non-null   object
#  23  Sector                                                              5948 non-null   object
#  24  Keywords Count                                                      5948 non-null   float64
#  25  Gender_Female_n                                                     5948 non-null   float64
#  26  Gender_Female_% per Sector                                          5948 non-null   float64
#  27  Gender_Female_% per Social Category                                 5948 non-null   float64
#  28  Gender_Female_% per Workforce                                       5948 non-null   float64
#  29  Gender_Male_n                                                       5948 non-null   float64
#  30  Gender_Male_% per Sector                                            5948 non-null   float64
#  31  Gender_Male_% per Social Category                                   5948 non-null   float64
#  32  Gender_Male_% per Workforce                                         5948 non-null   float64
#  33  Gender                                                              5948 non-null   object
#  34  Age_Older_n                                                         5948 non-null   float64
#  35  Age_Older_% per Sector                                              5948 non-null   float64
#  36  Age_Older_% per Social Category                                     5948 non-null   float64
#  37  Age_Older_% per Workforce                                           5948 non-null   float64
#  38  Age_Younger_n                                                       5948 non-null   float64
#  39  Age_Younger_% per Sector                                            5948 non-null   float64
#  40  Age_Younger_% per Social Category                                   5948 non-null   float64
#  41  Age_Younger_% per Workforce                                         5948 non-null   float64
#  42  Age                                                                 5948 non-null   object
#  43  Sector_n                                                            5948 non-null   float64
#  44  % Sector per Workforce                                              5948 non-null   float64
#  45  Sector Job Advertisement Count                                      5948 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count                   5948 non-null   int64
#  47  Sector Age Designation Job Advertisement Count                      5948 non-null   int64
#  48  Gender_Female                                                       5948 non-null   int64
#  49  Gender_Male                                                         5948 non-null   int64
#  50  Gender_Mixed                                                        5948 non-null   int64
#  51  Age_Mixed                                                           5948 non-null   int64
#  52  Age_Older                                                           5948 non-null   int64
#  53  Age_Younger                                                         5948 non-null   int64
#  54  Gender_Num                                                          5948 non-null   int64
#  55  Age_Num                                                             5948 non-null   int64
#  56  Interaction_Female_Older_% per Sector                               5948 non-null   float64
#  57  Interaction_Female_Younger_% per Sector                             5948 non-null   float64
#  58  Interaction_Male_Older_% per Sector                                 5948 non-null   float64
#  59  Interaction_Male_Younger_% per Sector                               5948 non-null   float64
#  60  Platform_Num                                                        5948 non-null   int64
#  61  Platform_LinkedIn                                                   5948 non-null   int64
#  62  Platform_Indeed                                                     5948 non-null   int64
#  63  Platform_Glassdoor                                                  5948 non-null   int64
#  64  Job Description spacy_sentencized_lower                             5948 non-null   object
#  65  Job Description spacy_tokenized                                     5948 non-null   object
#  66  Job Description spacy_sentencized_cleaned                           5948 non-null   object
#  67  Job Description spacy_sentencized_num_words                         5948 non-null   int64
#  68  Job Description spacy_sentencized_num_unique_words                  5948 non-null   int64
#  69  Job Description spacy_sentencized_num_chars                         5948 non-null   int64
#  70  Job Description spacy_sentencized_num_chars_no_whitespact_and_punt  5948 non-null   int64
#  71  Job Description spacy_sentencized_num_punctuations                  5948 non-null   int64
# dtypes: float64(23), int64(30), object(19)
# memory usage: 3.4+ MB
# ====================
# Warmth:
# --------------------
# Warmth Counts:
# Warmth
# 0    4333
# 1    1615
# Name: count, dtype: int64
# --------------------
# Warmth Percentages:
# Warmth
# 0   72.800
# 1   27.200
# Name: proportion, dtype: float64
# --------------------
# Min Warmth value: 0.0
# Max Warmth value: 1.0
# --------------------
# Warmth Mean: 0.272
# --------------------
# Warmth Standard Deviation: 0.445
# ====================
# Competence:
# --------------------
# Competence Counts:
# Competence
# 0    3181
# 1    2767
# Name: count, dtype: int64
# --------------------
# Competence Percentages:
# Competence
# 0   53.500
# 1   46.500
# Name: proportion, dtype: float64
# --------------------
# Min Competence value: 0.0
# Max Competence value: 1.0
# --------------------
# Competence Mean: 0.465
# --------------------
# Competence Standard Deviation: 0.499

# %%
assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
df_manual.to_pickle(f'{df_save_dir}df_manual_tokenized_spacy.pkl')
df_manual.to_csv(f'{df_save_dir}df_manual_tokenized_spacy.csv')

# %% [markdown]
# ## Use NLTK to tokenize sentences

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_TOKENIZED_SPACY
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %%
import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

mod = sys.modules[__name__]

code_dir = None
code_dir_name = 'Code'
unwanted_subdir_name = 'Analysis'

if code_dir_name not in str(Path.cwd()).split('/')[-1]:
    for _ in range(5):

        parent_path = str(Path.cwd().parents[_]).split('/')[-1]

        if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

            code_dir = str(Path.cwd().parents[_])

            if code_dir is not None:
                break
else:
    code_dir = str(Path.cwd())
sys.path.append(code_dir)

# %load_ext autoreload
# %autoreload 2

# %%
from setup_module.imports import * # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# %%
df_manual = pd.read_pickle(f'{df_save_dir}df_manual_tokenized_spacy.pkl')

# %%
# Warmth 1 = 1595 (24.90%), Competence 1 = 2836 (44.30%)
get_df_info(df_manual, ivs_all=dvs)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 5948 entries, 0 to 5954
# Data columns (total 72 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Job ID                                                              5948 non-null   object
#  1   Job Description spacy_sentencized                                   5948 non-null   object
#  2   Warmth                                                              5948 non-null   int64
#  3   Competence                                                          5948 non-null   int64
#  4   Dutch Requirement in Sentence                                       5948 non-null   object
#  5   English Requirement in Sentence                                     5948 non-null   object
#  6   Dutch Requirement in Sentence_No                                    5948 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                                   5948 non-null   int64
#  8   English Requirement in Sentence_No                                  5948 non-null   int64
#  9   English Requirement in Sentence_Yes                                 5948 non-null   int64
#  10  Search Keyword                                                      5948 non-null   object
#  11  Platform                                                            5948 non-null   object
#  12  Job Title                                                           5948 non-null   object
#  13  Company Name                                                        5948 non-null   object
#  14  Location                                                            5948 non-null   object
#  15  Industry                                                            290 non-null    object
#  16  Dutch Requirement in Job Ad                                         5948 non-null   object
#  17  English Requirement in Job Ad                                       5948 non-null   object
#  18  Dutch Requirement in Job Ad_No                                      5948 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                                     5948 non-null   int64
#  20  English Requirement in Job Ad_No                                    5948 non-null   int64
#  21  English Requirement in Job Ad_Yes                                   5948 non-null   int64
#  22  Sector Code                                                         5948 non-null   object
#  23  Sector                                                              5948 non-null   object
#  24  Keywords Count                                                      5948 non-null   float64
#  25  Gender_Female_n                                                     5948 non-null   float64
#  26  Gender_Female_% per Sector                                          5948 non-null   float64
#  27  Gender_Female_% per Social Category                                 5948 non-null   float64
#  28  Gender_Female_% per Workforce                                       5948 non-null   float64
#  29  Gender_Male_n                                                       5948 non-null   float64
#  30  Gender_Male_% per Sector                                            5948 non-null   float64
#  31  Gender_Male_% per Social Category                                   5948 non-null   float64
#  32  Gender_Male_% per Workforce                                         5948 non-null   float64
#  33  Gender                                                              5948 non-null   object
#  34  Age_Older_n                                                         5948 non-null   float64
#  35  Age_Older_% per Sector                                              5948 non-null   float64
#  36  Age_Older_% per Social Category                                     5948 non-null   float64
#  37  Age_Older_% per Workforce                                           5948 non-null   float64
#  38  Age_Younger_n                                                       5948 non-null   float64
#  39  Age_Younger_% per Sector                                            5948 non-null   float64
#  40  Age_Younger_% per Social Category                                   5948 non-null   float64
#  41  Age_Younger_% per Workforce                                         5948 non-null   float64
#  42  Age                                                                 5948 non-null   object
#  43  Sector_n                                                            5948 non-null   float64
#  44  % Sector per Workforce                                              5948 non-null   float64
#  45  Sector Job Advertisement Count                                      5948 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count                   5948 non-null   int64
#  47  Sector Age Designation Job Advertisement Count                      5948 non-null   int64
#  48  Gender_Female                                                       5948 non-null   int64
#  49  Gender_Male                                                         5948 non-null   int64
#  50  Gender_Mixed                                                        5948 non-null   int64
#  51  Age_Mixed                                                           5948 non-null   int64
#  52  Age_Older                                                           5948 non-null   int64
#  53  Age_Younger                                                         5948 non-null   int64
#  54  Gender_Num                                                          5948 non-null   int64
#  55  Age_Num                                                             5948 non-null   int64
#  56  Interaction_Female_Older_% per Sector                               5948 non-null   float64
#  57  Interaction_Female_Younger_% per Sector                             5948 non-null   float64
#  58  Interaction_Male_Older_% per Sector                                 5948 non-null   float64
#  59  Interaction_Male_Younger_% per Sector                               5948 non-null   float64
#  60  Platform_Num                                                        5948 non-null   int64
#  61  Platform_LinkedIn                                                   5948 non-null   int64
#  62  Platform_Indeed                                                     5948 non-null   int64
#  63  Platform_Glassdoor                                                  5948 non-null   int64
#  64  Job Description spacy_sentencized_lower                             5948 non-null   object
#  65  Job Description spacy_tokenized                                     5948 non-null   object
#  66  Job Description spacy_sentencized_cleaned                           5948 non-null   object
#  67  Job Description spacy_sentencized_num_words                         5948 non-null   int64
#  68  Job Description spacy_sentencized_num_unique_words                  5948 non-null   int64
#  69  Job Description spacy_sentencized_num_chars                         5948 non-null   int64
#  70  Job Description spacy_sentencized_num_chars_no_whitespact_and_punt  5948 non-null   int64
#  71  Job Description spacy_sentencized_num_punctuations                  5948 non-null   int64
# dtypes: float64(23), int64(30), object(19)
# memory usage: 3.3+ MB
# ====================
# Warmth:
# --------------------
# Warmth Counts:
# Warmth
# 0    4333
# 1    1615
# Name: count, dtype: int64
# --------------------
# Warmth Percentages:
# Warmth
# 0   72.800
# 1   27.200
# Name: proportion, dtype: float64
# --------------------
# Min Warmth value: 0.0
# Max Warmth value: 1.0
# --------------------
# Warmth Mean: 0.272
# --------------------
# Warmth Standard Deviation: 0.445
# ====================
# Competence:
# --------------------
# Competence Counts:
# Competence
# 0    3181
# 1    2767
# Name: count, dtype: int64
# --------------------
# Competence Percentages:
# Competence
# 0   53.500
# 1   46.500
# Name: proportion, dtype: float64
# --------------------
# Min Competence value: 0.0
# Max Competence value: 1.0
# --------------------
# Competence Mean: 0.465
# --------------------
# Competence Standard Deviation: 0.499

# %%
df_manual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5948 entries, 0 to 5954
# Data columns (total 72 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Job ID                                                              5948 non-null   object
#  1   Job Description spacy_sentencized                                   5948 non-null   object
#  2   Warmth                                                              5948 non-null   int64
#  3   Competence                                                          5948 non-null   int64
#  4   Dutch Requirement in Sentence                                       5948 non-null   object
#  5   English Requirement in Sentence                                     5948 non-null   object
#  6   Dutch Requirement in Sentence_No                                    5948 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                                   5948 non-null   int64
#  8   English Requirement in Sentence_No                                  5948 non-null   int64
#  9   English Requirement in Sentence_Yes                                 5948 non-null   int64
#  10  Search Keyword                                                      5948 non-null   object
#  11  Platform                                                            5948 non-null   object
#  12  Job Title                                                           5948 non-null   object
#  13  Company Name                                                        5948 non-null   object
#  14  Location                                                            5948 non-null   object
#  15  Industry                                                            290 non-null    object
#  16  Dutch Requirement in Job Ad                                         5948 non-null   object
#  17  English Requirement in Job Ad                                       5948 non-null   object
#  18  Dutch Requirement in Job Ad_No                                      5948 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                                     5948 non-null   int64
#  20  English Requirement in Job Ad_No                                    5948 non-null   int64
#  21  English Requirement in Job Ad_Yes                                   5948 non-null   int64
#  22  Sector Code                                                         5948 non-null   object
#  23  Sector                                                              5948 non-null   object
#  24  Keywords Count                                                      5948 non-null   float64
#  25  Gender_Female_n                                                     5948 non-null   float64
#  26  Gender_Female_% per Sector                                          5948 non-null   float64
#  27  Gender_Female_% per Social Category                                 5948 non-null   float64
#  28  Gender_Female_% per Workforce                                       5948 non-null   float64
#  29  Gender_Male_n                                                       5948 non-null   float64
#  30  Gender_Male_% per Sector                                            5948 non-null   float64
#  31  Gender_Male_% per Social Category                                   5948 non-null   float64
#  32  Gender_Male_% per Workforce                                         5948 non-null   float64
#  33  Gender                                                              5948 non-null   object
#  34  Age_Older_n                                                         5948 non-null   float64
#  35  Age_Older_% per Sector                                              5948 non-null   float64
#  36  Age_Older_% per Social Category                                     5948 non-null   float64
#  37  Age_Older_% per Workforce                                           5948 non-null   float64
#  38  Age_Younger_n                                                       5948 non-null   float64
#  39  Age_Younger_% per Sector                                            5948 non-null   float64
#  40  Age_Younger_% per Social Category                                   5948 non-null   float64
#  41  Age_Younger_% per Workforce                                         5948 non-null   float64
#  42  Age                                                                 5948 non-null   object
#  43  Sector_n                                                            5948 non-null   float64
#  44  % Sector per Workforce                                              5948 non-null   float64
#  45  Sector Job Advertisement Count                                      5948 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count                   5948 non-null   int64
#  47  Sector Age Designation Job Advertisement Count                      5948 non-null   int64
#  48  Gender_Female                                                       5948 non-null   int64
#  49  Gender_Male                                                         5948 non-null   int64
#  50  Gender_Mixed                                                        5948 non-null   int64
#  51  Age_Mixed                                                           5948 non-null   int64
#  52  Age_Older                                                           5948 non-null   int64
#  53  Age_Younger                                                         5948 non-null   int64
#  54  Gender_Num                                                          5948 non-null   int64
#  55  Age_Num                                                             5948 non-null   int64
#  56  Interaction_Female_Older_% per Sector                               5948 non-null   float64
#  57  Interaction_Female_Younger_% per Sector                             5948 non-null   float64
#  58  Interaction_Male_Older_% per Sector                                 5948 non-null   float64
#  59  Interaction_Male_Younger_% per Sector                               5948 non-null   float64
#  60  Platform_Num                                                        5948 non-null   int64
#  61  Platform_LinkedIn                                                   5948 non-null   int64
#  62  Platform_Indeed                                                     5948 non-null   int64
#  63  Platform_Glassdoor                                                  5948 non-null   int64
#  64  Job Description spacy_sentencized_lower                             5948 non-null   object
#  65  Job Description spacy_tokenized                                     5948 non-null   object
#  66  Job Description spacy_sentencized_cleaned                           5948 non-null   object
#  67  Job Description spacy_sentencized_num_words                         5948 non-null   int64
#  68  Job Description spacy_sentencized_num_unique_words                  5948 non-null   int64
#  69  Job Description spacy_sentencized_num_chars                         5948 non-null   int64
#  70  Job Description spacy_sentencized_num_chars_no_whitespact_and_punt  5948 non-null   int64
#  71  Job Description spacy_sentencized_num_punctuations                  5948 non-null   int64
# dtypes: float64(23), int64(30), object(19)
# memory usage: 3.3+ MB

# %%
df_manual['Job Description spacy_sentencized'].head()
# Out:
# 0    Through daily contact, as a partner of sales a...
# 1                 This role is truly cross functional.
# 2    The other part of your time would be spent as ...
# 3    Being the expert on your product also means yo...
# 4    Your mindset is commercial, result oriented an...
# Name: Job Description spacy_sentencized, dtype: object

# %%
df_manual['Job Description spacy_sentencized'].describe()
# Out:
# count                5948
# unique               5110
# top       Job Description
# freq                   12
# Name: Job Description spacy_sentencized, dtype: object

# %%
df_manual['Job Description spacy_sentencized'] = df_manual['Job Description spacy_sentencized'].progress_apply(lambda x: unicodedata.normalize('NFKD', x.encode('ascii', 'ignore').decode('utf-8', 'ignore')))
# Out:
# progress-bar:   0%|          | 0/5948 [00:00<?, ?it/s]

# %%
# %%time
# Tokenize with NLTK
stop_words = set(stopwords.words('english'))
punctuations = list(string.punctuation)
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()

df_manual['Job Description nltk_tokenized'] = df_manual['Job Description spacy_sentencized'].progress_apply(
    lambda job_sentence: [
        str(token.strip().lower())
        for token in word_tokenize(job_sentence)
        if len(token) != 0
        and token != '...'
        and not token.lower() in nan_list
        and not token.lower() in custom_punct_chars
        and not token.lower() in set(stopwords.words('english'))
        and not token.lower() in list(string.punctuation)
        and not token.lower() in list(string.whitespace)
        and (t.lower() in list(string.printable) for t in token.lower())
    ]
)

assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
df_manual.to_pickle(f'{df_save_dir}df_manual_tokenized_spacy_nltk.pkl')
df_manual.to_csv(f'{df_save_dir}df_manual_tokenized_spacy_nltk.csv')
# Out:
# progress-bar:   0%|          | 0/5948 [00:00<?, ?it/s]
# CPU times: user 6.76 s, sys: 2.08 s, total: 8.85 s
# Wall time: 14.8 s

# %%
df_manual['Job Description nltk_tokenized'].head()
# Out:
# 0    [daily, contact, partner, sales, account, mana...
# 1                     [role, truly, cross, functional]
# 2    [part, time, would, spent, application, lead, ...
# 3    [expert, product, also, means, organize, custo...
# 4    [mindset, commercial, result, oriented, servic...
# Name: Job Description nltk_tokenized, dtype: object

# %%
df_manual['Job Description nltk_tokenized'].describe()
# Out:
# count     5948
# unique    4941
# top         []
# freq        34
# Name: Job Description nltk_tokenized, dtype: object

# %%
# Keep the some of the [] rows because they contain 'Who are we', 'What we do', etc. and remove '1. ' and '2. ' etc. abd 'T)'
df_manual = df_manual.loc[~df_manual['Job Description spacy_sentencized'].str.match('^\d\.|.\)')]

# %%
df_manual['Job Description spacy_sentencized'].head()
# Out:
# 0    Through daily contact, as a partner of sales a...
# 1                 This role is truly cross functional.
# 2    The other part of your time would be spent as ...
# 3    Being the expert on your product also means yo...
# 4    Your mindset is commercial, result oriented an...
# Name: Job Description spacy_sentencized, dtype: object

# %%
df_manual['Job Description spacy_sentencized'].describe()
# Out:
# count                5947
# unique               5109
# top       Job Description
# freq                   12
# Name: Job Description spacy_sentencized, dtype: object

# %%
df_manual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5947 entries, 0 to 5954
# Data columns (total 73 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Job ID                                                              5947 non-null   object
#  1   Job Description spacy_sentencized                                   5947 non-null   object
#  2   Warmth                                                              5947 non-null   int64
#  3   Competence                                                          5947 non-null   int64
#  4   Dutch Requirement in Sentence                                       5947 non-null   object
#  5   English Requirement in Sentence                                     5947 non-null   object
#  6   Dutch Requirement in Sentence_No                                    5947 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                                   5947 non-null   int64
#  8   English Requirement in Sentence_No                                  5947 non-null   int64
#  9   English Requirement in Sentence_Yes                                 5947 non-null   int64
#  10  Search Keyword                                                      5947 non-null   object
#  11  Platform                                                            5947 non-null   object
#  12  Job Title                                                           5947 non-null   object
#  13  Company Name                                                        5947 non-null   object
#  14  Location                                                            5947 non-null   object
#  15  Industry                                                            290 non-null    object
#  16  Dutch Requirement in Job Ad                                         5947 non-null   object
#  17  English Requirement in Job Ad                                       5947 non-null   object
#  18  Dutch Requirement in Job Ad_No                                      5947 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                                     5947 non-null   int64
#  20  English Requirement in Job Ad_No                                    5947 non-null   int64
#  21  English Requirement in Job Ad_Yes                                   5947 non-null   int64
#  22  Sector Code                                                         5947 non-null   object
#  23  Sector                                                              5947 non-null   object
#  24  Keywords Count                                                      5947 non-null   float64
#  25  Gender_Female_n                                                     5947 non-null   float64
#  26  Gender_Female_% per Sector                                          5947 non-null   float64
#  27  Gender_Female_% per Social Category                                 5947 non-null   float64
#  28  Gender_Female_% per Workforce                                       5947 non-null   float64
#  29  Gender_Male_n                                                       5947 non-null   float64
#  30  Gender_Male_% per Sector                                            5947 non-null   float64
#  31  Gender_Male_% per Social Category                                   5947 non-null   float64
#  32  Gender_Male_% per Workforce                                         5947 non-null   float64
#  33  Gender                                                              5947 non-null   object
#  34  Age_Older_n                                                         5947 non-null   float64
#  35  Age_Older_% per Sector                                              5947 non-null   float64
#  36  Age_Older_% per Social Category                                     5947 non-null   float64
#  37  Age_Older_% per Workforce                                           5947 non-null   float64
#  38  Age_Younger_n                                                       5947 non-null   float64
#  39  Age_Younger_% per Sector                                            5947 non-null   float64
#  40  Age_Younger_% per Social Category                                   5947 non-null   float64
#  41  Age_Younger_% per Workforce                                         5947 non-null   float64
#  42  Age                                                                 5947 non-null   object
#  43  Sector_n                                                            5947 non-null   float64
#  44  % Sector per Workforce                                              5947 non-null   float64
#  45  Sector Job Advertisement Count                                      5947 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count                   5947 non-null   int64
#  47  Sector Age Designation Job Advertisement Count                      5947 non-null   int64
#  48  Gender_Female                                                       5947 non-null   int64
#  49  Gender_Male                                                         5947 non-null   int64
#  50  Gender_Mixed                                                        5947 non-null   int64
#  51  Age_Mixed                                                           5947 non-null   int64
#  52  Age_Older                                                           5947 non-null   int64
#  53  Age_Younger                                                         5947 non-null   int64
#  54  Gender_Num                                                          5947 non-null   int64
#  55  Age_Num                                                             5947 non-null   int64
#  56  Interaction_Female_Older_% per Sector                               5947 non-null   float64
#  57  Interaction_Female_Younger_% per Sector                             5947 non-null   float64
#  58  Interaction_Male_Older_% per Sector                                 5947 non-null   float64
#  59  Interaction_Male_Younger_% per Sector                               5947 non-null   float64
#  60  Platform_Num                                                        5947 non-null   int64
#  61  Platform_LinkedIn                                                   5947 non-null   int64
#  62  Platform_Indeed                                                     5947 non-null   int64
#  63  Platform_Glassdoor                                                  5947 non-null   int64
#  64  Job Description spacy_sentencized_lower                             5947 non-null   object
#  65  Job Description spacy_tokenized                                     5947 non-null   object
#  66  Job Description spacy_sentencized_cleaned                           5947 non-null   object
#  67  Job Description spacy_sentencized_num_words                         5947 non-null   int64
#  68  Job Description spacy_sentencized_num_unique_words                  5947 non-null   int64
#  69  Job Description spacy_sentencized_num_chars                         5947 non-null   int64
#  70  Job Description spacy_sentencized_num_chars_no_whitespact_and_punt  5947 non-null   int64
#  71  Job Description spacy_sentencized_num_punctuations                  5947 non-null   int64
#  72  Job Description nltk_tokenized                                      5947 non-null   object
# dtypes: float64(23), int64(30), object(20)
# memory usage: 3.4+ MB

# %%
assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
df_manual.to_pickle(f'{df_save_dir}df_manual_tokenized_spacy_nltk.pkl')
df_manual.to_csv(f'{df_save_dir}df_manual_tokenized_spacy_nltk.csv')

# %% [markdown]
# ## Use gensim to tokenize sentences

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_TOKENIZED_SPACY_NLTK
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %%
import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

mod = sys.modules[__name__]

code_dir = None
code_dir_name = 'Code'
unwanted_subdir_name = 'Analysis'

if code_dir_name not in str(Path.cwd()).split('/')[-1]:
    for _ in range(5):

        parent_path = str(Path.cwd().parents[_]).split('/')[-1]

        if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

            code_dir = str(Path.cwd().parents[_])

            if code_dir is not None:
                break
else:
    code_dir = str(Path.cwd())
sys.path.append(code_dir)

# %load_ext autoreload
# %autoreload 2

# %%
from setup_module.imports import * # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# %%
df_manual = pd.read_pickle(f'{df_save_dir}df_manual_tokenized_spacy_nltk.pkl')

# %%
# Warmth 1 = 1595 (24.90%), Competence 1 = 2836 (44.30%)
get_df_info(df_manual, ivs_all=dvs)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 5947 entries, 0 to 5954
# Data columns (total 73 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Job ID                                                              5947 non-null   object
#  1   Job Description spacy_sentencized                                   5947 non-null   object
#  2   Warmth                                                              5947 non-null   int64
#  3   Competence                                                          5947 non-null   int64
#  4   Dutch Requirement in Sentence                                       5947 non-null   object
#  5   English Requirement in Sentence                                     5947 non-null   object
#  6   Dutch Requirement in Sentence_No                                    5947 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                                   5947 non-null   int64
#  8   English Requirement in Sentence_No                                  5947 non-null   int64
#  9   English Requirement in Sentence_Yes                                 5947 non-null   int64
#  10  Search Keyword                                                      5947 non-null   object
#  11  Platform                                                            5947 non-null   object
#  12  Job Title                                                           5947 non-null   object
#  13  Company Name                                                        5947 non-null   object
#  14  Location                                                            5947 non-null   object
#  15  Industry                                                            290 non-null    object
#  16  Dutch Requirement in Job Ad                                         5947 non-null   object
#  17  English Requirement in Job Ad                                       5947 non-null   object
#  18  Dutch Requirement in Job Ad_No                                      5947 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                                     5947 non-null   int64
#  20  English Requirement in Job Ad_No                                    5947 non-null   int64
#  21  English Requirement in Job Ad_Yes                                   5947 non-null   int64
#  22  Sector Code                                                         5947 non-null   object
#  23  Sector                                                              5947 non-null   object
#  24  Keywords Count                                                      5947 non-null   float64
#  25  Gender_Female_n                                                     5947 non-null   float64
#  26  Gender_Female_% per Sector                                          5947 non-null   float64
#  27  Gender_Female_% per Social Category                                 5947 non-null   float64
#  28  Gender_Female_% per Workforce                                       5947 non-null   float64
#  29  Gender_Male_n                                                       5947 non-null   float64
#  30  Gender_Male_% per Sector                                            5947 non-null   float64
#  31  Gender_Male_% per Social Category                                   5947 non-null   float64
#  32  Gender_Male_% per Workforce                                         5947 non-null   float64
#  33  Gender                                                              5947 non-null   object
#  34  Age_Older_n                                                         5947 non-null   float64
#  35  Age_Older_% per Sector                                              5947 non-null   float64
#  36  Age_Older_% per Social Category                                     5947 non-null   float64
#  37  Age_Older_% per Workforce                                           5947 non-null   float64
#  38  Age_Younger_n                                                       5947 non-null   float64
#  39  Age_Younger_% per Sector                                            5947 non-null   float64
#  40  Age_Younger_% per Social Category                                   5947 non-null   float64
#  41  Age_Younger_% per Workforce                                         5947 non-null   float64
#  42  Age                                                                 5947 non-null   object
#  43  Sector_n                                                            5947 non-null   float64
#  44  % Sector per Workforce                                              5947 non-null   float64
#  45  Sector Job Advertisement Count                                      5947 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count                   5947 non-null   int64
#  47  Sector Age Designation Job Advertisement Count                      5947 non-null   int64
#  48  Gender_Female                                                       5947 non-null   int64
#  49  Gender_Male                                                         5947 non-null   int64
#  50  Gender_Mixed                                                        5947 non-null   int64
#  51  Age_Mixed                                                           5947 non-null   int64
#  52  Age_Older                                                           5947 non-null   int64
#  53  Age_Younger                                                         5947 non-null   int64
#  54  Gender_Num                                                          5947 non-null   int64
#  55  Age_Num                                                             5947 non-null   int64
#  56  Interaction_Female_Older_% per Sector                               5947 non-null   float64
#  57  Interaction_Female_Younger_% per Sector                             5947 non-null   float64
#  58  Interaction_Male_Older_% per Sector                                 5947 non-null   float64
#  59  Interaction_Male_Younger_% per Sector                               5947 non-null   float64
#  60  Platform_Num                                                        5947 non-null   int64
#  61  Platform_LinkedIn                                                   5947 non-null   int64
#  62  Platform_Indeed                                                     5947 non-null   int64
#  63  Platform_Glassdoor                                                  5947 non-null   int64
#  64  Job Description spacy_sentencized_lower                             5947 non-null   object
#  65  Job Description spacy_tokenized                                     5947 non-null   object
#  66  Job Description spacy_sentencized_cleaned                           5947 non-null   object
#  67  Job Description spacy_sentencized_num_words                         5947 non-null   int64
#  68  Job Description spacy_sentencized_num_unique_words                  5947 non-null   int64
#  69  Job Description spacy_sentencized_num_chars                         5947 non-null   int64
#  70  Job Description spacy_sentencized_num_chars_no_whitespact_and_punt  5947 non-null   int64
#  71  Job Description spacy_sentencized_num_punctuations                  5947 non-null   int64
#  72  Job Description nltk_tokenized                                      5947 non-null   object
# dtypes: float64(23), int64(30), object(20)
# memory usage: 3.4+ MB
# ====================
# Warmth:
# --------------------
# Warmth Counts:
# Warmth
# 0    4332
# 1    1615
# Name: count, dtype: int64
# --------------------
# Warmth Percentages:
# Warmth
# 0   72.800
# 1   27.200
# Name: proportion, dtype: float64
# --------------------
# Min Warmth value: 0.0
# Max Warmth value: 1.0
# --------------------
# Warmth Mean: 0.272
# --------------------
# Warmth Standard Deviation: 0.445
# ====================
# Competence:
# --------------------
# Competence Counts:
# Competence
# 0    3180
# 1    2767
# Name: count, dtype: int64
# --------------------
# Competence Percentages:
# Competence
# 0   53.500
# 1   46.500
# Name: proportion, dtype: float64
# --------------------
# Min Competence value: 0.0
# Max Competence value: 1.0
# --------------------
# Competence Mean: 0.465
# --------------------
# Competence Standard Deviation: 0.499

# %%
df_manual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5947 entries, 0 to 5954
# Data columns (total 73 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Job ID                                                              5947 non-null   object
#  1   Job Description spacy_sentencized                                   5947 non-null   object
#  2   Warmth                                                              5947 non-null   int64
#  3   Competence                                                          5947 non-null   int64
#  4   Dutch Requirement in Sentence                                       5947 non-null   object
#  5   English Requirement in Sentence                                     5947 non-null   object
#  6   Dutch Requirement in Sentence_No                                    5947 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                                   5947 non-null   int64
#  8   English Requirement in Sentence_No                                  5947 non-null   int64
#  9   English Requirement in Sentence_Yes                                 5947 non-null   int64
#  10  Search Keyword                                                      5947 non-null   object
#  11  Platform                                                            5947 non-null   object
#  12  Job Title                                                           5947 non-null   object
#  13  Company Name                                                        5947 non-null   object
#  14  Location                                                            5947 non-null   object
#  15  Industry                                                            290 non-null    object
#  16  Dutch Requirement in Job Ad                                         5947 non-null   object
#  17  English Requirement in Job Ad                                       5947 non-null   object
#  18  Dutch Requirement in Job Ad_No                                      5947 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                                     5947 non-null   int64
#  20  English Requirement in Job Ad_No                                    5947 non-null   int64
#  21  English Requirement in Job Ad_Yes                                   5947 non-null   int64
#  22  Sector Code                                                         5947 non-null   object
#  23  Sector                                                              5947 non-null   object
#  24  Keywords Count                                                      5947 non-null   float64
#  25  Gender_Female_n                                                     5947 non-null   float64
#  26  Gender_Female_% per Sector                                          5947 non-null   float64
#  27  Gender_Female_% per Social Category                                 5947 non-null   float64
#  28  Gender_Female_% per Workforce                                       5947 non-null   float64
#  29  Gender_Male_n                                                       5947 non-null   float64
#  30  Gender_Male_% per Sector                                            5947 non-null   float64
#  31  Gender_Male_% per Social Category                                   5947 non-null   float64
#  32  Gender_Male_% per Workforce                                         5947 non-null   float64
#  33  Gender                                                              5947 non-null   object
#  34  Age_Older_n                                                         5947 non-null   float64
#  35  Age_Older_% per Sector                                              5947 non-null   float64
#  36  Age_Older_% per Social Category                                     5947 non-null   float64
#  37  Age_Older_% per Workforce                                           5947 non-null   float64
#  38  Age_Younger_n                                                       5947 non-null   float64
#  39  Age_Younger_% per Sector                                            5947 non-null   float64
#  40  Age_Younger_% per Social Category                                   5947 non-null   float64
#  41  Age_Younger_% per Workforce                                         5947 non-null   float64
#  42  Age                                                                 5947 non-null   object
#  43  Sector_n                                                            5947 non-null   float64
#  44  % Sector per Workforce                                              5947 non-null   float64
#  45  Sector Job Advertisement Count                                      5947 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count                   5947 non-null   int64
#  47  Sector Age Designation Job Advertisement Count                      5947 non-null   int64
#  48  Gender_Female                                                       5947 non-null   int64
#  49  Gender_Male                                                         5947 non-null   int64
#  50  Gender_Mixed                                                        5947 non-null   int64
#  51  Age_Mixed                                                           5947 non-null   int64
#  52  Age_Older                                                           5947 non-null   int64
#  53  Age_Younger                                                         5947 non-null   int64
#  54  Gender_Num                                                          5947 non-null   int64
#  55  Age_Num                                                             5947 non-null   int64
#  56  Interaction_Female_Older_% per Sector                               5947 non-null   float64
#  57  Interaction_Female_Younger_% per Sector                             5947 non-null   float64
#  58  Interaction_Male_Older_% per Sector                                 5947 non-null   float64
#  59  Interaction_Male_Younger_% per Sector                               5947 non-null   float64
#  60  Platform_Num                                                        5947 non-null   int64
#  61  Platform_LinkedIn                                                   5947 non-null   int64
#  62  Platform_Indeed                                                     5947 non-null   int64
#  63  Platform_Glassdoor                                                  5947 non-null   int64
#  64  Job Description spacy_sentencized_lower                             5947 non-null   object
#  65  Job Description spacy_tokenized                                     5947 non-null   object
#  66  Job Description spacy_sentencized_cleaned                           5947 non-null   object
#  67  Job Description spacy_sentencized_num_words                         5947 non-null   int64
#  68  Job Description spacy_sentencized_num_unique_words                  5947 non-null   int64
#  69  Job Description spacy_sentencized_num_chars                         5947 non-null   int64
#  70  Job Description spacy_sentencized_num_chars_no_whitespact_and_punt  5947 non-null   int64
#  71  Job Description spacy_sentencized_num_punctuations                  5947 non-null   int64
#  72  Job Description nltk_tokenized                                      5947 non-null   object
# dtypes: float64(23), int64(30), object(20)
# memory usage: 3.4+ MB

# %%
# %%time
df_manual['Job Description gensim_tokenized'] = df_manual['Job Description spacy_sentencized'].progress_apply(
    lambda sentence: preprocess_string(re.sub(pattern, '.', sentence.strip().lower()))
)

assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
df_manual.to_pickle(f'{df_save_dir}df_manual_tokenized_spacy_nltk_gensim.pkl')
df_manual.to_csv(f'{df_save_dir}df_manual_tokenized_spacy_nltk_gensim.csv')
# Out:
# progress-bar:   0%|          | 0/5947 [00:00<?, ?it/s]
# CPU times: user 779 ms, sys: 22.8 ms, total: 802 ms
# Wall time: 1.35 s

# %%
df_manual['Job Description gensim_tokenized'].head()
# Out:
# 0    [daili, contact, partner, sale, account, manag...
# 1                       [role, truli, cross, function]
# 2    [time, spent, applic, lead, maintain, intern, ...
# 3    [expert, product, mean, organ, custom, worksho...
# 4    [mindset, commerci, result, orient, servic, mi...
# Name: Job Description gensim_tokenized, dtype: object

# %%
df_manual['Job Description gensim_tokenized'].describe()
# Out:
# count     5947
# unique    4847
# top         []
# freq        78
# Name: Job Description gensim_tokenized, dtype: object

# %%
# Keep the some of the [] rows because they contain 'Who are we', 'What we do', etc. and remove '1. ' and '2. ' etc.
df_manual = df_manual.loc[~df_manual['Job Description spacy_sentencized'].str.match('^\d\.|.\)')]

# %%
df_manual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5947 entries, 0 to 5954
# Data columns (total 74 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Job ID                                                              5947 non-null   object
#  1   Job Description spacy_sentencized                                   5947 non-null   object
#  2   Warmth                                                              5947 non-null   int64
#  3   Competence                                                          5947 non-null   int64
#  4   Dutch Requirement in Sentence                                       5947 non-null   object
#  5   English Requirement in Sentence                                     5947 non-null   object
#  6   Dutch Requirement in Sentence_No                                    5947 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                                   5947 non-null   int64
#  8   English Requirement in Sentence_No                                  5947 non-null   int64
#  9   English Requirement in Sentence_Yes                                 5947 non-null   int64
#  10  Search Keyword                                                      5947 non-null   object
#  11  Platform                                                            5947 non-null   object
#  12  Job Title                                                           5947 non-null   object
#  13  Company Name                                                        5947 non-null   object
#  14  Location                                                            5947 non-null   object
#  15  Industry                                                            290 non-null    object
#  16  Dutch Requirement in Job Ad                                         5947 non-null   object
#  17  English Requirement in Job Ad                                       5947 non-null   object
#  18  Dutch Requirement in Job Ad_No                                      5947 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                                     5947 non-null   int64
#  20  English Requirement in Job Ad_No                                    5947 non-null   int64
#  21  English Requirement in Job Ad_Yes                                   5947 non-null   int64
#  22  Sector Code                                                         5947 non-null   object
#  23  Sector                                                              5947 non-null   object
#  24  Keywords Count                                                      5947 non-null   float64
#  25  Gender_Female_n                                                     5947 non-null   float64
#  26  Gender_Female_% per Sector                                          5947 non-null   float64
#  27  Gender_Female_% per Social Category                                 5947 non-null   float64
#  28  Gender_Female_% per Workforce                                       5947 non-null   float64
#  29  Gender_Male_n                                                       5947 non-null   float64
#  30  Gender_Male_% per Sector                                            5947 non-null   float64
#  31  Gender_Male_% per Social Category                                   5947 non-null   float64
#  32  Gender_Male_% per Workforce                                         5947 non-null   float64
#  33  Gender                                                              5947 non-null   object
#  34  Age_Older_n                                                         5947 non-null   float64
#  35  Age_Older_% per Sector                                              5947 non-null   float64
#  36  Age_Older_% per Social Category                                     5947 non-null   float64
#  37  Age_Older_% per Workforce                                           5947 non-null   float64
#  38  Age_Younger_n                                                       5947 non-null   float64
#  39  Age_Younger_% per Sector                                            5947 non-null   float64
#  40  Age_Younger_% per Social Category                                   5947 non-null   float64
#  41  Age_Younger_% per Workforce                                         5947 non-null   float64
#  42  Age                                                                 5947 non-null   object
#  43  Sector_n                                                            5947 non-null   float64
#  44  % Sector per Workforce                                              5947 non-null   float64
#  45  Sector Job Advertisement Count                                      5947 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count                   5947 non-null   int64
#  47  Sector Age Designation Job Advertisement Count                      5947 non-null   int64
#  48  Gender_Female                                                       5947 non-null   int64
#  49  Gender_Male                                                         5947 non-null   int64
#  50  Gender_Mixed                                                        5947 non-null   int64
#  51  Age_Mixed                                                           5947 non-null   int64
#  52  Age_Older                                                           5947 non-null   int64
#  53  Age_Younger                                                         5947 non-null   int64
#  54  Gender_Num                                                          5947 non-null   int64
#  55  Age_Num                                                             5947 non-null   int64
#  56  Interaction_Female_Older_% per Sector                               5947 non-null   float64
#  57  Interaction_Female_Younger_% per Sector                             5947 non-null   float64
#  58  Interaction_Male_Older_% per Sector                                 5947 non-null   float64
#  59  Interaction_Male_Younger_% per Sector                               5947 non-null   float64
#  60  Platform_Num                                                        5947 non-null   int64
#  61  Platform_LinkedIn                                                   5947 non-null   int64
#  62  Platform_Indeed                                                     5947 non-null   int64
#  63  Platform_Glassdoor                                                  5947 non-null   int64
#  64  Job Description spacy_sentencized_lower                             5947 non-null   object
#  65  Job Description spacy_tokenized                                     5947 non-null   object
#  66  Job Description spacy_sentencized_cleaned                           5947 non-null   object
#  67  Job Description spacy_sentencized_num_words                         5947 non-null   int64
#  68  Job Description spacy_sentencized_num_unique_words                  5947 non-null   int64
#  69  Job Description spacy_sentencized_num_chars                         5947 non-null   int64
#  70  Job Description spacy_sentencized_num_chars_no_whitespact_and_punt  5947 non-null   int64
#  71  Job Description spacy_sentencized_num_punctuations                  5947 non-null   int64
#  72  Job Description nltk_tokenized                                      5947 non-null   object
#  73  Job Description gensim_tokenized                                    5947 non-null   object
# dtypes: float64(23), int64(30), object(21)
# memory usage: 3.4+ MB

# %%
assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
df_manual.to_pickle(f'{df_save_dir}df_manual_tokenized_spacy_nltk_gensim.pkl')
df_manual.to_csv(f'{df_save_dir}df_manual_tokenized_spacy_nltk_gensim.csv')

# %% [markdown]
# ## Use BERT to tokenize sentences

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_TOKENIZED_SPACY_NLTK_GENSIM
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %%
import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

mod = sys.modules[__name__]

code_dir = None
code_dir_name = 'Code'
unwanted_subdir_name = 'Analysis'

if code_dir_name not in str(Path.cwd()).split('/')[-1]:
    for _ in range(5):

        parent_path = str(Path.cwd().parents[_]).split('/')[-1]

        if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

            code_dir = str(Path.cwd().parents[_])

            if code_dir is not None:
                break
else:
    code_dir = str(Path.cwd())
sys.path.append(code_dir)

# %load_ext autoreload
# %autoreload 2

# %%
from setup_module.imports import * # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# %%
import evaluate
from accelerate import Accelerator

from transformers import (
    AdamW,
    AutoConfig,
    AutoModel,
    AutoModelForSequenceClassification,
    AutoModelForTokenClassification,
    AutoTokenizer,
    BertConfig,
    BertForPreTraining,
    BertForSequenceClassification,
    BertModel,
    BertTokenizer,
    BertTokenizerFast,
    BitsAndBytesConfig,
    DistilBertForSequenceClassification,
    DistilBertTokenizerFast,
    EarlyStoppingCallback,
    GPT2Config,
    GPT2ForSequenceClassification,
    GPT2Model,
    GPT2TokenizerFast,
    GPTJConfig,
    GPTJForSequenceClassification,
    GPTJModel,
    GPTNeoXConfig,
    GPTNeoXForSequenceClassification,
    GPTNeoXTokenizerFast,
    LlamaConfig,
    LlamaForSequenceClassification,
    LlamaTokenizer,
    LlamaTokenizerFast,
    MegatronBertForSequenceClassification,
    OpenAIGPTConfig,
    OpenAIGPTForSequenceClassification,
    OpenAIGPTTokenizerFast,
    TextClassificationPipeline,
    TFGPTJForSequenceClassification,
    TFGPTJModel,
    TokenClassificationPipeline,
    Trainer,
    TrainingArguments,
    get_linear_schedule_with_warmup,
    pipeline,
)
from transformers.integrations import (
    TensorBoardCallback,
    is_optuna_available,
    is_ray_available,
)
accelerator = Accelerator()

# %%
df_manual = pd.read_pickle(f'{df_save_dir}df_manual_tokenized_spacy_nltk_gensim.pkl')

# %%
# Warmth 1 = 1504 (24.90%), Competence 1 = 2709 (44.30%)
get_df_info(df_manual, ivs_all=dvs)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 5947 entries, 0 to 5954
# Data columns (total 74 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Job ID                                                              5947 non-null   object
#  1   Job Description spacy_sentencized                                   5947 non-null   object
#  2   Warmth                                                              5947 non-null   int64
#  3   Competence                                                          5947 non-null   int64
#  4   Dutch Requirement in Sentence                                       5947 non-null   object
#  5   English Requirement in Sentence                                     5947 non-null   object
#  6   Dutch Requirement in Sentence_No                                    5947 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                                   5947 non-null   int64
#  8   English Requirement in Sentence_No                                  5947 non-null   int64
#  9   English Requirement in Sentence_Yes                                 5947 non-null   int64
#  10  Search Keyword                                                      5947 non-null   object
#  11  Platform                                                            5947 non-null   object
#  12  Job Title                                                           5947 non-null   object
#  13  Company Name                                                        5947 non-null   object
#  14  Location                                                            5947 non-null   object
#  15  Industry                                                            290 non-null    object
#  16  Dutch Requirement in Job Ad                                         5947 non-null   object
#  17  English Requirement in Job Ad                                       5947 non-null   object
#  18  Dutch Requirement in Job Ad_No                                      5947 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                                     5947 non-null   int64
#  20  English Requirement in Job Ad_No                                    5947 non-null   int64
#  21  English Requirement in Job Ad_Yes                                   5947 non-null   int64
#  22  Sector Code                                                         5947 non-null   object
#  23  Sector                                                              5947 non-null   object
#  24  Keywords Count                                                      5947 non-null   float64
#  25  Gender_Female_n                                                     5947 non-null   float64
#  26  Gender_Female_% per Sector                                          5947 non-null   float64
#  27  Gender_Female_% per Social Category                                 5947 non-null   float64
#  28  Gender_Female_% per Workforce                                       5947 non-null   float64
#  29  Gender_Male_n                                                       5947 non-null   float64
#  30  Gender_Male_% per Sector                                            5947 non-null   float64
#  31  Gender_Male_% per Social Category                                   5947 non-null   float64
#  32  Gender_Male_% per Workforce                                         5947 non-null   float64
#  33  Gender                                                              5947 non-null   object
#  34  Age_Older_n                                                         5947 non-null   float64
#  35  Age_Older_% per Sector                                              5947 non-null   float64
#  36  Age_Older_% per Social Category                                     5947 non-null   float64
#  37  Age_Older_% per Workforce                                           5947 non-null   float64
#  38  Age_Younger_n                                                       5947 non-null   float64
#  39  Age_Younger_% per Sector                                            5947 non-null   float64
#  40  Age_Younger_% per Social Category                                   5947 non-null   float64
#  41  Age_Younger_% per Workforce                                         5947 non-null   float64
#  42  Age                                                                 5947 non-null   object
#  43  Sector_n                                                            5947 non-null   float64
#  44  % Sector per Workforce                                              5947 non-null   float64
#  45  Sector Job Advertisement Count                                      5947 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count                   5947 non-null   int64
#  47  Sector Age Designation Job Advertisement Count                      5947 non-null   int64
#  48  Gender_Female                                                       5947 non-null   int64
#  49  Gender_Male                                                         5947 non-null   int64
#  50  Gender_Mixed                                                        5947 non-null   int64
#  51  Age_Mixed                                                           5947 non-null   int64
#  52  Age_Older                                                           5947 non-null   int64
#  53  Age_Younger                                                         5947 non-null   int64
#  54  Gender_Num                                                          5947 non-null   int64
#  55  Age_Num                                                             5947 non-null   int64
#  56  Interaction_Female_Older_% per Sector                               5947 non-null   float64
#  57  Interaction_Female_Younger_% per Sector                             5947 non-null   float64
#  58  Interaction_Male_Older_% per Sector                                 5947 non-null   float64
#  59  Interaction_Male_Younger_% per Sector                               5947 non-null   float64
#  60  Platform_Num                                                        5947 non-null   int64
#  61  Platform_LinkedIn                                                   5947 non-null   int64
#  62  Platform_Indeed                                                     5947 non-null   int64
#  63  Platform_Glassdoor                                                  5947 non-null   int64
#  64  Job Description spacy_sentencized_lower                             5947 non-null   object
#  65  Job Description spacy_tokenized                                     5947 non-null   object
#  66  Job Description spacy_sentencized_cleaned                           5947 non-null   object
#  67  Job Description spacy_sentencized_num_words                         5947 non-null   int64
#  68  Job Description spacy_sentencized_num_unique_words                  5947 non-null   int64
#  69  Job Description spacy_sentencized_num_chars                         5947 non-null   int64
#  70  Job Description spacy_sentencized_num_chars_no_whitespact_and_punt  5947 non-null   int64
#  71  Job Description spacy_sentencized_num_punctuations                  5947 non-null   int64
#  72  Job Description nltk_tokenized                                      5947 non-null   object
#  73  Job Description gensim_tokenized                                    5947 non-null   object
# dtypes: float64(23), int64(30), object(21)
# memory usage: 3.4+ MB
# ====================
# Warmth:
# --------------------
# Warmth Counts:
# Warmth
# 0    4332
# 1    1615
# Name: count, dtype: int64
# --------------------
# Warmth Percentages:
# Warmth
# 0   72.800
# 1   27.200
# Name: proportion, dtype: float64
# --------------------
# Min Warmth value: 0.0
# Max Warmth value: 1.0
# --------------------
# Warmth Mean: 0.272
# --------------------
# Warmth Standard Deviation: 0.445
# ====================
# Competence:
# --------------------
# Competence Counts:
# Competence
# 0    3180
# 1    2767
# Name: count, dtype: int64
# --------------------
# Competence Percentages:
# Competence
# 0   53.500
# 1   46.500
# Name: proportion, dtype: float64
# --------------------
# Min Competence value: 0.0
# Max Competence value: 1.0
# --------------------
# Competence Mean: 0.465
# --------------------
# Competence Standard Deviation: 0.499

# %%
df_manual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5947 entries, 0 to 5954
# Data columns (total 74 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Job ID                                                              5947 non-null   object
#  1   Job Description spacy_sentencized                                   5947 non-null   object
#  2   Warmth                                                              5947 non-null   int64
#  3   Competence                                                          5947 non-null   int64
#  4   Dutch Requirement in Sentence                                       5947 non-null   object
#  5   English Requirement in Sentence                                     5947 non-null   object
#  6   Dutch Requirement in Sentence_No                                    5947 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                                   5947 non-null   int64
#  8   English Requirement in Sentence_No                                  5947 non-null   int64
#  9   English Requirement in Sentence_Yes                                 5947 non-null   int64
#  10  Search Keyword                                                      5947 non-null   object
#  11  Platform                                                            5947 non-null   object
#  12  Job Title                                                           5947 non-null   object
#  13  Company Name                                                        5947 non-null   object
#  14  Location                                                            5947 non-null   object
#  15  Industry                                                            290 non-null    object
#  16  Dutch Requirement in Job Ad                                         5947 non-null   object
#  17  English Requirement in Job Ad                                       5947 non-null   object
#  18  Dutch Requirement in Job Ad_No                                      5947 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                                     5947 non-null   int64
#  20  English Requirement in Job Ad_No                                    5947 non-null   int64
#  21  English Requirement in Job Ad_Yes                                   5947 non-null   int64
#  22  Sector Code                                                         5947 non-null   object
#  23  Sector                                                              5947 non-null   object
#  24  Keywords Count                                                      5947 non-null   float64
#  25  Gender_Female_n                                                     5947 non-null   float64
#  26  Gender_Female_% per Sector                                          5947 non-null   float64
#  27  Gender_Female_% per Social Category                                 5947 non-null   float64
#  28  Gender_Female_% per Workforce                                       5947 non-null   float64
#  29  Gender_Male_n                                                       5947 non-null   float64
#  30  Gender_Male_% per Sector                                            5947 non-null   float64
#  31  Gender_Male_% per Social Category                                   5947 non-null   float64
#  32  Gender_Male_% per Workforce                                         5947 non-null   float64
#  33  Gender                                                              5947 non-null   object
#  34  Age_Older_n                                                         5947 non-null   float64
#  35  Age_Older_% per Sector                                              5947 non-null   float64
#  36  Age_Older_% per Social Category                                     5947 non-null   float64
#  37  Age_Older_% per Workforce                                           5947 non-null   float64
#  38  Age_Younger_n                                                       5947 non-null   float64
#  39  Age_Younger_% per Sector                                            5947 non-null   float64
#  40  Age_Younger_% per Social Category                                   5947 non-null   float64
#  41  Age_Younger_% per Workforce                                         5947 non-null   float64
#  42  Age                                                                 5947 non-null   object
#  43  Sector_n                                                            5947 non-null   float64
#  44  % Sector per Workforce                                              5947 non-null   float64
#  45  Sector Job Advertisement Count                                      5947 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count                   5947 non-null   int64
#  47  Sector Age Designation Job Advertisement Count                      5947 non-null   int64
#  48  Gender_Female                                                       5947 non-null   int64
#  49  Gender_Male                                                         5947 non-null   int64
#  50  Gender_Mixed                                                        5947 non-null   int64
#  51  Age_Mixed                                                           5947 non-null   int64
#  52  Age_Older                                                           5947 non-null   int64
#  53  Age_Younger                                                         5947 non-null   int64
#  54  Gender_Num                                                          5947 non-null   int64
#  55  Age_Num                                                             5947 non-null   int64
#  56  Interaction_Female_Older_% per Sector                               5947 non-null   float64
#  57  Interaction_Female_Younger_% per Sector                             5947 non-null   float64
#  58  Interaction_Male_Older_% per Sector                                 5947 non-null   float64
#  59  Interaction_Male_Younger_% per Sector                               5947 non-null   float64
#  60  Platform_Num                                                        5947 non-null   int64
#  61  Platform_LinkedIn                                                   5947 non-null   int64
#  62  Platform_Indeed                                                     5947 non-null   int64
#  63  Platform_Glassdoor                                                  5947 non-null   int64
#  64  Job Description spacy_sentencized_lower                             5947 non-null   object
#  65  Job Description spacy_tokenized                                     5947 non-null   object
#  66  Job Description spacy_sentencized_cleaned                           5947 non-null   object
#  67  Job Description spacy_sentencized_num_words                         5947 non-null   int64
#  68  Job Description spacy_sentencized_num_unique_words                  5947 non-null   int64
#  69  Job Description spacy_sentencized_num_chars                         5947 non-null   int64
#  70  Job Description spacy_sentencized_num_chars_no_whitespact_and_punt  5947 non-null   int64
#  71  Job Description spacy_sentencized_num_punctuations                  5947 non-null   int64
#  72  Job Description nltk_tokenized                                      5947 non-null   object
#  73  Job Description gensim_tokenized                                    5947 non-null   object
# dtypes: float64(23), int64(30), object(21)
# memory usage: 3.4+ MB

# %%
# %%time
max_length = 512
returned_tensor = 'pt'
cpu_counts = torch.multiprocessing.cpu_count()
device = torch.device('mps') if torch.has_mps and torch.backends.mps.is_built() and torch.backends.mps.is_available() else torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
device_name = str(device.type)
print(f'Using {device_name.upper()}')
bert_model_name = 'bert-base-uncased'
bert_tokenizer = BertTokenizerFast.from_pretrained(bert_model_name, strip_accents = True, trust_remote_code=True)
bert_model = BertForSequenceClassification.from_pretrained(bert_model_name, trust_remote_code=True).to(device)

df_manual['Job Description bert_tokenized'] = df_manual['Job Description spacy_sentencized'].progress_apply(
    lambda sentence: bert_tokenizer.tokenize(str(sentence))
)

assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
df_manual.to_pickle(f'{df_save_dir}df_manual_tokenized_spacy_nltk_gensim_bert.pkl')
df_manual.to_csv(f'{df_save_dir}df_manual_tokenized_spacy_nltk_gensim_bert.csv')
# Out:
# Using MPS
# Downloading tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# progress-bar:   0%|          | 0/5947 [00:00<?, ?it/s]
# CPU times: user 1.68 s, sys: 488 ms, total: 2.17 s
# Wall time: 6.42 s

# %%
df_manual['Job Description bert_tokenized'].head()
# Out:
# 0    [through, daily, contact, ,, as, a, partner, o...
# 1        [this, role, is, truly, cross, functional, .]
# 2    [the, other, part, of, your, time, would, be, ...
# 3    [being, the, expert, on, your, product, also, ...
# 4    [your, minds, ##et, is, commercial, ,, result,...
# Name: Job Description bert_tokenized, dtype: object

# %%
df_manual['Job Description bert_tokenized'].describe()
# Out:
# count                   5947
# unique                  5081
# top       [job, description]
# freq                      17
# Name: Job Description bert_tokenized, dtype: object

# %%
assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
# df_manual.to_pickle(f'{df_save_dir}df_manual_tokenized_spacy_nltk_gensim_bert.pkl')
# df_manual.to_csv(f'{df_save_dir}df_manual_tokenized_spacy_nltk_gensim_bert.csv')
df_manual.to_pickle(f'{df_save_dir}df_manual_for_training.pkl')
df_manual.to_csv(f'{df_save_dir}df_manual_for_training.csv')

# %% [markdown]
# ## Check data

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_FOR_training
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %%
import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

mod = sys.modules[__name__]

code_dir = None
code_dir_name = 'Code'
unwanted_subdir_name = 'Analysis'

if code_dir_name not in str(Path.cwd()).split('/')[-1]:
    for _ in range(5):

        parent_path = str(Path.cwd().parents[_]).split('/')[-1]

        if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

            code_dir = str(Path.cwd().parents[_])

            if code_dir is not None:
                break
else:
    code_dir = str(Path.cwd())
sys.path.append(code_dir)

# %load_ext autoreload
# %autoreload 2

# %%
from setup_module.imports import * # type:ignore # isort:skip # fmt:skip # noqa # nopep8
from setup_module import specification_curve_fork as specy # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# %%
with open(f'{data_dir}df_manual_len.txt', 'r') as f:
    df_manual_len = int(f.read())

df_manual = pd.read_pickle(f'{df_save_dir}df_manual_for_training.pkl')
assert len(df_manual) == df_manual_len, f'DATAFRAME MISSING DATA! DF SHOULD BE OF LENGTH {df_manual_len} BUT IS OF LENGTH {len(df_manual)}'
print(f'Dataframe loaded with shape: {df_manual.shape}')
# Out:
# Dataframe loaded with shape: (5947, 75)

# %%
get_df_info(df_manual, ivs_all=dvs)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 5947 entries, 0 to 5954
# Data columns (total 75 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Job ID                                                              5947 non-null   object
#  1   Job Description spacy_sentencized                                   5947 non-null   object
#  2   Warmth                                                              5947 non-null   int64
#  3   Competence                                                          5947 non-null   int64
#  4   Dutch Requirement in Sentence                                       5947 non-null   object
#  5   English Requirement in Sentence                                     5947 non-null   object
#  6   Dutch Requirement in Sentence_No                                    5947 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                                   5947 non-null   int64
#  8   English Requirement in Sentence_No                                  5947 non-null   int64
#  9   English Requirement in Sentence_Yes                                 5947 non-null   int64
#  10  Search Keyword                                                      5947 non-null   object
#  11  Platform                                                            5947 non-null   object
#  12  Job Title                                                           5947 non-null   object
#  13  Company Name                                                        5947 non-null   object
#  14  Location                                                            5947 non-null   object
#  15  Industry                                                            290 non-null    object
#  16  Dutch Requirement in Job Ad                                         5947 non-null   object
#  17  English Requirement in Job Ad                                       5947 non-null   object
#  18  Dutch Requirement in Job Ad_No                                      5947 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                                     5947 non-null   int64
#  20  English Requirement in Job Ad_No                                    5947 non-null   int64
#  21  English Requirement in Job Ad_Yes                                   5947 non-null   int64
#  22  Sector Code                                                         5947 non-null   object
#  23  Sector                                                              5947 non-null   object
#  24  Keywords Count                                                      5947 non-null   float64
#  25  Gender_Female_n                                                     5947 non-null   float64
#  26  Gender_Female_% per Sector                                          5947 non-null   float64
#  27  Gender_Female_% per Social Category                                 5947 non-null   float64
#  28  Gender_Female_% per Workforce                                       5947 non-null   float64
#  29  Gender_Male_n                                                       5947 non-null   float64
#  30  Gender_Male_% per Sector                                            5947 non-null   float64
#  31  Gender_Male_% per Social Category                                   5947 non-null   float64
#  32  Gender_Male_% per Workforce                                         5947 non-null   float64
#  33  Gender                                                              5947 non-null   object
#  34  Age_Older_n                                                         5947 non-null   float64
#  35  Age_Older_% per Sector                                              5947 non-null   float64
#  36  Age_Older_% per Social Category                                     5947 non-null   float64
#  37  Age_Older_% per Workforce                                           5947 non-null   float64
#  38  Age_Younger_n                                                       5947 non-null   float64
#  39  Age_Younger_% per Sector                                            5947 non-null   float64
#  40  Age_Younger_% per Social Category                                   5947 non-null   float64
#  41  Age_Younger_% per Workforce                                         5947 non-null   float64
#  42  Age                                                                 5947 non-null   object
#  43  Sector_n                                                            5947 non-null   float64
#  44  % Sector per Workforce                                              5947 non-null   float64
#  45  Sector Job Advertisement Count                                      5947 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count                   5947 non-null   int64
#  47  Sector Age Designation Job Advertisement Count                      5947 non-null   int64
#  48  Gender_Female                                                       5947 non-null   int64
#  49  Gender_Male                                                         5947 non-null   int64
#  50  Gender_Mixed                                                        5947 non-null   int64
#  51  Age_Mixed                                                           5947 non-null   int64
#  52  Age_Older                                                           5947 non-null   int64
#  53  Age_Younger                                                         5947 non-null   int64
#  54  Gender_Num                                                          5947 non-null   int64
#  55  Age_Num                                                             5947 non-null   int64
#  56  Interaction_Female_Older_% per Sector                               5947 non-null   float64
#  57  Interaction_Female_Younger_% per Sector                             5947 non-null   float64
#  58  Interaction_Male_Older_% per Sector                                 5947 non-null   float64
#  59  Interaction_Male_Younger_% per Sector                               5947 non-null   float64
#  60  Platform_Num                                                        5947 non-null   int64
#  61  Platform_LinkedIn                                                   5947 non-null   int64
#  62  Platform_Indeed                                                     5947 non-null   int64
#  63  Platform_Glassdoor                                                  5947 non-null   int64
#  64  Job Description spacy_sentencized_lower                             5947 non-null   object
#  65  Job Description spacy_tokenized                                     5947 non-null   object
#  66  Job Description spacy_sentencized_cleaned                           5947 non-null   object
#  67  Job Description spacy_sentencized_num_words                         5947 non-null   int64
#  68  Job Description spacy_sentencized_num_unique_words                  5947 non-null   int64
#  69  Job Description spacy_sentencized_num_chars                         5947 non-null   int64
#  70  Job Description spacy_sentencized_num_chars_no_whitespact_and_punt  5947 non-null   int64
#  71  Job Description spacy_sentencized_num_punctuations                  5947 non-null   int64
#  72  Job Description nltk_tokenized                                      5947 non-null   object
#  73  Job Description gensim_tokenized                                    5947 non-null   object
#  74  Job Description bert_tokenized                                      5947 non-null   object
# dtypes: float64(23), int64(30), object(22)
# memory usage: 3.4+ MB
# ====================
# Warmth:
# --------------------
# Warmth Counts:
# Warmth
# 0    4332
# 1    1615
# Name: count, dtype: int64
# --------------------
# Warmth Percentages:
# Warmth
# 0   72.800
# 1   27.200
# Name: proportion, dtype: float64
# --------------------
# Min Warmth value: 0.0
# Max Warmth value: 1.0
# --------------------
# Warmth Mean: 0.272
# --------------------
# Warmth Standard Deviation: 0.445
# ====================
# Competence:
# --------------------
# Competence Counts:
# Competence
# 0    3180
# 1    2767
# Name: count, dtype: int64
# --------------------
# Competence Percentages:
# Competence
# 0   53.500
# 1   46.500
# Name: proportion, dtype: float64
# --------------------
# Min Competence value: 0.0
# Max Competence value: 1.0
# --------------------
# Competence Mean: 0.465
# --------------------
# Competence Standard Deviation: 0.499

# %%
get_df_info(df_manual, ivs_all=ivs)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 5947 entries, 0 to 5954
# Data columns (total 75 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Job ID                                                              5947 non-null   object
#  1   Job Description spacy_sentencized                                   5947 non-null   object
#  2   Warmth                                                              5947 non-null   int64
#  3   Competence                                                          5947 non-null   int64
#  4   Dutch Requirement in Sentence                                       5947 non-null   object
#  5   English Requirement in Sentence                                     5947 non-null   object
#  6   Dutch Requirement in Sentence_No                                    5947 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                                   5947 non-null   int64
#  8   English Requirement in Sentence_No                                  5947 non-null   int64
#  9   English Requirement in Sentence_Yes                                 5947 non-null   int64
#  10  Search Keyword                                                      5947 non-null   object
#  11  Platform                                                            5947 non-null   object
#  12  Job Title                                                           5947 non-null   object
#  13  Company Name                                                        5947 non-null   object
#  14  Location                                                            5947 non-null   object
#  15  Industry                                                            290 non-null    object
#  16  Dutch Requirement in Job Ad                                         5947 non-null   object
#  17  English Requirement in Job Ad                                       5947 non-null   object
#  18  Dutch Requirement in Job Ad_No                                      5947 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                                     5947 non-null   int64
#  20  English Requirement in Job Ad_No                                    5947 non-null   int64
#  21  English Requirement in Job Ad_Yes                                   5947 non-null   int64
#  22  Sector Code                                                         5947 non-null   object
#  23  Sector                                                              5947 non-null   object
#  24  Keywords Count                                                      5947 non-null   float64
#  25  Gender_Female_n                                                     5947 non-null   float64
#  26  Gender_Female_% per Sector                                          5947 non-null   float64
#  27  Gender_Female_% per Social Category                                 5947 non-null   float64
#  28  Gender_Female_% per Workforce                                       5947 non-null   float64
#  29  Gender_Male_n                                                       5947 non-null   float64
#  30  Gender_Male_% per Sector                                            5947 non-null   float64
#  31  Gender_Male_% per Social Category                                   5947 non-null   float64
#  32  Gender_Male_% per Workforce                                         5947 non-null   float64
#  33  Gender                                                              5947 non-null   object
#  34  Age_Older_n                                                         5947 non-null   float64
#  35  Age_Older_% per Sector                                              5947 non-null   float64
#  36  Age_Older_% per Social Category                                     5947 non-null   float64
#  37  Age_Older_% per Workforce                                           5947 non-null   float64
#  38  Age_Younger_n                                                       5947 non-null   float64
#  39  Age_Younger_% per Sector                                            5947 non-null   float64
#  40  Age_Younger_% per Social Category                                   5947 non-null   float64
#  41  Age_Younger_% per Workforce                                         5947 non-null   float64
#  42  Age                                                                 5947 non-null   object
#  43  Sector_n                                                            5947 non-null   float64
#  44  % Sector per Workforce                                              5947 non-null   float64
#  45  Sector Job Advertisement Count                                      5947 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count                   5947 non-null   int64
#  47  Sector Age Designation Job Advertisement Count                      5947 non-null   int64
#  48  Gender_Female                                                       5947 non-null   int64
#  49  Gender_Male                                                         5947 non-null   int64
#  50  Gender_Mixed                                                        5947 non-null   int64
#  51  Age_Mixed                                                           5947 non-null   int64
#  52  Age_Older                                                           5947 non-null   int64
#  53  Age_Younger                                                         5947 non-null   int64
#  54  Gender_Num                                                          5947 non-null   int64
#  55  Age_Num                                                             5947 non-null   int64
#  56  Interaction_Female_Older_% per Sector                               5947 non-null   float64
#  57  Interaction_Female_Younger_% per Sector                             5947 non-null   float64
#  58  Interaction_Male_Older_% per Sector                                 5947 non-null   float64
#  59  Interaction_Male_Younger_% per Sector                               5947 non-null   float64
#  60  Platform_Num                                                        5947 non-null   int64
#  61  Platform_LinkedIn                                                   5947 non-null   int64
#  62  Platform_Indeed                                                     5947 non-null   int64
#  63  Platform_Glassdoor                                                  5947 non-null   int64
#  64  Job Description spacy_sentencized_lower                             5947 non-null   object
#  65  Job Description spacy_tokenized                                     5947 non-null   object
#  66  Job Description spacy_sentencized_cleaned                           5947 non-null   object
#  67  Job Description spacy_sentencized_num_words                         5947 non-null   int64
#  68  Job Description spacy_sentencized_num_unique_words                  5947 non-null   int64
#  69  Job Description spacy_sentencized_num_chars                         5947 non-null   int64
#  70  Job Description spacy_sentencized_num_chars_no_whitespact_and_punt  5947 non-null   int64
#  71  Job Description spacy_sentencized_num_punctuations                  5947 non-null   int64
#  72  Job Description nltk_tokenized                                      5947 non-null   object
#  73  Job Description gensim_tokenized                                    5947 non-null   object
#  74  Job Description bert_tokenized                                      5947 non-null   object
# dtypes: float64(23), int64(30), object(22)
# memory usage: 3.4+ MB
# ====================
# Gender:
# --------------------
# Gender Counts:
# Gender
# Mixed Gender    3836
# Male            1151
# Female           960
# Name: count, dtype: int64
# --------------------
# Gender Percentages:
# Gender
# Mixed Gender   64.500
# Male           19.400
# Female         16.100
# Name: proportion, dtype: float64
# --------------------
# Gender not available.
# ====================
# Age:
# --------------------
# Age Counts:
# Age
# Younger      3221
# Mixed Age    2045
# Older         681
# Name: count, dtype: int64
# --------------------
# Age Percentages:
# Age
# Younger     54.200
# Mixed Age   34.400
# Older       11.500
# Name: proportion, dtype: float64
# --------------------
# Age not available.

# %%
get_df_info(df_manual, ivs_all=ivs_dummy)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 5947 entries, 0 to 5954
# Data columns (total 75 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Job ID                                                              5947 non-null   object
#  1   Job Description spacy_sentencized                                   5947 non-null   object
#  2   Warmth                                                              5947 non-null   int64
#  3   Competence                                                          5947 non-null   int64
#  4   Dutch Requirement in Sentence                                       5947 non-null   object
#  5   English Requirement in Sentence                                     5947 non-null   object
#  6   Dutch Requirement in Sentence_No                                    5947 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                                   5947 non-null   int64
#  8   English Requirement in Sentence_No                                  5947 non-null   int64
#  9   English Requirement in Sentence_Yes                                 5947 non-null   int64
#  10  Search Keyword                                                      5947 non-null   object
#  11  Platform                                                            5947 non-null   object
#  12  Job Title                                                           5947 non-null   object
#  13  Company Name                                                        5947 non-null   object
#  14  Location                                                            5947 non-null   object
#  15  Industry                                                            290 non-null    object
#  16  Dutch Requirement in Job Ad                                         5947 non-null   object
#  17  English Requirement in Job Ad                                       5947 non-null   object
#  18  Dutch Requirement in Job Ad_No                                      5947 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                                     5947 non-null   int64
#  20  English Requirement in Job Ad_No                                    5947 non-null   int64
#  21  English Requirement in Job Ad_Yes                                   5947 non-null   int64
#  22  Sector Code                                                         5947 non-null   object
#  23  Sector                                                              5947 non-null   object
#  24  Keywords Count                                                      5947 non-null   float64
#  25  Gender_Female_n                                                     5947 non-null   float64
#  26  Gender_Female_% per Sector                                          5947 non-null   float64
#  27  Gender_Female_% per Social Category                                 5947 non-null   float64
#  28  Gender_Female_% per Workforce                                       5947 non-null   float64
#  29  Gender_Male_n                                                       5947 non-null   float64
#  30  Gender_Male_% per Sector                                            5947 non-null   float64
#  31  Gender_Male_% per Social Category                                   5947 non-null   float64
#  32  Gender_Male_% per Workforce                                         5947 non-null   float64
#  33  Gender                                                              5947 non-null   object
#  34  Age_Older_n                                                         5947 non-null   float64
#  35  Age_Older_% per Sector                                              5947 non-null   float64
#  36  Age_Older_% per Social Category                                     5947 non-null   float64
#  37  Age_Older_% per Workforce                                           5947 non-null   float64
#  38  Age_Younger_n                                                       5947 non-null   float64
#  39  Age_Younger_% per Sector                                            5947 non-null   float64
#  40  Age_Younger_% per Social Category                                   5947 non-null   float64
#  41  Age_Younger_% per Workforce                                         5947 non-null   float64
#  42  Age                                                                 5947 non-null   object
#  43  Sector_n                                                            5947 non-null   float64
#  44  % Sector per Workforce                                              5947 non-null   float64
#  45  Sector Job Advertisement Count                                      5947 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count                   5947 non-null   int64
#  47  Sector Age Designation Job Advertisement Count                      5947 non-null   int64
#  48  Gender_Female                                                       5947 non-null   int64
#  49  Gender_Male                                                         5947 non-null   int64
#  50  Gender_Mixed                                                        5947 non-null   int64
#  51  Age_Mixed                                                           5947 non-null   int64
#  52  Age_Older                                                           5947 non-null   int64
#  53  Age_Younger                                                         5947 non-null   int64
#  54  Gender_Num                                                          5947 non-null   int64
#  55  Age_Num                                                             5947 non-null   int64
#  56  Interaction_Female_Older_% per Sector                               5947 non-null   float64
#  57  Interaction_Female_Younger_% per Sector                             5947 non-null   float64
#  58  Interaction_Male_Older_% per Sector                                 5947 non-null   float64
#  59  Interaction_Male_Younger_% per Sector                               5947 non-null   float64
#  60  Platform_Num                                                        5947 non-null   int64
#  61  Platform_LinkedIn                                                   5947 non-null   int64
#  62  Platform_Indeed                                                     5947 non-null   int64
#  63  Platform_Glassdoor                                                  5947 non-null   int64
#  64  Job Description spacy_sentencized_lower                             5947 non-null   object
#  65  Job Description spacy_tokenized                                     5947 non-null   object
#  66  Job Description spacy_sentencized_cleaned                           5947 non-null   object
#  67  Job Description spacy_sentencized_num_words                         5947 non-null   int64
#  68  Job Description spacy_sentencized_num_unique_words                  5947 non-null   int64
#  69  Job Description spacy_sentencized_num_chars                         5947 non-null   int64
#  70  Job Description spacy_sentencized_num_chars_no_whitespact_and_punt  5947 non-null   int64
#  71  Job Description spacy_sentencized_num_punctuations                  5947 non-null   int64
#  72  Job Description nltk_tokenized                                      5947 non-null   object
#  73  Job Description gensim_tokenized                                    5947 non-null   object
#  74  Job Description bert_tokenized                                      5947 non-null   object
# dtypes: float64(23), int64(30), object(22)
# memory usage: 3.4+ MB
# ====================
# Gender_Female:
# --------------------
# Gender_Female Counts:
# Gender_Female
# 0    4987
# 1     960
# Name: count, dtype: int64
# --------------------
# Gender_Female Percentages:
# Gender_Female
# 0   83.900
# 1   16.100
# Name: proportion, dtype: float64
# --------------------
# Min Gender_Female value: 0.0
# Max Gender_Female value: 1.0
# --------------------
# Gender_Female Mean: 0.161
# --------------------
# Gender_Female Standard Deviation: 0.368
# ====================
# Gender_Mixed:
# --------------------
# Gender_Mixed Counts:
# Gender_Mixed
# 1    3836
# 0    2111
# Name: count, dtype: int64
# --------------------
# Gender_Mixed Percentages:
# Gender_Mixed
# 1   64.500
# 0   35.500
# Name: proportion, dtype: float64
# --------------------
# Min Gender_Mixed value: 0.0
# Max Gender_Mixed value: 1.0
# --------------------
# Gender_Mixed Mean: 0.645
# --------------------
# Gender_Mixed Standard Deviation: 0.479
# ====================
# Gender_Male:
# --------------------
# Gender_Male Counts:
# Gender_Male
# 0    4796
# 1    1151
# Name: count, dtype: int64
# --------------------
# Gender_Male Percentages:
# Gender_Male
# 0   80.600
# 1   19.400
# Name: proportion, dtype: float64
# --------------------
# Min Gender_Male value: 0.0
# Max Gender_Male value: 1.0
# --------------------
# Gender_Male Mean: 0.194
# --------------------
# Gender_Male Standard Deviation: 0.395
# ====================
# Age_Older:
# --------------------
# Age_Older Counts:
# Age_Older
# 0    5266
# 1     681
# Name: count, dtype: int64
# --------------------
# Age_Older Percentages:
# Age_Older
# 0   88.500
# 1   11.500
# Name: proportion, dtype: float64
# --------------------
# Min Age_Older value: 0.0
# Max Age_Older value: 1.0
# --------------------
# Age_Older Mean: 0.115
# --------------------
# Age_Older Standard Deviation: 0.318
# ====================
# Age_Mixed:
# --------------------
# Age_Mixed Counts:
# Age_Mixed
# 0    3902
# 1    2045
# Name: count, dtype: int64
# --------------------
# Age_Mixed Percentages:
# Age_Mixed
# 0   65.600
# 1   34.400
# Name: proportion, dtype: float64
# --------------------
# Min Age_Mixed value: 0.0
# Max Age_Mixed value: 1.0
# --------------------
# Age_Mixed Mean: 0.344
# --------------------
# Age_Mixed Standard Deviation: 0.475
# ====================
# Age_Younger:
# --------------------
# Age_Younger Counts:
# Age_Younger
# 1    3221
# 0    2726
# Name: count, dtype: int64
# --------------------
# Age_Younger Percentages:
# Age_Younger
# 1   54.200
# 0   45.800
# Name: proportion, dtype: float64
# --------------------
# Min Age_Younger value: 0.0
# Max Age_Younger value: 1.0
# --------------------
# Age_Younger Mean: 0.542
# --------------------
# Age_Younger Standard Deviation: 0.498

# %%
get_df_info(df_manual, ivs_all=ivs_perc)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 5947 entries, 0 to 5954
# Data columns (total 75 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Job ID                                                              5947 non-null   object
#  1   Job Description spacy_sentencized                                   5947 non-null   object
#  2   Warmth                                                              5947 non-null   int64
#  3   Competence                                                          5947 non-null   int64
#  4   Dutch Requirement in Sentence                                       5947 non-null   object
#  5   English Requirement in Sentence                                     5947 non-null   object
#  6   Dutch Requirement in Sentence_No                                    5947 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                                   5947 non-null   int64
#  8   English Requirement in Sentence_No                                  5947 non-null   int64
#  9   English Requirement in Sentence_Yes                                 5947 non-null   int64
#  10  Search Keyword                                                      5947 non-null   object
#  11  Platform                                                            5947 non-null   object
#  12  Job Title                                                           5947 non-null   object
#  13  Company Name                                                        5947 non-null   object
#  14  Location                                                            5947 non-null   object
#  15  Industry                                                            290 non-null    object
#  16  Dutch Requirement in Job Ad                                         5947 non-null   object
#  17  English Requirement in Job Ad                                       5947 non-null   object
#  18  Dutch Requirement in Job Ad_No                                      5947 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                                     5947 non-null   int64
#  20  English Requirement in Job Ad_No                                    5947 non-null   int64
#  21  English Requirement in Job Ad_Yes                                   5947 non-null   int64
#  22  Sector Code                                                         5947 non-null   object
#  23  Sector                                                              5947 non-null   object
#  24  Keywords Count                                                      5947 non-null   float64
#  25  Gender_Female_n                                                     5947 non-null   float64
#  26  Gender_Female_% per Sector                                          5947 non-null   float64
#  27  Gender_Female_% per Social Category                                 5947 non-null   float64
#  28  Gender_Female_% per Workforce                                       5947 non-null   float64
#  29  Gender_Male_n                                                       5947 non-null   float64
#  30  Gender_Male_% per Sector                                            5947 non-null   float64
#  31  Gender_Male_% per Social Category                                   5947 non-null   float64
#  32  Gender_Male_% per Workforce                                         5947 non-null   float64
#  33  Gender                                                              5947 non-null   object
#  34  Age_Older_n                                                         5947 non-null   float64
#  35  Age_Older_% per Sector                                              5947 non-null   float64
#  36  Age_Older_% per Social Category                                     5947 non-null   float64
#  37  Age_Older_% per Workforce                                           5947 non-null   float64
#  38  Age_Younger_n                                                       5947 non-null   float64
#  39  Age_Younger_% per Sector                                            5947 non-null   float64
#  40  Age_Younger_% per Social Category                                   5947 non-null   float64
#  41  Age_Younger_% per Workforce                                         5947 non-null   float64
#  42  Age                                                                 5947 non-null   object
#  43  Sector_n                                                            5947 non-null   float64
#  44  % Sector per Workforce                                              5947 non-null   float64
#  45  Sector Job Advertisement Count                                      5947 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count                   5947 non-null   int64
#  47  Sector Age Designation Job Advertisement Count                      5947 non-null   int64
#  48  Gender_Female                                                       5947 non-null   int64
#  49  Gender_Male                                                         5947 non-null   int64
#  50  Gender_Mixed                                                        5947 non-null   int64
#  51  Age_Mixed                                                           5947 non-null   int64
#  52  Age_Older                                                           5947 non-null   int64
#  53  Age_Younger                                                         5947 non-null   int64
#  54  Gender_Num                                                          5947 non-null   int64
#  55  Age_Num                                                             5947 non-null   int64
#  56  Interaction_Female_Older_% per Sector                               5947 non-null   float64
#  57  Interaction_Female_Younger_% per Sector                             5947 non-null   float64
#  58  Interaction_Male_Older_% per Sector                                 5947 non-null   float64
#  59  Interaction_Male_Younger_% per Sector                               5947 non-null   float64
#  60  Platform_Num                                                        5947 non-null   int64
#  61  Platform_LinkedIn                                                   5947 non-null   int64
#  62  Platform_Indeed                                                     5947 non-null   int64
#  63  Platform_Glassdoor                                                  5947 non-null   int64
#  64  Job Description spacy_sentencized_lower                             5947 non-null   object
#  65  Job Description spacy_tokenized                                     5947 non-null   object
#  66  Job Description spacy_sentencized_cleaned                           5947 non-null   object
#  67  Job Description spacy_sentencized_num_words                         5947 non-null   int64
#  68  Job Description spacy_sentencized_num_unique_words                  5947 non-null   int64
#  69  Job Description spacy_sentencized_num_chars                         5947 non-null   int64
#  70  Job Description spacy_sentencized_num_chars_no_whitespact_and_punt  5947 non-null   int64
#  71  Job Description spacy_sentencized_num_punctuations                  5947 non-null   int64
#  72  Job Description nltk_tokenized                                      5947 non-null   object
#  73  Job Description gensim_tokenized                                    5947 non-null   object
#  74  Job Description bert_tokenized                                      5947 non-null   object
# dtypes: float64(23), int64(30), object(22)
# memory usage: 3.4+ MB
# ====================
# Gender_Female_% per Sector:
# --------------------
# Min Gender_Female_% per Sector value: 19.444
# Max Gender_Female_% per Sector value: 84.299
# --------------------
# Gender_Female_% per Sector Mean: 45.147
# --------------------
# Gender_Female_% per Sector Standard Deviation: 15.883
# ====================
# Gender_Male_% per Sector:
# --------------------
# Min Gender_Male_% per Sector value: 15.632
# Max Gender_Male_% per Sector value: 80.556
# --------------------
# Gender_Male_% per Sector Mean: 54.832
# --------------------
# Gender_Male_% per Sector Standard Deviation: 15.907
# ====================
# Age_Older_% per Sector:
# --------------------
# Min Age_Older_% per Sector value: 18.939
# Max Age_Older_% per Sector value: 58.333
# --------------------
# Age_Older_% per Sector Mean: 38.12
# --------------------
# Age_Older_% per Sector Standard Deviation: 8.74
# ====================
# Age_Younger_% per Sector:
# --------------------
# Min Age_Younger_% per Sector value: 44.444
# Max Age_Younger_% per Sector value: 80.808
# --------------------
# Age_Younger_% per Sector Mean: 61.625
# --------------------
# Age_Younger_% per Sector Standard Deviation: 8.82

# %%
get_df_info(df_manual, ivs_all=controls)
# Out:
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 5947 entries, 0 to 5954
# Data columns (total 75 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Job ID                                                              5947 non-null   object
#  1   Job Description spacy_sentencized                                   5947 non-null   object
#  2   Warmth                                                              5947 non-null   int64
#  3   Competence                                                          5947 non-null   int64
#  4   Dutch Requirement in Sentence                                       5947 non-null   object
#  5   English Requirement in Sentence                                     5947 non-null   object
#  6   Dutch Requirement in Sentence_No                                    5947 non-null   int64
#  7   Dutch Requirement in Sentence_Yes                                   5947 non-null   int64
#  8   English Requirement in Sentence_No                                  5947 non-null   int64
#  9   English Requirement in Sentence_Yes                                 5947 non-null   int64
#  10  Search Keyword                                                      5947 non-null   object
#  11  Platform                                                            5947 non-null   object
#  12  Job Title                                                           5947 non-null   object
#  13  Company Name                                                        5947 non-null   object
#  14  Location                                                            5947 non-null   object
#  15  Industry                                                            290 non-null    object
#  16  Dutch Requirement in Job Ad                                         5947 non-null   object
#  17  English Requirement in Job Ad                                       5947 non-null   object
#  18  Dutch Requirement in Job Ad_No                                      5947 non-null   int64
#  19  Dutch Requirement in Job Ad_Yes                                     5947 non-null   int64
#  20  English Requirement in Job Ad_No                                    5947 non-null   int64
#  21  English Requirement in Job Ad_Yes                                   5947 non-null   int64
#  22  Sector Code                                                         5947 non-null   object
#  23  Sector                                                              5947 non-null   object
#  24  Keywords Count                                                      5947 non-null   float64
#  25  Gender_Female_n                                                     5947 non-null   float64
#  26  Gender_Female_% per Sector                                          5947 non-null   float64
#  27  Gender_Female_% per Social Category                                 5947 non-null   float64
#  28  Gender_Female_% per Workforce                                       5947 non-null   float64
#  29  Gender_Male_n                                                       5947 non-null   float64
#  30  Gender_Male_% per Sector                                            5947 non-null   float64
#  31  Gender_Male_% per Social Category                                   5947 non-null   float64
#  32  Gender_Male_% per Workforce                                         5947 non-null   float64
#  33  Gender                                                              5947 non-null   object
#  34  Age_Older_n                                                         5947 non-null   float64
#  35  Age_Older_% per Sector                                              5947 non-null   float64
#  36  Age_Older_% per Social Category                                     5947 non-null   float64
#  37  Age_Older_% per Workforce                                           5947 non-null   float64
#  38  Age_Younger_n                                                       5947 non-null   float64
#  39  Age_Younger_% per Sector                                            5947 non-null   float64
#  40  Age_Younger_% per Social Category                                   5947 non-null   float64
#  41  Age_Younger_% per Workforce                                         5947 non-null   float64
#  42  Age                                                                 5947 non-null   object
#  43  Sector_n                                                            5947 non-null   float64
#  44  % Sector per Workforce                                              5947 non-null   float64
#  45  Sector Job Advertisement Count                                      5947 non-null   int64
#  46  Sector Gender Designation Job Advertisement Count                   5947 non-null   int64
#  47  Sector Age Designation Job Advertisement Count                      5947 non-null   int64
#  48  Gender_Female                                                       5947 non-null   int64
#  49  Gender_Male                                                         5947 non-null   int64
#  50  Gender_Mixed                                                        5947 non-null   int64
#  51  Age_Mixed                                                           5947 non-null   int64
#  52  Age_Older                                                           5947 non-null   int64
#  53  Age_Younger                                                         5947 non-null   int64
#  54  Gender_Num                                                          5947 non-null   int64
#  55  Age_Num                                                             5947 non-null   int64
#  56  Interaction_Female_Older_% per Sector                               5947 non-null   float64
#  57  Interaction_Female_Younger_% per Sector                             5947 non-null   float64
#  58  Interaction_Male_Older_% per Sector                                 5947 non-null   float64
#  59  Interaction_Male_Younger_% per Sector                               5947 non-null   float64
#  60  Platform_Num                                                        5947 non-null   int64
#  61  Platform_LinkedIn                                                   5947 non-null   int64
#  62  Platform_Indeed                                                     5947 non-null   int64
#  63  Platform_Glassdoor                                                  5947 non-null   int64
#  64  Job Description spacy_sentencized_lower                             5947 non-null   object
#  65  Job Description spacy_tokenized                                     5947 non-null   object
#  66  Job Description spacy_sentencized_cleaned                           5947 non-null   object
#  67  Job Description spacy_sentencized_num_words                         5947 non-null   int64
#  68  Job Description spacy_sentencized_num_unique_words                  5947 non-null   int64
#  69  Job Description spacy_sentencized_num_chars                         5947 non-null   int64
#  70  Job Description spacy_sentencized_num_chars_no_whitespact_and_punt  5947 non-null   int64
#  71  Job Description spacy_sentencized_num_punctuations                  5947 non-null   int64
#  72  Job Description nltk_tokenized                                      5947 non-null   object
#  73  Job Description gensim_tokenized                                    5947 non-null   object
#  74  Job Description bert_tokenized                                      5947 non-null   object
# dtypes: float64(23), int64(30), object(22)
# memory usage: 3.4+ MB
# ====================
# Job Description spacy_sentencized_num_words:
# --------------------
# Min Job Description spacy_sentencized_num_words value: 1.0
# Max Job Description spacy_sentencized_num_words value: 131.0
# --------------------
# Job Description spacy_sentencized_num_words Mean: 13.818
# --------------------
# Job Description spacy_sentencized_num_words Standard Deviation: 10.615
# ====================
# % Sector per Workforce:
# --------------------
# Min % Sector per Workforce value: 0.115
# Max % Sector per Workforce value: 31.385
# --------------------
# % Sector per Workforce Mean: 4.47
# --------------------
# % Sector per Workforce Standard Deviation: 5.288
# ====================
# Sector Job Advertisement Count:
# --------------------
# Min Sector Job Advertisement Count value: 150.0
# Max Sector Job Advertisement Count value: 2895.0
# --------------------
# Sector Job Advertisement Count Mean: 1138.182
# --------------------
# Sector Job Advertisement Count Standard Deviation: 546.523
# ====================
# Keywords Count:
# --------------------
# Min Keywords Count value: 1.0
# Max Keywords Count value: 11.0
# --------------------
# Keywords Count Mean: 7.111
# --------------------
# Keywords Count Standard Deviation: 2.429
# ====================
# English Requirement in Job Ad_Yes:
# --------------------
# English Requirement in Job Ad_Yes Counts:
# English Requirement in Job Ad_Yes
# 0    5407
# 1     540
# Name: count, dtype: int64
# --------------------
# English Requirement in Job Ad_Yes Percentages:
# English Requirement in Job Ad_Yes
# 0   90.900
# 1    9.100
# Name: proportion, dtype: float64
# --------------------
# Min English Requirement in Job Ad_Yes value: 0.0
# Max English Requirement in Job Ad_Yes value: 1.0
# --------------------
# English Requirement in Job Ad_Yes Mean: 0.091
# --------------------
# English Requirement in Job Ad_Yes Standard Deviation: 0.287
# ====================
# Dutch Requirement in Job Ad_Yes:
# --------------------
# Dutch Requirement in Job Ad_Yes Counts:
# Dutch Requirement in Job Ad_Yes
# 0    5754
# 1     193
# Name: count, dtype: int64
# --------------------
# Dutch Requirement in Job Ad_Yes Percentages:
# Dutch Requirement in Job Ad_Yes
# 0   96.800
# 1    3.200
# Name: proportion, dtype: float64
# --------------------
# Min Dutch Requirement in Job Ad_Yes value: 0.0
# Max Dutch Requirement in Job Ad_Yes value: 1.0
# --------------------
# Dutch Requirement in Job Ad_Yes Mean: 0.032
# --------------------
# Dutch Requirement in Job Ad_Yes Standard Deviation: 0.177

# %%
print(f'Running OLS specification curve analysis with:\nDEPENDENT VARIABLES = {dvs}\nINDEPENDENT VARIABLES = {ivs_dummy}\nCONTROLS = {controls}')
sc = specy.SpecificationCurve(df=df_manual, y_endog=dvs, x_exog=ivs_dummy, controls=controls)
sc.fit(estimator=sm.OLS)
sc.plot(show_plot=True)
# Out:
# Running OLS specification curve analysis with:
# DEPENDENT VARIABLES = ['Warmth', 'Competence']
# INDEPENDENT VARIABLES = ['Gender_Female', 'Gender_Mixed', 'Gender_Male', 'Age_Older', 'Age_Mixed', 'Age_Younger']
# CONTROLS = ['Job Description spacy_sentencized_num_words', '% Sector per Workforce', 'Sector Job Advertisement Count', 'Keywords Count', 'English Requirement in Job Ad_Yes', 'Dutch Requirement in Job Ad_Yes']
# Fit complete

# %%
print(f'Running Logit specification curve analysis with:\nDEPENDENT VARIABLES = {dvs}\nINDEPENDENT VARIABLES = {ivs_perc}\nCONTROLS = {controls}')
sc = specy.SpecificationCurve(df=df_manual, y_endog=dvs, x_exog=ivs_perc, controls=controls[:4])
sc.fit(estimator=sm.Logit)
sc.plot(show_plot=True)
# Out:
# Running Logit specification curve analysis with:
# DEPENDENT VARIABLES = ['Warmth', 'Competence']
# INDEPENDENT VARIABLES = ['Gender_Female_% per Sector', 'Gender_Male_% per Sector', 'Age_Older_% per Sector', 'Age_Younger_% per Sector']
# CONTROLS = ['Job Description spacy_sentencized_num_words', '% Sector per Workforce', 'Sector Job Advertisement Count', 'Keywords Count', 'English Requirement in Job Ad_Yes', 'Dutch Requirement in Job Ad_Yes']
# Optimization terminated successfully.
#          Current function value: 0.600135
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.584885
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.600125
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598276
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598206
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.584878
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.581295
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.580461
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598270
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598138
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597901
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.581279
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.580438
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.580085
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597869
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.580082
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588616
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.567290
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588465
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588405
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.587688
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.565910
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.565639
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.562147
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588300
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.587683
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.587562
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.564611
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.561895
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.561849
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.587562
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.561671
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583553
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.555242
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583268
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583535
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583465
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.555196
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.554574
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.553161
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583243
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583086
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583453
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.554512
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.552876
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.553081
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583037
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.552729
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590585
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.562711
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590500
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590192
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.589532
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.562704
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.561442
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.560611
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590065
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.589505
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.589500
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.561401
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.560602
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.560333
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.589461
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.560333
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690749
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.648969
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690381
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690734
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690631
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.648897
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648007
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.646011
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690362
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690209
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690383
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.647951
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.645805
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.645943
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689850
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.645695
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691119
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.650913
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691013
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.691111
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690686
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.650396
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649592
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.644353
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690995
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690346
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690390
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.649241
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.644346
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.643489
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689927
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.643433
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690591
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.644786
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690251
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690565
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690484
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.644777
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.643943
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.640641
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690234
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690029
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690149
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.643927
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.640340
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.640035
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689523
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.639544
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690957
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.642647
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690708
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690914
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690687
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.642593
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.642043
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.642645
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690641
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690360
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690442
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.641949
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.642587
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.641853
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689998
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.641692
#          Iterations 5
# Fit complete

# %%
print(f'Running Logit specification curve analysis with:\nDEPENDENT VARIABLES = {dvs}\nINDEPENDENT VARIABLES = {ivs_perc_interactions}\nCONTROLS = {controls}')
sc = specy.SpecificationCurve(df=df_manual, y_endog=dvs, x_exog=ivs_perc_interactions, controls=controls[:4])
sc.fit(estimator=sm.Logit)
sc.plot(show_plot=True)
# Out:
# Running Logit specification curve analysis with:
# DEPENDENT VARIABLES = ['Warmth', 'Competence']
# INDEPENDENT VARIABLES = ['Interaction_Female_Older_% per Sector', 'Interaction_Female_Younger_% per Sector', 'Interaction_Male_Older_% per Sector', 'Interaction_Male_Younger_% per Sector']
# CONTROLS = ['Job Description spacy_sentencized_num_words', '% Sector per Workforce', 'Sector Job Advertisement Count', 'Keywords Count', 'English Requirement in Job Ad_Yes', 'Dutch Requirement in Job Ad_Yes']
# Optimization terminated successfully.
#          Current function value: 0.603542
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.593874
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.603487
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598370
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597218
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.593564
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583475
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.579456
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598370
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597087
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596983
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583383
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.579381
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.579209
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596901
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.579173
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.601563
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.586533
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.601563
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.599981
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.600014
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.586491
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583880
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583672
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.599974
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.600008
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.599663
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583786
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583664
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583183
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.599663
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583143
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588677
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.572301
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588245
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.586549
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.584633
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.570071
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.564536
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.557475
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.586437
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.584617
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.584552
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.563496
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.557420
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.557300
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.584520
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.557272
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.593930
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.575852
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.593623
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.593626
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.592868
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.574203
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.574477
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.571602
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.593386
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.592815
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.592824
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.573134
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.571113
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.571472
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.592783
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.571047
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690575
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.654306
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690196
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690574
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690448
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.654298
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.650366
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.645913
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690196
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.689941
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690196
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.650366
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.645669
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.645814
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689562
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.645512
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690967
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.648831
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690681
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690964
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690695
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.648782
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648382
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.647046
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690673
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690357
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690438
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.648348
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.646936
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.646995
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690003
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.646860
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691183
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.657356
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691123
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.691105
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690626
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.656095
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.651563
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.643521
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691000
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690262
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690303
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.651076
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.643484
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.642798
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689801
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.642682
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691220
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.651387
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691124
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.691213
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690689
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.650922
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.650756
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.646300
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691110
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690355
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690440
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.650376
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.646300
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.645572
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690001
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.645555
#          Iterations 5
# Fit complete

# %%
print(f'Running Logit specification curve analysis with:\nDEPENDENT VARIABLES = {dvs}\nINDEPENDENT VARIABLES = {ivs_dummy_and_perc}\nCONTROLS = {controls}')
sc = specy.SpecificationCurve(df=df_manual, y_endog=dvs, x_exog=ivs_dummy_and_perc, controls=controls[:4])
sc.fit(estimator=sm.Logit)
sc.plot(show_plot=True)
# Out:
# Running Logit specification curve analysis with:
# DEPENDENT VARIABLES = ['Warmth', 'Competence']
# INDEPENDENT VARIABLES = ['Gender_Female', 'Gender_Mixed', 'Gender_Male', 'Gender_Female_% per Sector', 'Gender_Male_% per Sector', 'Age_Older', 'Age_Mixed', 'Age_Younger', 'Age_Older_% per Sector', 'Age_Younger_% per Sector']
# CONTROLS = ['Job Description spacy_sentencized_num_words', '% Sector per Workforce', 'Sector Job Advertisement Count', 'Keywords Count', 'English Requirement in Job Ad_Yes', 'Dutch Requirement in Job Ad_Yes']
# Optimization terminated successfully.
#          Current function value: 0.677163
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.661686
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.645774
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.609749
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602950
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.644687
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.604004
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.591270
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.607904
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602876
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602631
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.600192
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590850
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590812
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602491
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590191
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.629455
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.629268
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.621915
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.605312
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602736
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.619776
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595202
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590286
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.604086
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602613
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602177
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.591918
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.589645
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.589224
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.601942
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588192
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.663421
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.651197
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.629615
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.606447
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595953
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.629583
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.599953
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581483
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.604140
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595799
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595627
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595543
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.580814
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.581184
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595526
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.580623
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.600135
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.584885
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.600125
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598276
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598206
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.584878
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.581295
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.580461
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598270
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598138
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597901
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.581279
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.580438
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.580085
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597869
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.580082
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588616
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.567290
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588465
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588405
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.587688
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.565910
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.565639
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.562147
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588300
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.587683
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.587562
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.564611
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.561895
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.561849
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.587562
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.561671
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.671029
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.655495
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.633248
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.601502
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594286
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.633109
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592744
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.577909
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.599566
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594194
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594155
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588302
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.577309
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.577674
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594023
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.576929
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.657475
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.650932
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.638998
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.609804
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.601335
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.638746
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.604036
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588053
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.607916
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.601331
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.601333
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.600193
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588009
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588005
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.601325
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.587985
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.640786
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.640122
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626594
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.607030
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602869
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625954
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598956
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.591307
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.605221
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602797
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602677
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594818
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590832
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590972
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602512
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590182
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583553
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.555242
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583268
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583535
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583465
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.555196
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.554574
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.553161
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583243
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583086
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583453
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.554512
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.552876
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.553081
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583037
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.552729
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590585
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.562711
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590500
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590192
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.589532
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.562704
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.561442
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.560611
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590065
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.589505
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.589500
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.561401
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.560602
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.560333
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.589461
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.560333
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691797
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.679924
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.691786
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690989
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690363
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676147
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.660196
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649527
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690854
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.689862
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690112
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.659409
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649496
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649418
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689486
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.649365
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.692235
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.669040
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.692228
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.691526
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690435
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.666583
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.656326
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649703
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691485
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690098
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.689982
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.655661
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649702
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649673
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689502
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.649669
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.692619
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.681775
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692419
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.691510
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690634
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.675552
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.661544
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648915
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691487
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690313
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690141
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.660216
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648915
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648051
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689689
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.648039
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690749
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.648969
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690381
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690734
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690631
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.648897
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648007
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.646011
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690362
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690209
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690383
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.647951
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.645805
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.645943
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689850
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.645695
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691119
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.650913
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691013
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.691111
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690686
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.650396
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649592
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.644353
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690995
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690346
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690390
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.649241
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.644346
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.643489
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689927
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.643433
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.693141
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.684001
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692833
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.691503
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690646
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.677739
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.661057
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649134
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691475
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690312
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690408
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.659725
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649133
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648965
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689976
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.648956
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.692054
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.677497
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692054
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.691442
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690626
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.674893
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.661381
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648934
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691371
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690158
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690119
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.660251
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648820
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648058
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689158
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.647574
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691604
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.670241
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691600
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.691207
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690695
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.665934
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.656002
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649932
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691158
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690354
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690397
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.654777
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649931
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649881
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689818
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.649879
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690591
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.644786
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690251
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690565
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690484
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.644777
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.643943
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.640641
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690234
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690029
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690149
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.643927
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.640340
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.640035
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689523
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.639544
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690957
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.642647
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690708
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690914
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690687
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.642593
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.642043
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.642645
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690641
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690360
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690442
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.641949
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.642587
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.641853
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689998
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.641692
#          Iterations 5
# Fit complete

# %%
print(f'Running OLS specification curve analysis with:\nDEPENDENT VARIABLES = {dvs}\nINDEPENDENT VARIABLES = {ivs_dummy_and_perc}\nCONTROLS = {controls}')
sc = specy.SpecificationCurve(df=df_manual, y_endog=dvs, x_exog=ivs_dummy_and_perc, controls=controls)
sc.fit(estimator=sm.OLS)
sc.plot(show_plot=True)
# Out:
# Running OLS specification curve analysis with:
# DEPENDENT VARIABLES = ['Warmth', 'Competence']
# INDEPENDENT VARIABLES = ['Gender_Female', 'Gender_Mixed', 'Gender_Male', 'Gender_Female_% per Sector', 'Gender_Male_% per Sector', 'Age_Older', 'Age_Mixed', 'Age_Younger', 'Age_Older_% per Sector', 'Age_Younger_% per Sector']
# CONTROLS = ['Job Description spacy_sentencized_num_words', '% Sector per Workforce', 'Sector Job Advertisement Count', 'Keywords Count', 'English Requirement in Job Ad_Yes', 'Dutch Requirement in Job Ad_Yes']
# Fit complete

# %%
print(f'Running Logit specification curve analysis with:\nDEPENDENT VARIABLES = {dvs}\nINDEPENDENT VARIABLES = {ivs_dummy_perc_and_perc_interactions}\nCONTROLS = {controls}')
sc = specy.SpecificationCurve(df=df_manual, y_endog=dvs, x_exog=ivs_dummy_perc_and_perc_interactions, controls=controls[:4])
sc.fit(estimator=sm.Logit)
sc.plot(show_plot=True)
# Out:
# Running Logit specification curve analysis with:
# DEPENDENT VARIABLES = ['Warmth', 'Competence']
# INDEPENDENT VARIABLES = ['Gender_Female', 'Gender_Mixed', 'Gender_Male', 'Gender_Female_% per Sector', 'Gender_Male_% per Sector', 'Age_Older', 'Age_Mixed', 'Age_Younger', 'Age_Older_% per Sector', 'Age_Younger_% per Sector', 'Interaction_Female_Older_% per Sector', 'Interaction_Female_Younger_% per Sector', 'Interaction_Male_Older_% per Sector', 'Interaction_Male_Younger_% per Sector']
# CONTROLS = ['Job Description spacy_sentencized_num_words', '% Sector per Workforce', 'Sector Job Advertisement Count', 'Keywords Count', 'English Requirement in Job Ad_Yes', 'Dutch Requirement in Job Ad_Yes']
# Optimization terminated successfully.
#          Current function value: 0.677163
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.661686
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.645774
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.609749
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602950
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.644687
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.604004
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.591270
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.607904
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602876
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602631
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.600192
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590850
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590812
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602491
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590191
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.629455
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.629268
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.621915
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.605312
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602736
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.619776
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595202
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590286
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.604086
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602613
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602177
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.591918
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.589645
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.589224
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.601942
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588192
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.663421
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.651197
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.629615
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.606447
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595953
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.629583
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.599953
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581483
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.604140
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595799
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595627
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595543
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.580814
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.581184
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595526
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.580623
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.600135
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.584885
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.600125
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598276
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598206
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.584878
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.581295
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.580461
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598270
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598138
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597901
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.581279
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.580438
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.580085
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597869
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.580082
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588616
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.567290
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588465
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588405
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.587688
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.565910
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.565639
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.562147
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588300
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.587683
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.587562
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.564611
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.561895
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.561849
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.587562
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.561671
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.671029
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.655495
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.633248
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.601502
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594286
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.633109
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592744
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.577909
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.599566
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594194
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594155
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588302
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.577309
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.577674
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594023
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.576929
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.657475
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.650932
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.638998
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.609804
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.601335
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.638746
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.604036
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588053
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.607916
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.601331
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.601333
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.600193
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588009
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588005
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.601325
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.587985
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.640786
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.640122
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.626594
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.607030
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602869
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625954
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598956
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.591307
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.605221
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602797
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602677
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594818
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590832
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590972
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602512
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590182
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583553
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.555242
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583268
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583535
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583465
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.555196
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.554574
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.553161
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583243
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583086
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583453
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.554512
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.552876
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.553081
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583037
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.552729
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590585
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.562711
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590500
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590192
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.589532
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.562704
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.561442
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.560611
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590065
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.589505
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.589500
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.561401
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.560602
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.560333
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.589461
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.560333
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.603542
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.593874
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.603487
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598370
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597218
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.593564
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583475
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.579456
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598370
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597087
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596983
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583383
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.579381
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.579209
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596901
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.579173
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.601563
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.586533
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.601563
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.599981
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.600014
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.586491
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583880
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583672
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.599974
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.600008
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.599663
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583786
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583664
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583183
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.599663
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583143
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588677
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.572301
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588245
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.586549
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.584633
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.570071
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.564536
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.557475
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.586437
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.584617
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.584552
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.563496
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.557420
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.557300
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.584520
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.557272
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.593930
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.575852
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.593623
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.593626
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.592868
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.574203
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.574477
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.571602
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.593386
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.592815
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.592824
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.573134
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.571113
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.571472
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.592783
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.571047
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691797
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.679924
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.691786
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690989
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690363
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.676147
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.660196
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649527
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690854
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.689862
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690112
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.659409
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649496
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649418
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689486
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.649365
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.692235
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.669040
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.692228
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.691526
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690435
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.666583
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.656326
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649703
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691485
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690098
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.689982
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.655661
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649702
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649673
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689502
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.649669
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.692619
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.681775
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692419
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.691510
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690634
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.675552
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.661544
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648915
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691487
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690313
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690141
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.660216
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648915
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648051
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689689
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.648039
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690749
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.648969
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690381
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690734
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690631
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.648897
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648007
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.646011
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690362
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690209
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690383
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.647951
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.645805
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.645943
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689850
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.645695
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691119
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.650913
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691013
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.691111
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690686
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.650396
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649592
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.644353
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690995
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690346
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690390
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.649241
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.644346
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.643489
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689927
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.643433
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.693141
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.684001
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692833
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.691503
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690646
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.677739
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.661057
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649134
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691475
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690312
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690408
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.659725
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649133
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648965
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689976
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.648956
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.692054
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.677497
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692054
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.691442
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690626
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.674893
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.661381
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648934
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691371
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690158
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690119
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.660251
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648820
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648058
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689158
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.647574
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691604
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.670241
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691600
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.691207
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690695
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.665934
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.656002
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649932
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691158
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690354
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.690397
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.654777
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649931
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.649881
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689818
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.649879
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690591
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.644786
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690251
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690565
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690484
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.644777
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.643943
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.640641
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690234
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690029
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690149
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.643927
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.640340
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.640035
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689523
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.639544
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690957
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.642647
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690708
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690914
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690687
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.642593
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.642043
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.642645
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690641
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690360
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690442
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.641949
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.642587
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.641853
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689998
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.641692
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690575
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.654306
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690196
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690574
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690448
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.654298
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.650366
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.645913
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690196
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.689941
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690196
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.650366
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.645669
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.645814
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689562
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.645512
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690967
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.648831
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690681
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690964
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690695
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.648782
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.648382
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.647046
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690673
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690357
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690438
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.648348
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.646936
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.646995
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690003
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.646860
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691183
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.657356
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691123
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.691105
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690626
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.656095
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.651563
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.643521
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691000
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690262
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690303
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.651076
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.643484
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.642798
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.689801
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.642682
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691220
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.651387
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691124
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.691213
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690689
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.650922
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.650756
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.646300
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.691110
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690355
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.690440
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.650376
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.646300
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.645572
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.690001
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.645555
#          Iterations 5
# Fit complete

# %%
print(f'Running OLS specification curve analysis with:\nDEPENDENT VARIABLES = {dvs}\nINDEPENDENT VARIABLES = {ivs_dummy_perc_and_perc_interactions}\nCONTROLS = {controls}')
sc = specy.SpecificationCurve(df=df_manual, y_endog=dvs, x_exog=ivs_dummy_perc_and_perc_interactions, controls=controls)
sc.fit(estimator=sm.OLS)
sc.plot(show_plot=True)
# Out:
# Running OLS specification curve analysis with:
# DEPENDENT VARIABLES = ['Warmth', 'Competence']
# INDEPENDENT VARIABLES = ['Gender_Female', 'Gender_Mixed', 'Gender_Male', 'Gender_Female_% per Sector', 'Gender_Male_% per Sector', 'Age_Older', 'Age_Mixed', 'Age_Younger', 'Age_Older_% per Sector', 'Age_Younger_% per Sector', 'Interaction_Female_Older_% per Sector', 'Interaction_Female_Younger_% per Sector', 'Interaction_Male_Older_% per Sector', 'Interaction_Male_Younger_% per Sector']
# CONTROLS = ['Job Description spacy_sentencized_num_words', '% Sector per Workforce', 'Sector Job Advertisement Count', 'Keywords Count', 'English Requirement in Job Ad_Yes', 'Dutch Requirement in Job Ad_Yes']
# Fit complete

# %%
# assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
# df_manual.to_pickle(f'{df_save_dir}df_manual_tokenized_spacy_nltk_gensim_bert.pkl')
# df_manual.to_csv(f'{df_save_dir}df_manual_tokenized_spacy_nltk_gensim_bert.csv')

# %% [markdown]
# # ATTN: This script should be run AFTER all tokenization (spacy, nltk, gensim, and BERT) completed.

# %% [markdown]
# ## Use spacy and nltk for sentiment scoring

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_NGRAMS_BOW
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %%
# import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# mod = sys.modules[__name__]

# code_dir = None
# code_dir_name = 'Code'
# unwanted_subdir_name = 'Analysis'

# if code_dir_name not in str(Path.cwd()).split('/')[-1]:
#     for _ in range(5):

#         parent_path = str(Path.cwd().parents[_]).split('/')[-1]

#         if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

#             code_dir = str(Path.cwd().parents[_])

#             if code_dir is not None:
#                 break
# else:
#     code_dir = str(Path.cwd())
# sys.path.append(code_dir)

# # %load_ext autoreload
# # %autoreload 2

# %%
# from setup_module.imports import * # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# %%
# df_manual = pd.read_pickle(f'{df_save_dir}df_manual_tokenized_spacy_nltk_gensim_bert.pkl')
# df_manual = pd.read_pickle(f'{df_save_dir}df_manual_for_training.pkl')

# %%
# get_df_info(df_manual, ivs_all=dvs)

# %%
# %%time
# # NLTK sentiment
# df_manual['Job Description nltk_sentiment'] = df_manual['Job Description spacy_sentencized'].progress_apply(
#     lambda sentence: float(sentim_analyzer.polarity_scores(sentence)['compound'])
#     if isinstance(sentence, str) else np.nan
# )

# %%
# df_manual['Job Description nltk_sentiment'].head()

# %%
# assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
# df_manual.to_pickle(f'{df_save_dir}df_manual_sentiment_nltk.pkl')
# df_manual.to_csv(f'{df_save_dir}df_manual_sentiment_nltk.csv')

# %% [markdown]
# # ATTN: This script should be run AFTER all sentiment analysis (spacy, nltk) completed.

# %% [markdown]
# ## Use spacy to create Parts-Of-Speech (POS) tags, lemmas, and stems

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_TOKENIZED_SPACY_NLTK_GENSIM_BERT
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %%
# import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# mod = sys.modules[__name__]

# code_dir = None
# code_dir_name = 'Code'
# unwanted_subdir_name = 'Analysis'

# if code_dir_name not in str(Path.cwd()).split('/')[-1]:
#     for _ in range(5):

#         parent_path = str(Path.cwd().parents[_]).split('/')[-1]

#         if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

#             code_dir = str(Path.cwd().parents[_])

#             if code_dir is not None:
#                 break
# else:
#     code_dir = str(Path.cwd())
# sys.path.append(code_dir)

# # %load_ext autoreload
# # %autoreload 2

# %%
# from setup_module.imports import * # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# %%
# df_manual = pd.read_pickle(f'{df_save_dir}df_manual_sentiment_nltk.pkl')

# %%
## Warmth 1 = 1595 (24.90%), Competence 1 = 2836 (44.30%)
# get_df_info(df_manual, ivs_all=dvs)

# %%
# df_manual.info()

# %%
# %%time
# # Load customer characters
# with open(f'{data_dir}punctuations.txt', 'rb') as f:
#     custom_punct_chars = pickle.load(f)

# # POS tagging
# df_manual['Job Description spacy_token_tags'] = df_manual[
#     'Job Description spacy_sentencized'
# ].progress_apply(
#     lambda job_sentence: [
#         (token.text.strip().lower(), token.tag_) for token in nlp(job_sentence)
#     ]
# )

# # Lemmatization
# df_manual['Job Description spacy_lemmas'] = df_manual['Job Description spacy_sentencized'].progress_apply(
#     lambda job_sentence: [
#         token.lemma_.strip().lower()
#         for token in nlp(job_sentence)
#         if token.text is not None
#         and len(token.text) != 0
#         and token.text != '...'
#         and not token.is_space
#         and not token.is_stop
#         and not token.is_punct
#         and not token.is_quote
#         and token.is_ascii
#         and not token.is_bracket
#         and not token.like_email
#     ]
# )

# # Stemming
# df_manual['Job Description spacy_stems'] = df_manual['Job Description spacy_sentencized'].progress_apply(
#     lambda job_sentence: [
#         stemmer.stem(token.text.strip().lower())
#         for token in nlp(job_sentence)
#         if token.text is not None
#         and len(token) != 0
#         and len(token.text) != 0
#         and bool(token)
#         and bool(token.text)
#         and token.text != '...'
#         and not token.is_space
#         and not token.is_punct
#         and not token.is_quote
#         and not token.is_bracket
#         and not token.like_email
#     ]
# )

# assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
# df_manual.to_pickle(f'{df_save_dir}df_manual_tags_lemmas_stems_spacy.pkl')
# df_manual.to_csv(f'{df_save_dir}df_manual_tags_lemmas_stems_spacy.csv')

# %%
# df_manual.info()

# %%
# df_manual[
#     [
#         'Job Description spacy_token_tags',
#         'Job Description spacy_lemmas',
#         'Job Description spacy_stems'
#     ]
# ].head()

# %%
# assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
# df_manual.to_pickle(f'{df_save_dir}df_manual_tags_lemmas_stems_spacy.pkl')
# df_manual.to_csv(f'{df_save_dir}df_manual_tags_lemmas_stems_spacy.csv')

# %% [markdown]
# ## Use NLTK to create Parts-Of-Speech (POS) tags, lemmas, and stems

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_TAGS_LEMMAS_STEMS_SPACY
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %%
# import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# mod = sys.modules[__name__]

# code_dir = None
# code_dir_name = 'Code'
# unwanted_subdir_name = 'Analysis'

# if code_dir_name not in str(Path.cwd()).split('/')[-1]:
#     for _ in range(5):

#         parent_path = str(Path.cwd().parents[_]).split('/')[-1]

#         if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

#             code_dir = str(Path.cwd().parents[_])

#             if code_dir is not None:
#                 break
# else:
#     code_dir = str(Path.cwd())
# sys.path.append(code_dir)

# # %load_ext autoreload
# # %autoreload 2

# %%
# from setup_module.imports import * # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# %%
# def get_wordnet_pos(token):
#     """Map POS tag to first character lemmatize() accepts"""
#     tag = nltk.pos_tag([token])[0][1][0].upper()
#     tag_dict = {"J": wordnet.ADJ,
#                 "N": wordnet.NOUN,
#                 "V": wordnet.VERB,
#                 "R": wordnet.ADV}

#     return tag_dict.get(tag, wordnet.NOUN)

# %%
# df_manual = pd.read_pickle(f'{df_save_dir}df_manual_tags_lemmas_stems_spacy.pkl')

# %%
# get_df_info(df_manual, ivs_all=dvs)

# %%
# df_manual.info()

# %%
# %%time
# # POS tagging
# df_manual['Job Description nltk_token_tags'] = df_manual['Job Description spacy_tokenized'].progress_apply(
#     lambda token: pos_tag(token)
# )

# # Lemmatization
# df_manual['Job Description nltk_lemmas'] = df_manual['Job Description spacy_tokenized'].progress_apply(
#     lambda tokens: [
#         lemmatizer.lemmatize(
#             token, get_wordnet_pos(
#                 unicodedata.normalize('NFKD', str(token.strip().lower())).encode('ascii', 'ignore').decode('utf-8', 'ignore')
#             )
#         )
#         for token in tokens
#     ]
# )

# # Stemming
# df_manual['Job Description nltk_stems'] = df_manual['Job Description spacy_tokenized'].progress_apply(
#     lambda tokens: [
#         stemmer.stem(
#             unicodedata.normalize('NFKD', str(token.strip().lower())).encode('ascii', 'ignore').decode('utf-8', 'ignore')
#         )
#         for token in tokens
#     ]
# )

# assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
# df_manual.to_pickle(f'{df_save_dir}df_manual_tags_lemmas_stems_spacy_nltk.pkl')
# df_manual.to_csv(f'{df_save_dir}df_manual_tags_lemmas_stems_spacy_nltk.csv')

# %%
# df_manual.info()

# %%
# df_manual[['Job Description nltk_token_tags', 'Job Description nltk_lemmas', 'Job Description nltk_stems']].head()

# %%
# assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
# df_manual.to_pickle(f'{df_save_dir}df_manual_tags_lemmas_stems_spacy_nltk.pkl')
# df_manual.to_csv(f'{df_save_dir}df_manual_tags_lemmas_stems_spacy_nltk.csv')

# %% [markdown]
# ## Use BERT to create Parts-Of-Speech (POS) tags, lemmas, and stems

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_TAGS_LEMMAS_STEMS_SPACY_NLTK
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %%
# import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# mod = sys.modules[__name__]

# code_dir = None
# code_dir_name = 'Code'
# unwanted_subdir_name = 'Analysis'

# if code_dir_name not in str(Path.cwd()).split('/')[-1]:
#     for _ in range(5):

#         parent_path = str(Path.cwd().parents[_]).split('/')[-1]

#         if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

#             code_dir = str(Path.cwd().parents[_])

#             if code_dir is not None:
#                 break
# else:
#     code_dir = str(Path.cwd())
# sys.path.append(code_dir)

# # %load_ext autoreload
# # %autoreload 2

# %%
# from setup_module.imports import * # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# %%
# df_manual = pd.read_pickle(f'{df_save_dir}df_manual_tags_lemmas_stems_spacy_nltk.pkl')

# %%
# get_df_info(df_manual, ivs_all=dvs)

# %%
# %%time
# bert_pos_model_name = 'QCRI/bert-base-multilingual-cased-pos-english'
# bert_pos_model = AutoModelForTokenClassification.from_pretrained(bert_pos_model_name, trust_remote_code=True).to(device)
# bert_pos_tagger = TokenClassificationPipeline(model=bert_pos_model, tokenizer=bert_tokenizer).to(device)

# df_manual['Job Description bert_token_tags_with_scores'] = df_manual['Job Description spacy_sentencized'].progress_apply(
#     lambda sentence: [
#         (bert_pos_tag['word'], bert_pos_tag['entity'], bert_pos_tag['score'])
#         for i in range(len(sentence.split()))
#         for bert_pos_tag in bert_pos_tagger(sentence)
#     ]
# )

# df_manual['Job Description bert_token_tags'] = df_manual['Job Description bert_token_tags_with_scores'].progress_apply(
#     lambda tag_list: [
#         [(tag_list[i][0], tag_list[i][1])]
#         for tag_tuple in tag_list
#         for i in range(len(tag_list))
#     ]
# )


# assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
# df_manual.to_pickle(f'{df_save_dir}df_manual_tags_lemmas_stems_spacy_nltk_bert.pkl')
# df_manual.to_csv(f'{df_save_dir}df_manual_tags_lemmas_stems_spacy_nltk_bert.csv')

# %%
# df_manual['Job Description bert_token_tags'].head()

# %%
# assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
# df_manual.to_pickle(f'{df_save_dir}df_manual_tags_lemmas_stems_spacy_nltk_bert.pkl')
# df_manual.to_csv(f'{df_save_dir}df_manual_tags_lemmas_stems_spacy_nltk_bert.csv')

# %% [markdown]
# # ATTN: This script should be run AFTER all POS tagging, lemmatization, and stemming (spacy and nltk) completed. If BERT POS tagging was done, change pkl file loading

# %% [markdown]
# ## Use spacy to create bi and trigrams

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_TAGS_LEMMAS_STEMS_SPACY_NLTK
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %%
# import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# mod = sys.modules[__name__]

# code_dir = None
# code_dir_name = 'Code'
# unwanted_subdir_name = 'Analysis'

# if code_dir_name not in str(Path.cwd()).split('/')[-1]:
#     for _ in range(5):

#         parent_path = str(Path.cwd().parents[_]).split('/')[-1]

#         if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

#             code_dir = str(Path.cwd().parents[_])

#             if code_dir is not None:
#                 break
# else:
#     code_dir = str(Path.cwd())
# sys.path.append(code_dir)

# # %load_ext autoreload
# # %autoreload 2

# %%
# from setup_module.imports import * # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# %%
# def spacy_make_ngrams(sentence, matcher, gram_type):

#     doc = nlp(sentence)
#     matches = matcher(doc)
#     matches_list = []

#     for idx in range(len(matches)):
#         for match_id, start, end in matches:
#             if nlp.vocab.strings[match_id].split('_')[0] == gram_type:
#                 match = doc[matches[idx][1]: matches[idx][2]].text
#                 matches_list.append(match.lower())

#     return list(set(matches_list))

# %%
# df_manual = pd.read_pickle(f'{df_save_dir}df_manual_tags_lemmas_stems_spacy_nltk_bert.pkl')

# %%
# get_df_info(df_manual, ivs_all=dvs)

# %%
# %%time
# df_manual['Job Description spacy_1grams_original_list'] = df_manual['Job Description spacy_tokenized']
# df_manual['Job Description spacy_1grams'] = df_manual['Job Description spacy_tokenized'].progress_apply(
#     lambda tokens: [
#         tuple(token.split())
#         for token in tokens
#     ]
# )

# %%
# %%time
# # Spacy bi and trigrams
# matcher = Matcher(nlp.vocab)

# bigram_rules = [
#     ['NOUN', 'VERB'],
#     ['VERB', 'NOUN'],
#     ['ADJ', 'NOUN'],
#     ['ADJ', 'PROPN'],
#     # more rules here...
# ]

# trigram_rules = [
#     ['VERB', 'ADJ', 'NOUN'],
#     ['NOUN', 'VERB', 'ADV'],
#     ['NOUN', 'ADP', 'NOUN'],
#     # more rules here...
# ]

# patters_dict = {
#     'bigram_patterns': [[{'POS': i} for i in j] for j in bigram_rules],
#     'trigram_patterns': [[{'POS': i} for i in j] for j in trigram_rules],
# }

# ngram_dict = {
#     'bigram': 2,
#     'trigram': 3,
# }

# for ngram_name, ngram_num in tqdm.tqdm(ngram_dict.items()):

#     matcher.add(f'{ngram_name}_patterns', patters_dict[f'{ngram_name}_patterns'])

#     df_manual[f'Job Description spacy_{str(ngram_num)}grams_original_list'] = df_manual['Job Description spacy_sentencized'].progress_apply(
#         lambda sentence:
#             [
#                 '_'.join(ngram_.split())
#                 for ngram_ in spacy_make_ngrams(sentence, matcher, ngram_name)
#             ]
#     )

#     df_manual[f'Job Description spacy_{str(ngram_num)}grams'] = df_manual['Job Description spacy_sentencized'].progress_apply(
#         lambda sentence:
#             [
#                 tuple(ngram_.split())
#                 for ngram_ in spacy_make_ngrams(sentence, matcher, ngram_name)
#             ]
#     )

#     df_manual[f'Job Description spacy_{str(ngram_num)}grams_in_sent'] = df_manual['Job Description spacy_sentencized'].str.lower().replace(
#         regex = {
#             re.escape(' '.join(ngram_.split('_'))): re.escape(ngram_)
#             for ngrams_list in df_manual[f'Job Description spacy_{str(ngram_num)}grams_original_list']
#             for ngram_ in ngrams_list
#             if '_' in ngram_
#         }
#     )

#     if f'{ngram_name}_patterns' in matcher:
#         matcher.remove(f'{ngram_name}_patterns')
#     assert f'{ngram_name}_patterns' not in matcher

# %%
# %%time
# # Spacy Allgrams
# df_manual['Job Description spacy_123grams_original_list'] = df_manual['Job Description spacy_tokenized'] + df_manual['Job Description spacy_2grams_original_list'] + df_manual['Job Description spacy_3grams_original_list']
# df_manual['Job Description spacy_123grams'] = df_manual['Job Description spacy_1grams'] + df_manual['Job Description spacy_2grams'] + df_manual['Job Description spacy_3grams']
# df_manual['Job Description spacy_123grams_in_sent'] = (
#     df_manual['Job Description spacy_sentencized']
#     .str.lower()
#     .replace(
#         regex={
#             re.escape(' '.join(ngram_.split('_'))): re.escape(ngram_)
#             for ngrams_list in df_manual[
#                 'Job Description spacy_123grams_original_list'
#             ]
#             for ngram_ in ngrams_list
#             if '_' in ngram_
#         }
#     )
# )

# %%
# assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
# df_manual.to_pickle(f'{df_save_dir}df_manual_ngrams_spacy.pkl')
# df_manual.to_csv(f'{df_save_dir}df_manual_ngrams_spacy.csv')

# %% [markdown]
# ## Use NLTK to create bi and trigrams

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_NGRAMS_SPACY
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %%
# import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# mod = sys.modules[__name__]

# code_dir = None
# code_dir_name = 'Code'
# unwanted_subdir_name = 'Analysis'

# if code_dir_name not in str(Path.cwd()).split('/')[-1]:
#     for _ in range(5):

#         parent_path = str(Path.cwd().parents[_]).split('/')[-1]

#         if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

#             code_dir = str(Path.cwd().parents[_])

#             if code_dir is not None:
#                 break
# else:
#     code_dir = str(Path.cwd())
# sys.path.append(code_dir)

# # %load_ext autoreload
# # %autoreload 2

# %%
# from setup_module.imports import * # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# %%
# df_manual = pd.read_pickle(f'{df_save_dir}df_manual_ngrams_spacy.pkl')

# %%
# get_df_info(df_manual, ivs_all=dvs)

# %%
# %%time
# df_manual['Job Description nltk_1grams_original_list'] = df_manual['Job Description nltk_tokenized']
# df_manual['Job Description nltk_1grams'] = df_manual['Job Description nltk_tokenized'].progress_apply(
#     lambda tokens: [
#         tuple(token.split())
#         for token in tokens
#     ]
# )

# %%
# %%time
# # NLTK bi and trigrams
# ngram_dict = {
#     'bigram': 2,
#     'trigram': 3
# }

# for ngram_name, ngram_num in tqdm.tqdm(ngram_dict.items()):

#     df_manual[f'Job Description nltk_{str(ngram_num)}grams_original_list'] = df_manual['Job Description nltk_tokenized'].progress_apply(
#         lambda tokens:
#             list(
#                 '_'.join(ngram_list)
#                 for ngram_list in nltk.ngrams(tokens, ngram_num)
#             )
#     )

#     df_manual[f'Job Description nltk_{str(ngram_num)}grams'] = df_manual['Job Description nltk_tokenized'].progress_apply(
#         lambda tokens: list(nltk.ngrams(tokens, ngram_num))
#     )

#     df_manual[f'Job Description nltk_{str(ngram_num)}grams_in_sent'] = df_manual['Job Description spacy_sentencized'].str.lower().replace(
#         regex = {
#             re.escape(' '.join(ngram_.split('_'))): re.escape(ngram_)
#             for ngrams_list in df_manual[f'Job Description nltk_{str(ngram_num)}grams_original_list']
#             for ngram_ in ngrams_list
#             if '_' in ngram_
#         }
#     )

# %%
# %%time
# # NLTK Allgrams
# df_manual['Job Description nltk_123grams_original_list'] = (
#     df_manual['Job Description nltk_tokenized']
#     + df_manual['Job Description nltk_2grams_original_list']
#     + df_manual['Job Description nltk_3grams_original_list']
# )
# df_manual['Job Description nltk_123grams'] = (
#     df_manual['Job Description nltk_1grams']
#     + df_manual['Job Description nltk_2grams']
#     + df_manual['Job Description nltk_3grams']
# )
# df_manual['Job Description nltk_123grams_in_sent'] = (
#     df_manual['Job Description spacy_sentencized']
#     .str.lower()
#     .replace(
#         regex={
#             re.escape(' '.join(ngram_.split('_'))): re.escape(ngram_)
#             for ngrams_list in df_manual[
#                 'Job Description nltk_123grams_original_list'
#             ]
#             for ngram_ in ngrams_list
#             if '_' in ngram_
#         }
#     )
# )

# %%
# assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
# df_manual.to_pickle(f'{df_save_dir}df_manual_ngrams_spacy_nltk.pkl')
# df_manual.to_csv(f'{df_save_dir}df_manual_ngrams_spacy_nltk.csv')

# %% [markdown]
# ## Use Gensim to create bi and trigrams

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_NGRAMS_SPACY_NLTK
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %%
# import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# mod = sys.modules[__name__]

# code_dir = None
# code_dir_name = 'Code'
# unwanted_subdir_name = 'Analysis'

# if code_dir_name not in str(Path.cwd()).split('/')[-1]:
#     for _ in range(5):

#         parent_path = str(Path.cwd().parents[_]).split('/')[-1]

#         if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

#             code_dir = str(Path.cwd().parents[_])

#             if code_dir is not None:
#                 break
# else:
#     code_dir = str(Path.cwd())
# sys.path.append(code_dir)

# # %load_ext autoreload
# # %autoreload 2

# %%
# from setup_module.imports import * # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# %%
# df_manual = pd.read_pickle(f'{df_save_dir}df_manual_ngrams_spacy_nltk.pkl')

# %%
# get_df_info(df_manual, ivs_all=dvs)

# %%
# df_manual['Job Description gensim_1grams_original_list'] = df_manual['Job Description gensim_tokenized']
# df_manual['Job Description gensim_1grams'] = df_manual['Job Description gensim_tokenized'].progress_apply(
#     lambda tokens: [
#         tuple(token.split())
#         for token in tokens
#     ]
# )

# %%
# %%time
# # Gensim bi and trigrams
# # Gensim Bigrams
# bigram = Phraser(Phrases(df_manual['Job Description gensim_tokenized'], connector_words=ENGLISH_CONNECTOR_WORDS, min_count=1, threshold=1))
# df_manual['Job Description gensim_2grams_original_list_all'] = bigram[df_manual['Job Description gensim_tokenized']]
# df_manual['Job Description gensim_2grams_original_list'] = df_manual['Job Description gensim_2grams_original_list_all'].progress_apply(
#     lambda ngrams_list: [
#         ngram_
#         for ngram_ in ngrams_list
#         if len(re.findall('[a-zA-Z]*\_[a-zA-Z]*', ngram_)) != 0
#     ]
# )
# df_manual['Job Description gensim_2grams'] = df_manual['Job Description gensim_2grams_original_list'].progress_apply(
#     lambda ngrams: [
#         tuple(ngram.split('_'))
#         for ngram in ngrams
#         if '_' in ngram
#     ]
# )
# df_manual['Job Description gensim_2grams_in_sent'] = (
#     df_manual['Job Description spacy_sentencized']
#     .str.lower()
#     .progress_apply(
#         lambda sentence: ' '.join(
#             preprocess_string(re.sub(pattern, ' ', sentence.strip().lower()))
#         )
#     )
#     .replace(
#         regex={
#             re.escape(' '.join(ngram_.split('_'))): re.escape(ngram_)
#             for ngrams_list in df_manual[
#                 'Job Description gensim_2grams_original_list'
#             ]
#             for ngram_ in ngrams_list
#             if '_' in ngram_
#         }
#     )
# )

# # Gensim Trigrams
# trigram = Phraser(Phrases(df_manual['Job Description gensim_2grams_original_list_all'], connector_words=ENGLISH_CONNECTOR_WORDS, min_count=1, threshold=1))
# df_manual['Job Description gensim_3grams_original_list_all'] = trigram[df_manual['Job Description gensim_2grams_original_list_all']]
# df_manual['Job Description gensim_3grams_original_list'] = df_manual['Job Description gensim_3grams_original_list_all'].progress_apply(
#     lambda ngrams_list: [
#         ngram_
#         for ngram_ in ngrams_list
#         if len(re.findall('[a-zA-Z]*\_[a-zA-Z]*\_[a-zA-Z]*', ngram_)) != 0
#     ]
# )
# df_manual['Job Description gensim_3grams'] = df_manual['Job Description gensim_3grams_original_list'].progress_apply(
#     lambda ngrams: [
#         tuple(ngram.split('_'))
#         for ngram in ngrams
#         if '_' in ngram
#     ]
# )
# df_manual['Job Description gensim_3grams_in_sent'] = (
#     df_manual['Job Description spacy_sentencized']
#     .str.lower()
#     .progress_apply(
#         lambda sentence: ' '.join(
#             preprocess_string(re.sub(pattern, ' ', sentence.strip().lower()))
#         )
#     )
#     .replace(
#         regex={
#             re.escape(' '.join(ngram_.split('_'))): re.escape(ngram_)
#             for ngrams_list in df_manual[
#                 'Job Description gensim_3grams_original_list'
#             ]
#             for ngram_ in ngrams_list
#             if '_' in ngram_
#         }
#     )
# )

# %%
# %%time
# # Gensim Allgrams
# pattern = r'[\n]+|[,]{2,}|[|]{2,}|[\n\r]+|(?<=[a-z]\.)(?=\s*[A-Z])|(?=\:+[A-Z])'

# df_manual['Job Description gensim_123grams_original_list'] = (
#     df_manual['Job Description gensim_tokenized']
#     + df_manual['Job Description gensim_2grams_original_list']
#     + df_manual['Job Description gensim_3grams_original_list']
# )
# df_manual['Job Description gensim_123grams'] = (
#     df_manual['Job Description gensim_1grams']
#     + df_manual['Job Description gensim_2grams']
#     + df_manual['Job Description gensim_3grams']
# )
# df_manual['Job Description gensim_123grams_in_sent'] = (
#     df_manual['Job Description spacy_sentencized']
#     .str.lower()
#     .progress_apply(
#         lambda sentence: ' '.join(
#             preprocess_string(re.sub(pattern, ' ', sentence.strip().lower()))
#         )
#     )
#     .replace(
#         regex={
#             re.escape(' '.join(ngram_.split('_'))): re.escape(ngram_)
#             for ngrams_list in df_manual[
#                 'Job Description gensim_123grams_original_list'
#             ]
#             for ngram_ in ngrams_list
#             if '_' in ngram_
#         }
#     )
# )

# %%
# assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
# df_manual.to_pickle(f'{df_save_dir}df_manual_ngrams_spacy_nltk_gensim.pkl')
# df_manual.to_csv(f'{df_save_dir}df_manual_ngrams_spacy_nltk_gensim.csv')

# %% [markdown]
# ## Create word frequencies for uni, bi, and trigrams

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_NGRAMS_SPACY_NLTK_GENSIM
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %%
# import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# mod = sys.modules[__name__]

# code_dir = None
# code_dir_name = 'Code'
# unwanted_subdir_name = 'Analysis'

# if code_dir_name not in str(Path.cwd()).split('/')[-1]:
#     for _ in range(5):

#         parent_path = str(Path.cwd().parents[_]).split('/')[-1]

#         if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

#             code_dir = str(Path.cwd().parents[_])

#             if code_dir is not None:
#                 break
# else:
#     code_dir = str(Path.cwd())
# sys.path.append(code_dir)

# # %load_ext autoreload
# # %autoreload 2

# %%
# from setup_module.imports import * # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# %%
# def get_abs_frequency(row, text_col, ngram_num, embedding_library):

#     abs_word_freq = defaultdict(int)
#     for word in row[f'Job Description {embedding_library}_{ngram_num}grams_original_list']:
#         abs_word_freq[word] += 1

#         abs_wtd_df = (
#             pd.DataFrame.from_dict(abs_word_freq, orient='index')
#             .rename(columns={0: 'abs_word_freq'})
#             .sort_values(by=['abs_word_freq'], ascending=False)
#             )
#         abs_wtd_df.insert(1, 'abs_word_perc', value=abs_wtd_df['abs_word_freq'] / abs_wtd_df['abs_word_freq'].sum())
#         abs_wtd_df.insert(2, 'abs_word_perc_cum', abs_wtd_df['abs_word_perc'].cumsum())

#         row[f'Job Description {embedding_library}_{ngram_num}grams_abs_word_freq'] = str(abs_wtd_df['abs_word_freq'].to_dict())
#         row[f'Job Description {embedding_library}_{ngram_num}grams_abs_word_perc'] = str(abs_wtd_df['abs_word_perc'].to_dict())
#         row[f'Job Description {embedding_library}_{ngram_num}grams_abs_word_perc_cum'] = str(abs_wtd_df['abs_word_perc_cum'].to_dict())

#     return row

# %%
# df_manual = pd.read_pickle(f'{df_save_dir}df_manual_ngrams_spacy_nltk_gensim.pkl')

# %%
# get_df_info(df_manual, ivs_all=dvs)

# %%
# %%time
# ngrams_list=[1, 2, 3, 123]
# embedding_libraries_list = ['spacy', 'nltk', 'gensim']

# for embedding_library, ngram_num in tqdm_product(embedding_libraries_list, ngrams_list):
#     df_manual[f'Job Description {embedding_library}_{ngram_num}grams_count'] = df_manual[f'Job Description {embedding_library}_{ngram_num}grams'].progress_apply(lambda x: len(x))
#     df_manual = df_manual.progress_apply(lambda row: get_abs_frequency(row=row, text_col='Job Description spacy_tokenized', ngram_num=ngram_num, embedding_library=embedding_library), axis='columns')

# %%
# assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
# df_manual.to_pickle(f'{df_save_dir}df_manual_ngrams_frequency.pkl')
# df_manual.to_csv(f'{df_save_dir}df_manual_ngrams_frequency.csv')

# %% [markdown]
# ## Create BoW dictionary, corpus, and tfidf matrix for uni, bi, and trigrams

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_NGRAMS_FREQUENCY
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %%
# import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# mod = sys.modules[__name__]

# code_dir = None
# code_dir_name = 'Code'
# unwanted_subdir_name = 'Analysis'

# if code_dir_name not in str(Path.cwd()).split('/')[-1]:
#     for _ in range(5):

#         parent_path = str(Path.cwd().parents[_]).split('/')[-1]

#         if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

#             code_dir = str(Path.cwd().parents[_])

#             if code_dir is not None:
#                 break
# else:
#     code_dir = str(Path.cwd())
# sys.path.append(code_dir)

# # %load_ext autoreload
# # %autoreload 2

# %%
# from setup_module.imports import * # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# %%
# def get_corpus_and_dictionary(row, ngram_num, embedding_library):

#     ngrams_original_list = row[f'Job Description {embedding_library}_{ngram_num}grams_original_list']
#     dictionary = Dictionary([ngrams_original_list])
#     BoW_corpus = [dictionary.doc2bow(ngrams_original_list)]
#     tfidf = TfidfModel(BoW_corpus, smartirs='ntc')
#     tfidf_matrix = [tfidf[doc] for doc in BoW_corpus]

#     row[f'Job Description {embedding_library}_{ngram_num}grams_dictionary'] = dictionary
#     row[f'Job Description {embedding_library}_{ngram_num}grams_BoW_corpus'] = BoW_corpus
#     row[f'Job Description {embedding_library}_{ngram_num}grams_tfidf'] = tfidf
#     row[f'Job Description {embedding_library}_{ngram_num}grams_tfidf_matrix'] = tfidf_matrix

#     return row

# %%
# df_manual = pd.read_pickle(f'{df_save_dir}df_manual_ngrams_frequency.pkl')

# %%
# get_df_info(df_manual, ivs_all=dvs)

# %%
# %%time
# ngrams_list=[1, 2, 3, 123]
# embedding_libraries_list = ['spacy', 'nltk', 'gensim']
# for embedding_library, ngram_num in tqdm_product(embedding_libraries_list, ngrams_list):
#     df_manual = df_manual.progress_apply(
#         lambda row: get_corpus_and_dictionary(
#             row=row, ngram_num=ngram_num, embedding_library=embedding_library
#         ),
#         axis='columns'
#     )

# assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
# df_manual.to_pickle(f'{df_save_dir}df_manual_ngrams_frequency.pkl')
# df_manual.to_csv(f'{df_save_dir}df_manual_ngrams_BoW.csv')

# %%
# df_manual.columns

# %%
# assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
# df_manual.to_pickle(f'{df_save_dir}df_manual_ngrams_BoW.pkl')
# df_manual.to_csv(f'{df_save_dir}df_manual_ngrams_BoW.csv')

# %% [markdown]
# # ATTN: This script should be run AFTER all sentiment scoring (spacy and nltk) completed.

# %% [markdown]
# ## Word2Vec and FastText embeddings

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_SENTIMENT_SPACY_NLTK
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %%
# import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# mod = sys.modules[__name__]

# code_dir = None
# code_dir_name = 'Code'
# unwanted_subdir_name = 'Analysis'

# if code_dir_name not in str(Path.cwd()).split('/')[-1]:
#     for _ in range(5):

#         parent_path = str(Path.cwd().parents[_]).split('/')[-1]

#         if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

#             code_dir = str(Path.cwd().parents[_])

#             if code_dir is not None:
#                 break
# else:
#     code_dir = str(Path.cwd())
# sys.path.append(code_dir)

# # %load_ext autoreload
# # %autoreload 2

# %%
# from setup_module.imports import *  # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# %%
# def build_train_word2vec(df, ngram_number, embedding_library, size = 300, words=None, t = time.time(), cores = multiprocessing.cpu_count()):
#     if words is None:
#         words = [
#             'she',
#             'he',
#             'support',
#             'leader',
#             'management',
#             'team',
#             'business',
#             'customer',
#             'risk',
#             'build',
#             'computer',
#             'programmer',
#         ]
#     sentences = df[f'Job Description {embedding_library}_{ngram_number}grams_original_list'].values

#     w2v_model = Word2Vec(
#         sentences=sentences,
#         vector_size=size,
#         min_count=0,
#         window=2,
#         sample=6e-5,
#         alpha=0.03,
#         min_alpha=0.0007,
#         negative=20,
#         workers=cores - 1,
#         sg = 1,
#     )

#     w2v_model.build_vocab(sentences, progress_per=10000)
#     print(f'Time to train the model for {size}: {round((time.time() - t) / 60, 2)} mins')

#     w2v_model.train(
#         sentences,
#         total_examples=w2v_model.corpus_count,
#         epochs=30,
#         report_delay=1,
#     )

#     print(f'Time to build w2v_vocab for {size}: {round((time.time() - t) / 60, 2)} mins')
#     w2v_vocab = list(w2v_model.wv.index_to_key)

#     print(f'Checking words form list of length {len(words)}')
#     print(f'WORDS LIST: {words}')

# #     for word in words:
# #         print(f'Checking word:\n{word.upper()}:')
# #         try:
# # #             print(f'Word2Vec {size}: {w2v_model.wv[word]}')
# #             print(f'Length of {size} model vobal: {len(w2v_vocab)}')
# #             print(f'{size} - Positive most similar to {word}: {w2v_model.wv.most_similar(positive=word, topn=5)}')
# #             print(f'{size} - Negative most similar to {word}: {w2v_model.wv.most_similar(negative=word, topn=5)}')

# #         except KeyError as e:
# #             print(e)

#     return w2v_vocab, w2v_model

# def word2vec_embeddings(sentences, w2v_vocab, w2v_model, size=300):

#     sentences = [word for word in sentences if word in w2v_vocab]

#     return (
#         np.mean(w2v_model.wv[sentences], axis=0)
#         if sentences
#         else np.zeros(size)
#     )

# %%
# def build_train_fasttext(df, ngram_number, embedding_library, size = 300, words=None, t = time.time(), cores = multiprocessing.cpu_count()):
#     if words is None:
#         words = [
#             'she',
#             'he',
#             'support',
#             'leader',
#             'management',
#             'team',
#             'business',
#             'customer',
#             'risk',
#             'build',
#             'computer',
#             'programmer',
#         ]
#     sentences = df[f'Job Description {embedding_library}_{ngram_number}grams_original_list'].values

#     ft_model = FastText(
#         sentences=sentences,
#         vector_size=size,
#         min_count=0,
#         window=2,
#         sample=6e-5,
#         alpha=0.03,
#         min_alpha=0.0007,
#         negative=20,
#         workers=cores - 1,
#         sg = 1,
#     )

#     ft_model.build_vocab(sentences, progress_per=10000)
#     print(f'Time to train the model for {size}: {round((time.time() - t) / 60, 2)} mins')

#     ft_model.train(
#         sentences,
#         total_examples=ft_model.corpus_count,
#         epochs=30,
#         report_delay=1,
#     )

#     print(f'Time to build vocab for {size}: {round((time.time() - t) / 60, 2)} mins')
#     ft_vocab = list(ft_model.wv.index_to_key)

#     print(f'Checking words form list of length {len(words)}')
#     print(f'WORDS LIST: {words}')

# #     for word in words:
# #         print(f'Checking word:\n{word.upper()}:')
# #         try:
# # #             print(f'FastText {size}: {ft_model_300.wv[word]}')
# #             print(f'Length of {size} model vobal: {len(ft_vocab)}')
# #             print(f'{size} - Positive most similar to {word}: {ft_model.wv.most_similar(positive=word, topn=5)}')
# #             print(f'{size} - Negative most similar to {word}: {ft_model.wv.most_similar(negative=word, topn=5)}')

# #         except KeyError as e:
# #             print(e)

#     return ft_vocab, ft_model

# def fasttext_embeddings(sentences, ft_vocab, ft_model, size=300):

#     sentences = [word for word in sentences if word in ft_vocab]

#     return np.mean(ft_model.wv[sentences], axis=0) if sentences else np.zeros(size)

# %%
# def get_glove(glove_file = f'{llm_path}gensim/glove/glove.840B.300d.txt'):
#     embeddings_index = {}
#     with open(glove_file, 'r', encoding='utf8') as glove:

#         for line in glove:
#             values = line.split()
#             word = values[0]

#             with contextlib.suppress(ValueError):
#                 coefs = np.asarray(values[1:], dtype='float32')
#                 embeddings_index[word] = coefs
#     print(f'Found {len(embeddings_index)} word vectors.')

#     return embeddings_index

# %%
# def sent2vec(sentences, embeddings_index=None, external_glove=True, extra_preprocessing_enabled=False):

#     if external_glove is False and embeddings_index is None:
#         embeddings_index= get_glove()

#     if extra_preprocessing_enabled is False:
#         words = sentences

#     elif extra_preprocessing_enabled is True:
#         stop_words = set(sw.words('english'))
#         words = str(sentences).lower()
#         words = word_tokenize(words)
#         words = [w for w in words if (w not in stop_words) and (w.isalpha())]

#     M = []

#     try:
#         for w in words:
#             try:
#                 M.append(embeddings_index[w])
#             except Exception:
#                 continue

#         M = np.array(M)
#         v = M.sum(axis='index')
#         return np.zeros(300) if type(v) != np.ndarray else v / np.sqrt((v ** 2).sum())

#     except Exception:
#         return np.zeros(300)

# %%
# df_manual = pd.read_pickle(f'{df_save_dir}df_manual_ngrams_BoW.pkl')

# %%
# get_df_info(df_manual, ivs_all=dvs)

# %%
# embedding_models_dict = {
#     'w2v': [build_train_word2vec, word2vec_embeddings, Word2Vec],
#     'ft': [build_train_fasttext, fasttext_embeddings, FastText],
# }

# %%
# %%time
# # Make embeddings
# ngrams_list=[1, 2, 3, 123]
# embedding_libraries_list = ['spacy', 'nltk', 'gensim']

# for embedding_library, ngram_number in tqdm_product(embedding_libraries_list, ngrams_list):
#     print(f'Building {embedding_library}_{ngram_number}grams model and vocabulary.')

#     for embed_model_name, embed_func_list in tqdm.tqdm(embedding_models_dict.items()):

#         build_train_func, embed_func, model_loader = embed_func_list
#         print(f'Building {embed_model_name} from {embed_func.__name__} function.')

#         vocab, model = build_train_func(
#             df=df_manual,
#             ngram_number=ngram_number,
#             embedding_library=embedding_library,
#         )

#         print(f'Getting {embed_model_name} embeddings.')

#         df_manual[
#             f'Job Description {embedding_library}_{ngram_number}grams_mean_{embed_model_name}_embeddings'
#         ] = df_manual[
#             f'Job Description {embedding_library}_{ngram_number}grams_original_list'
#         ].progress_apply(
#             lambda sentences: embed_func(sentences, vocab, model)
#         )
#         model.save(f'{data_dir}embeddings models/{embedding_library}_{ngram_number}grams_{embed_model_name}_model.model')

#     # Sent2Vec
#     print('Getting sent2vec embeddings.')
#     embeddings_index = get_glove()
#     df_manual[f'Job Description {embedding_library}_{ngram_number}grams_sent2vec_embeddings'] = df_manual[f'Job Description {embedding_library}_{ngram_number}grams'].progress_apply(lambda sentences: sent2vec(sentences, embeddings_index=embeddings_index, external_glove=True, extra_preprocessing_enabled=False))
#     print('Done getting sent2vec embeddings.')

# %%
# assert len(df_manual) > 0 and isinstance(df_manual, pd.DataFrame), f'ERORR: LENGTH OF DF = {len(df_manual)}'
# df_manual.to_pickle(f'{df_save_dir}df_manual_for_training.pkl')
# df_manual.to_csv(f'{df_save_dir}df_manual_for_training.csv')

# %%
# print(f'Saving df_manual length {len(df_manual)} to txt file.')
# with open(f'{data_dir}df_manual_len.txt', 'w') as f:
#     f.write(str(len(df_manual)))
