# %% [markdown]
# ---
# title: "Descriptives, Visualization, and Tables"
# author: "M.F. Abdulqadir Noon"
# format:
#   html:
#     code-fold: true
# jupyter: python3.10
# ---

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_FOR_training
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %% [markdown]
# # Descriptives and visualization

# %%
import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

mod = sys.modules[__name__]

code_dir = None
code_dir_name = 'Code'
unwanted_subdir_name = 'Analysis'

for _ in range(5):

    parent_path = str(Path.cwd().parents[_]).split('/')[-1]

    if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

        code_dir = str(Path.cwd().parents[_])

        if code_dir is not None:
            break

sys.path.append(code_dir)
# %load_ext autoreload
# %autoreload 2

# %%
from setup_module.imports import * # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# Out:
# Using MPS
# 0it [00:00, ?it/s]

# %%
# %load_ext rpy2.ipython
# %R require(ggstatsplot)
# %R require(glue)

# %%
import rpy2.robjects as robjects
import rpy2.ipython.html
from rpy2.ipython.ggplot import image_png
from rpy2.robjects.packages import importr
import rpy2.robjects.lib.ggplot2 as ggplot2

# Enable html printing
rpy2.ipython.html.init_printing()

# Set utils and base
utils = importr('utils')
base = importr('base')

# Set CRAN mirror
utils.chooseCRANmirror(ind=1)

# Install packages
utils.install_packages('ggstatsplot')
# utils.install_packages('ggplot2')
# utils.install_packages('ggpubr')
# utils.install_packages('glue')
# utils.install_packages('tidyverse')
# utils.install_packages('janitor')
# utils.install_packages('lme4')
# utils.install_packages('lmeInfo')
# utils.install_packages('broom')
# utils.install_packages('performance')

# Import packages
ggstatsplot = importr('ggstatsplot')
# ggplot2 = importr('ggplot2')
# ggpubr = importr('ggpubr')
# glue = importr('glue')
# tidyverse = importr('tidyverse')
# janitor = importr('janitor')
# lme4 = importr('lme4')
# lmeInfo = importr('lmeInfo')
# broom = importr('broom')
# performance = importr('performance')
# Out:
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/python3.10/site-packages/rpy2/robjects/lib/ggplot2.py:70: UserWarning: This was designed againt ggplot2 versions starting with 3.3. but you have 3.4.2
#   warnings.warn(
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: also installing the dependencies ‘BayesFactor’, ‘statsExpressions’
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/BayesFactor_0.9.12-4.4.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 1132315 bytes (1.1 MB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 1.1 MB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/statsExpressions_1.5.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 3295991 bytes (3.1 MB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 3.1 MB
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/ggstatsplot_0.11.1.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 4218673 bytes (4.0 MB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: downloaded 4.0 MB
#
#
# * installing *source* package ‘BayesFactor’ ...
# ** package ‘BayesFactor’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# arm64-apple-darwin20.0.0-clang++ -std=gnu++14 -I"/opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/include" -DNDEBUG  -I'/opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/Rcpp/include' -I'/opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include' -I/opt/homebrew/include -Xclang -fopenmp   -fPIC  -I/opt/homebrew/include -c RcppCallback.cpp -o RcppCallback.o
# In file included from RcppCallback.cpp:2:
# In file included from ./bfcommon.h:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigen.h:25:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigenForward.h:30:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Dense:1:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Core:374:
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/src/Core/MathFunctions.h:487:16: error: no member named 'Rlog1p' in namespace 'std'; did you mean 'log1p'?
#     using std::log1p;
#           ~~~~~^~~~~
#                log1p
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/include/Rmath.h:73:15: note: expanded from macro 'log1p'
# #define log1p Rlog1p
#               ^
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/bin/../include/c++/v1/cmath:448:9: note: 'log1p' declared here
# using ::log1p _LIBCPP_USING_IF_EXISTS;
#         ^
# In file included from RcppCallback.cpp:2:
# In file included from ./bfcommon.h:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigen.h:25:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigenForward.h:30:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Dense:1:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Core:540:
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:14:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from RcppCallback.cpp:2:
# In file included from ./bfcommon.h:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigen.h:25:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigenForward.h:30:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Dense:2:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/LU:47:
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:14:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from RcppCallback.cpp:2:
# In file included from ./bfcommon.h:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigen.h:25:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigenForward.h:30:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Dense:3:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Cholesky:12:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Jacobi:29:
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:14:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from RcppCallback.cpp:2:
# In file included from ./bfcommon.h:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigen.h:25:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigenForward.h:30:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Dense:3:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Cholesky:43:
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:14:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from RcppCallback.cpp:2:
# In file included from ./bfcommon.h:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigen.h:25:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigenForward.h:30:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Dense:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/QR:15:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Householder:27:
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:14:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from RcppCallback.cpp:2:
# In file included from ./bfcommon.h:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigen.h:25:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigenForward.h:30:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Dense:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/QR:48:
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:14:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from RcppCallback.cpp:2:
# In file included from ./bfcommon.h:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigen.h:25:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigenForward.h:30:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Dense:5:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/SVD:48:
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:14:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from RcppCallback.cpp:2:
# In file included from ./bfcommon.h:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigen.h:25:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigenForward.h:30:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Dense:6:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Geometry:58:
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:14:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from RcppCallback.cpp:2:
# In file included from ./bfcommon.h:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigen.h:25:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigenForward.h:30:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Dense:7:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Eigenvalues:58:
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:14:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from RcppCallback.cpp:2:
# In file included from ./bfcommon.h:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigen.h:25:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigenForward.h:31:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Sparse:26:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/SparseCore:66:
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:14:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from RcppCallback.cpp:2:
# In file included from ./bfcommon.h:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigen.h:25:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigenForward.h:31:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Sparse:27:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/OrderingMethods:71:
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:14:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from RcppCallback.cpp:2:
# In file included from ./bfcommon.h:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigen.h:25:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigenForward.h:31:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Sparse:29:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/SparseCholesky:43:
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:14:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from RcppCallback.cpp:2:
# In file included from ./bfcommon.h:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigen.h:25:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigenForward.h:31:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Sparse:32:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/SparseQR:34:
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:14:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from RcppCallback.cpp:2:
# In file included from ./bfcommon.h:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigen.h:25:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigenForward.h:31:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/Sparse:33:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/IterativeLinearSolvers:46:
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:14:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from RcppCallback.cpp:2:
# In file included from ./bfcommon.h:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigen.h:25:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigenForward.h:32:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/CholmodSupport:45:
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:14:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from RcppCallback.cpp:2:
# In file included from ./bfcommon.h:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigen.h:25:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigenForward.h:35:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/unsupported/Eigen/KroneckerProduct:34:
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:14:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from RcppCallback.cpp:2:
# In file included from ./bfcommon.h:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigen.h:25:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigenForward.h:39:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/unsupported/Eigen/Polynomials:135:
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:14:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# In file included from RcppCallback.cpp:2:
# In file included from ./bfcommon.h:4:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigen.h:25:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/RcppEigenForward.h:40:
# In file included from /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/unsupported/Eigen/SparseExtra:51:
# /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/RcppEigen/include/Eigen/src/Core/util/ReenableStupidWarnings.h:14:30: warning: pragma diagnostic pop could not pop, no matching push [-Wunknown-pragmas]
#     #pragma clang diagnostic pop
#                              ^
# 18 warnings and 1 error generated.
# make: *** [/opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/etc/Makeconf:178: RcppCallback.o] Error 1
# ERROR: compilation failed for package ‘BayesFactor’
# * removing ‘/opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/BayesFactor’
# ERROR: dependency ‘BayesFactor’ is not available for package ‘statsExpressions’
# * removing ‘/opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/statsExpressions’
# ERROR: dependency ‘statsExpressions’ is not available for package ‘ggstatsplot’
# * removing ‘/opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/R/library/ggstatsplot’
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The downloaded source packages are in
# 	‘/private/var/folders/46/q15p556n1dd63z6gkwyh896c0000gn/T/RtmpPSPwb5/downloaded_packages’
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Updating HTML index of packages in '.Library'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Making 'packages.html' ...
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  done
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /var/folders/46/q15p556n1dd63z6gkwyh896c0000gn/T/ipykernel_99728/1759508956.py:30 in <module>    │
# │                                                                                                  │
# │ [Errno 2] No such file or directory:                                                             │
# │ '/var/folders/46/q15p556n1dd63z6gkwyh896c0000gn/T/ipykernel_99728/1759508956.py'                 │
# │                                                                                                  │
# │ /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/python3.10/site-packages/rpy2/robjec │
# │ ts/packages.py:472 in importr                                                                    │
# │                                                                                                  │
# │   469 │   """                                                                                    │
# │   470 │                                                                                          │
# │   471 │   if not isinstalled(name, lib_loc=lib_loc):                                             │
# │ ❱ 472 │   │   raise PackageNotInstalledError(                                                    │
# │   473 │   │   │   'The R package "%s" is not installed.' % name                                  │
# │   474 │   │   )                                                                                  │
# │   475                                                                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# PackageNotInstalledError: The R package "ggstatsplot" is not installed.

# %%
# %%R -i df_manual,dvs,dvs_prob,dvs_all,ivs,ivs_perc,ivs_all -w 5 -h 5 --units in -r 200
#
# # Set CRAN mirror to Netherlands
# chooseCRANmirror(ind=56)
#
# # Load libraries
# library(tidyverse)
# library(janitor)
# library(ggstatsplot)
# library(ggplot2)
# library(glue)
#
# data = df_manual
#
# for (iv in ivs){
#   for (dv in dvs){
#     lev_not_sig <- analysis_func(df = data,
#                                  iv = iv,
#                                  dv = dv)
#     vplot <- ggbetweenstats(
#       data = data,
#       x = data[[iv]],
#       y = data[[dv]],
#       type = "parametric",
#       conf.level = 0.95,
#       plot.type = "boxviolin",
#       mean.plotting = TRUE,
#       outlier.tagging = TRUE,
#       outlier.coef = 1.5,
#       outlier.label = region,
#       outlier.label.color = "red",
#       sphericity.correction = TRUE,
#       p.adjust.method = "bonferroni",
#       pairwise.comparisons = TRUE,
#       pairwise.display = "significant",
#       centrality.plotting = TRUE,
#       centrality.path = TRUE,
#       centrality.type = "parameteric",
#       bf.message = TRUE,
#     )
#
#     vplot <- ggbetweenstats(
#       data = data,
#       x = data[[iv]],
#       y = data[[dv]],
#       xlab = glue("{iv} segregated sectors"),
#       ylab = glue("Presence of {dv}-related frames"),
#       type = "parametric",
#       conf.level = 0.95,
#       # ANOVA or Kruskal-Wallis
#       var.equal = lev_not_sig,
#       # ANOVA or Welch ANOVA
#       plot.type = "boxviolin",
#       mean.plotting = TRUE,
#       outlier.tagging = TRUE,
#       outlier.coef = 1.5,
#       outlier.label = region,
#       outlier.label.color = "red",
#       sphericity.correction = TRUE,
#       p.adjust.method = "bonferroni",
#       pairwise.comparisons = TRUE,
#       pairwise.display = "significant",
#       centrality.plotting = TRUE,
#       centrality.path = TRUE,
#       centrality.type = "parameteric",
#       bf.message = TRUE,
#       title = glue("Violin plot of {dv}-related frames in job ads from {iv} segregated sectors"),
#       caption = glue("{dv}-{iv} Violin plot ")
#     )
#     print(vplot)
#
#     # #### Save violin plot
#     # ggplot2::ggsave(
#     #     filename = glue("{plot_save_path}Violinplot {df_name} - {iv} x {dv}.png"),
#     #     plot = vplot,
#     #     device = "png",
#     #     dpi = 1200,
#     #     width = 15,
#     #     height = 10,
#     #     units = "cm"
#     # )
#   }
# }

# %%
try:
    df_sectors_all = pd.read_pickle(f'{table_save_path}Sectors Output from script.pkl')
except FileNotFoundError:
    cbs_notebook = '\\'.join(f'{scraped_data}CBS/CBS.ipynb')
    # %run $cbs_notebook import df_sectors_all # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# %% [markdown]
# # Functions

# %%
def show_and_close_plots():
    plt.show()
    plt.clf()
    plt.cla()
    plt.close()

# %%
def close_plots():
    plt.clf()
    plt.cla()
    plt.close()

# %% [markdown]
# # Descriptives

# %% [markdown]
# ### READ DATA

# %%
with open(f'{data_dir}df_manual_len.txt', 'r') as f:
    df_manual_len = int(f.read())

df_manual = pd.read_pickle(f'{df_save_dir}df_manual_for_training.pkl')
assert len(df_manual) == df_manual_len, f'DATAFRAME MISSING DATA! DF SHOULD BE OF LENGTH {df_manual_len} BUT IS OF LENGTH {len(df_manual)}'
print(f'Dataframe loaded with shape: {df_manual.shape}')

# %%
with open(f'{data_dir}df_jobs_len.txt', 'r') as f:
    df_jobs_len = int(f.read())

df_jobs = pd.read_pickle(f'{df_save_dir}df_jobs_for_classification.pkl')
assert len(df_jobs) == df_jobs_len, f'DATAFRAME MISSING DATA! DF SHOULD BE OF LENGTH {df_jobs_len} BUT IS OF LENGTH {len(df_manual)}'
print(f'Dataframe loaded with shape: {df_jobs.shape}')

# %%
dataframes = {
    'df_manual': df_manual,
    'df_jobs': df_jobs,
}

# %% [markdown]
# ### All info

# %%
# All info
analysis_columns = [
    'Warmth',
    'Competence'
]

for df_name, df in dataframes.items():
    print(f'{"+"*20} {df_name.upper()} {"+"*20}\n')

    df = categorize_df_gender_age(df)

    df.info()

# %% [markdown]
# ## Sentence Level

# %% [markdown]
# ### All Gender and Age info at Sentence Level

# %%
# Gender and Age info by sentence
for df_name, df in dataframes.items():
    print(f'{"+"*20} {df_name.upper()} {"+"*20}\n')

    print('='*30)
    print('Gender and Age info at Sentence Level')
    print('-'*30)
    get_df_info(df, ivs_all=ivs_all)
    print('-'*30)

# %% [markdown]
# ### % Gender and Age info at Sentence Level

# %%
for df_name, df in dataframes.items():
    print(f'{"+"*20} {df_name.upper()} {"+"*20}\n')

    for iv_perc in ivs_perc:
        min_sector = df['Sector'].loc[df[iv_perc] == df[iv_perc].min()].values[0]
        max_sector = df['Sector'].loc[df[iv_perc] == df[iv_perc].max()].values[0]
        mean = df[iv_perc].mean().round(2).astype(float)
        std = df[iv_perc].std().round(2).astype(float)
        print(f'{iv_perc}:\nMin Sector: {df[iv_perc].min():.1f}% in {min_sector}\nMax Sector: {df[iv_perc].max():.1f}% in {max_sector}\nMean: {mean}\nStandard Deviation: {std}\n')
        print('-'*20)

# %% [markdown]
# ### All Warmth and Competence info at Sentence Level

# %%
# Warmth and Competence percentages info by sentence
for df_name, df in dataframes.items():
    print(f'{"+"*20} {df_name.upper()} {"+"*20}\n')

    if df_name == 'df_jobs':
        dvs = dvs_all

    print('='*30)
    print('Warmth and Competence info at Sentence Level')
    print('-'*30)
    get_df_info(df, ivs_all=dvs)
    print('-'*30)

# %% [markdown]
# ## Job Ad Level

# %% [markdown]
# ### All Gender and Age info at Job Ad Level

# %%
# Gender and Age info by job ad
for df_name, df in dataframes.items():
    print(f'{"+"*20} {df_name.upper()} {"+"*20}\n')

    print('='*30)
    print('Gender and Age info at Job Advertisement Level')
    print('-'*30)
    get_df_info(df.groupby(['Job ID']).first(), ivs_all=ivs_all)
    print('-'*30)

# %% [markdown]
# ### % Gender and Age info at Job Ad Level

# %%
for df_name, df in dataframes.items():
    print(f'{"+"*20} {df_name.upper()} {"+"*20}\n')
    df = df.groupby(['Job ID']).first()

    for iv_perc in ivs_perc:
        min_sector = df['Sector'].loc[df[iv_perc] == df[iv_perc].min()].values[0]
        max_sector = df['Sector'].loc[df[iv_perc] == df[iv_perc].max()].values[0]
        mean = df[iv_perc].mean().round(2).astype(float)
        std = df[iv_perc].std().round(2).astype(float)
        print(f'{iv_perc}:\nMin Sector: {df[iv_perc].min():.1f}% in {min_sector}\nMax Sector: {df[iv_perc].max():.1f}% in {max_sector}\nMean: {mean}\nStandard Deviation: {std}\n')
        print('-'*20)

# %% [markdown]
# ### All Warmth and Competence info at Job Ad Level

# %%
# Warmth and Competence info by job ad
for df_name, df in dataframes.items():
    print(f'{"+"*20} {df_name.upper()} {"+"*20}\n')

    if df_name == 'df_jobs':
        dvs = dvs_all

    print('='*30)
    print('Warmth and Competence info at Job Advertisement Level')
    print('-'*30)
    get_df_info(df.groupby(['Job ID']).first(), ivs_all=dvs)
    print('-'*30)

# %% [markdown]
# # Controls

# %% [markdown]
# ## Sentence Level

# %% [markdown]
# ### Controls all info at Sentence Level

# %%
# Control variables info by sentence
for df_name, df in dataframes.items():
    print(f'{"+"*20} {df_name.upper()} {"+"*20}\n')

    print('='*30)
    print('Control varibales info at Sentence Level')
    print('-'*30)
    get_df_info(df, ivs_all = controls)
    print('-'*30)

# %% [markdown]
# ### All info % Sector per Workforce at Sentence Level

# %%
for df_name, df in dataframes.items():
    print(f'{"+"*20} {df_name.upper()} {"+"*20}\n')

    print('='*30)
    print('Sector info at Sentence Level')
    print('-'*30)
    get_df_info(df, ivs_all=['% Sector per Workforce'])
    print('-'*30)

# %% [markdown]
# ### % Sector per Workforce at Sentence Level

# %%
for df_name, df in dataframes.items():
    print(f'{"+"*20} {df_name.upper()} {"+"*20}\n')

    min_sector = df['Sector'].loc[df['% Sector per Workforce'] == df['% Sector per Workforce'].min()].values[0]
    max_sector = df['Sector'].loc[df['% Sector per Workforce'] == df['% Sector per Workforce'].max()].values[0]
    mean = df['% Sector per Workforce'].mean().round(2).astype(float)
    std = df['% Sector per Workforce'].std().round(2).astype(float)
    print(f'"% Sector per Workforce":\nMin Sector: {df["% Sector per Workforce"].min():.1f}% in {min_sector}\nMax Sector: {df["% Sector per Workforce"].max():.1f}% in {max_sector}\nMean: {mean}\nStandard Deviation: {std}\n')
    print('-'*20)

# %% [markdown]
# ## Job Ad Level

# %% [markdown]
# ### All Controls info at Job Ad Level

# %%
# Control variables info by job ad
for df_name, df in dataframes.items():
    print(f'{"+"*20} {df_name.upper()} {"+"*20}\n')

    print('='*30)
    print('Control varibales info at Job Advertisement Level')
    print('-'*30)
    get_df_info(df.groupby(['Job ID']).first(), ivs_all = controls)
    print('-'*30)

# %% [markdown]
# ## Imbalance Ratios

# %%
# Imbalance Ratio
for df_name, df in dataframes.items():
    print(f'{"+"*20} {df_name.upper()} {"+"*20}\n')

    warmth_imbalance_ratio = df['Warmth'].loc[
        df['Warmth'] == 1].count()/df['Warmth'].loc[df['Warmth'] == 0
    ].count()
    competence_imbalance_ratio = df['Competence'].loc[
        df['Competence'] == 1].count()/df['Competence'].loc[df['Competence'] == 0
    ].count()

    all_imbalance_ratio_dict = {
        'Warmth': warmth_imbalance_ratio,
        'Competence': competence_imbalance_ratio
    }

    print('='*20)
    print('Imabalance Ratios')
    print('-'*10)
    print(f'Warmth IR: {warmth_imbalance_ratio:.2f}')
    print(f'Competence IR: {competence_imbalance_ratio:.2f}')
    print('='*20)

# %% [markdown]
# # Plotting

# %%
# Ploting Warmth and Competence
close_plots()
for df_name, df in dataframes.items():
    print(f'{"+"*20} {df_name.upper()} {"+"*20}\n')

    if df_name == 'df_manual':
        title_prefix = 'Manually Annotated Dataset'
    elif df_name == 'df_jobs':
        title_prefix = 'Classifier Labeled'

    dfs_to_transpose = [
        df[dv]
        .value_counts(normalize=True)
        .mul(100)
        .round(2)
        .astype(float)
        .to_frame()
        .T
        for dv in dvs
    ]

    df_warm_comp_transposed = pd.concat(dfs_to_transpose)

    fig, ax = plt.subplots()
    ax.set_title(f'{title_prefix} Warmth and Competence Sentence Percentages')

    df_warm_comp_transposed.plot(
        kind='barh', legend=True, stacked=True, ax=ax, color=['C5', 'C0'],
    )
    ax.legend(['Absent', 'Present'])

    for container in ax.containers:
        labels = [f'{width:.1f}%' for v in container if float(width:= v.get_width())]
        ax.bar_label(container, labels=labels, label_type='center', color='white', weight='bold')    
        ax.set_xlabel('Job Ad Sentences Percentages (%)')

    for i, tick_label in enumerate(ax.get_ymajorticklabels()):
        ax.annotate(
            f'IR for {tick_label.get_text()} = {all_imbalance_ratio_dict[tick_label.get_text()]:.2f}',
            xy=(48, 0.3+i), ha='center', va='center'
        )

    for image_save_format in ['eps', 'png', 'svg']:
        fig.savefig(
            f'{plot_save_path}{df_name} - {title_prefix} Warmth and Competence Sentences.{image_save_format}',
            format=image_save_format, dpi=3000, bbox_inches='tight'
        )

# %%
# Ploting Categorical Gender and Age
close_plots()
for df_name, df in dataframes.items():
    print(f'{"+"*20} {df_name.upper()} {"+"*20}\n')

    if df_name == 'df_manual':
        title_prefix = 'Manually Annotated Dataset'
    elif df_name == 'df_jobs':
        title_prefix = 'Collected Dataset'

    df_gender_transposed = df['Gender'].value_counts(normalize=True).mul(100).round(2).astype(float).to_frame().T
    df_age_transposed = df['Age'].value_counts(normalize=True).mul(100).round(2).astype(float).to_frame().T

    fig, axs = plt.subplots(1, 2)
    fig.suptitle(f'{title_prefix} Categorical Gender and Age Sentence Percentages')

    df_gender_transposed.plot(
        kind='bar', legend=True, stacked=True, ax=axs[0], color=['C2', 'C0', 'C5']
    )
    df_age_transposed.plot(
        kind='bar', legend=True, stacked=True, ax=axs[1], color=['C0', 'C2', 'C5']
    )

    for ax in axs:
        for container in ax.containers:
            labels = [f'{height:.1f}%' for v in container if float(height:= v.get_height())]
            ax.bar_label(container, labels=labels, label_type='center', color='white', weight='bold')
            ax.set_ylabel('Job Ad Sentences Percentages (%)')
            handles, labels = ax.get_legend_handles_labels()
            order = [2, 1, 0] if 'Older' in labels else [2, 0, 1]
            ax.legend([handles[idx] for idx in order],[labels[idx] for idx in order], loc='upper right', fontsize=8, )

    for image_save_format in ['eps', 'png', 'svg']:
        fig.savefig(
            f'{plot_save_path}{df_name} - Categorical Gender and Age Sentences.{image_save_format}',
            format=image_save_format, dpi=3000, bbox_inches='tight'
        )
    show_and_close_plots()

# %%
# Ploting Percentages of Gender and Age
close_plots()
for df_name, df in dataframes.items():
    print(f'{"+"*20} {df_name.upper()} {"+"*20}\n')

    if df_name == 'df_manual':
        title_prefix = 'Manually Annotated Dataset'
    elif df_name == 'df_jobs':
        title_prefix = 'Collected Dataset'

    fig, ax = plt.subplots()
    fig.suptitle(f'{title_prefix} Continuous Gender and Age Sentence Percentages')

    sns.histplot(data=df[ivs_perc], palette='colorblind', kde=True, stat='density', multiple='dodge', ax=ax)
    plt.legend(title='Social Category of Sector', loc='upper left', labels=['Female', 'Male', 'Older', 'Younger'], fontsize=8, title_fontsize=8, bbox_to_anchor=(0, 1))
    ax.set_xlabel('Percentage per Workforce (%)')

    fig.tight_layout()

    for image_save_format in ['eps', 'png', 'svg']:
        fig.savefig(
            f'{plot_save_path}{df_name} - Continuous Gender and Age Sentences.{image_save_format}',
            format=image_save_format, dpi=3000, bbox_inches='tight'
        )
    show_and_close_plots()

# %%
# Make stacked barplots with percentages
close_plots()
for df_name, df in dataframes.items():
    print(f'{"+"*20} {df_name.upper()} {"+"*20}\n')

    if df_name == 'df_manual':
        title_prefix = 'Manually Annotated Dataset'
    elif df_name == 'df_jobs':
        title_prefix = 'Classifier Labeled'

    for iv in tqdm.tqdm(['Gender', 'Age', 'Sector']):
        fig, ax = plt.subplots()
        fig.suptitle(f'{title_prefix} Warmth and Competence Sentence Percentages per {iv}')

        try:
            vars_list = [iv, *dvs]
            df_pivot = df[
                vars_list
            ].pivot_table(
                index=iv, values=dvs, fill_value=0, aggfunc=lambda x: (100*x.sum())/len(df)
            )
        except KeyError:
            from setup_module.imports import dvs
            vars_list = [iv, *dvs]
            df_pivot = df[
                vars_list
            ].pivot_table(
                index=iv, values=dvs, fill_value=0, aggfunc=lambda x: (100*x.sum())/len(df)
            )

        df_pivot.sort_values(by=iv, ascending=False).plot(kind='barh', legend=True, stacked=True, ax=ax, color=['C0', 'C5'])

        ax.legend(dvs)

        for container in ax.containers:
            labels = [f'{width:.1f}%' for v in container if float(width:= v.get_width())]
            if iv != 'Sector':
                ax.bar_label(container, labels=labels, label_type='center', color='white', fontsize=8)
            ax.set_xlabel('Job Ad Sentences Percentages (%)')
            ax.set_ylabel(iv)
            ax.legend(loc='upper right', fontsize=8)

        for image_save_format in ['eps', 'png', 'svg']:
            fig.savefig(
                f'{plot_save_path}{df_name} - {title_prefix} Barplot - {iv} x {dvs[0]} and {dvs[1]} Sentences.{image_save_format}',
                format=image_save_format, dpi=3000, bbox_inches='tight'
            )
        show_and_close_plots()

# %%
def make_2ax_lineplot(df, ivs_cat_and_perc, dvs_all):

    line_plot = sns.lineplot(
        data=df.groupby(ivs_cat_and_perc[0])[dvs_all[0]].agg('mean').astype(float), marker='o', legend='full', ax=axs[0], color='C5'
    )
    line_plot = sns.lineplot(
        data=df.groupby(ivs_cat_and_perc[0])[dvs_all[1]].agg('mean').astype(float), marker='o', legend='full', ax=axs[0], color='C0'
    )
    line_plot = sns.lineplot(
        data=df.groupby(ivs_cat_and_perc[1])[dvs_all[0]].agg('mean').astype(float), marker='o', legend='full', ax=axs[1], color='C5'
    )
    line_plot = sns.lineplot(
        data=df.groupby(ivs_cat_and_perc[1])[dvs_all[1]].agg('mean').astype(float), marker='o', legend='full', ax=axs[1], color='C0'
    )

    return line_plot

# %%
# Make line plots 2 ax
close_plots()
for df_name, df in dataframes.items():
    print(f'{"+"*20} {df_name.upper()} {"+"*20}\n')

    if df_name == 'df_manual':
        title_prefix = 'Manually Annotated Dataset'
    elif df_name == 'df_jobs':
        title_prefix = 'Classifier Labeled'

    fig, axs = plt.subplots(1, 2)
    fig.suptitle(f'{title_prefix} Warmth and Competence x Gender and Age')

    line_plot = make_2ax_lineplot(df, ivs_cat_and_perc, dvs_all)

    fig = line_plot.get_figure()
    fig.legend(labels=dvs, fontsize=10, bbox_to_anchor=(1, 0.9))

    for image_save_format in ['eps', 'png', 'svg']:
        fig.savefig(
            f'{plot_save_path}{df_name} - {title_prefix} Line Plot (2 ax).{image_save_format}',
            format=image_save_format, dpi=3000, bbox_inches='tight'
        )
    show_and_close_plots()

# %%
def make_4ax_lineplot(df, ivs_cat_and_perc, dvs_all):

    line_plot = sns.lineplot(
        data=df.groupby(ivs_cat_and_perc[0])[dvs_all[0]].agg('mean').astype(float), marker='o', legend='full', ax=axs[0, 0], color='C5'
    )
    line_plot = sns.lineplot(
        data=df.groupby(ivs_cat_and_perc[0])[dvs_all[1]].agg('mean').astype(float), marker='o', legend='full', ax=axs[0, 1], color='C0'
    )
    line_plot = sns.lineplot(
        data=df.groupby(ivs_cat_and_perc[1])[dvs_all[0]].agg('mean').astype(float), marker='o', legend='full', ax=axs[1, 0], color='C5'
    )
    line_plot = sns.lineplot(
        data=df.groupby(ivs_cat_and_perc[1])[dvs_all[1]].agg('mean').astype(float), marker='o', legend='full', ax=axs[1, 1], color='C0'
    )

    return line_plot

# %%
# Make line plots 4 ax
close_plots()
for df_name, df in dataframes.items():
    print(f'{"+"*20} {df_name.upper()} {"+"*20}\n')
 
    if df_name == 'df_manual':
        title_prefix = 'Manually Annotated Dataset'
    elif df_name == 'df_jobs':
        title_prefix = 'Classifier Labeled'

    fig, axs = plt.subplots(2, 2)
    fig.suptitle(f'{title_prefix} Warmth and Competence x Gender and Age')

    line_plot = make_4ax_lineplot(df, ivs_cat_and_perc, dvs_all)

    fig = line_plot.get_figure()
    fig.legend(labels=dvs, fontsize=10, bbox_to_anchor=(1, 0.95))

    for image_save_format in ['eps', 'png', 'svg']:
        fig.savefig(
            f'{plot_save_path}{df_name} - {title_prefix} Line Plot (4 ax).{image_save_format}',
            format=image_save_format, dpi=3000, bbox_inches='tight'
        )
    show_and_close_plots()

# %%
def make_violin_plot(df, df_name, ivs_cat_and_perc, dvs_all, pallette=None):
    if pallette is None:
        pallette = ['C5', 'C2', 'C0']

    if df_name == 'df_manual':
        violin_plot = sns.violinplot(
            data=df, x=ivs_cat_and_perc[0], y=dvs_all[0], palette=pallette, inner='quartile', ax=axs[0, 0]
        )
        violin_plot = sns.violinplot(
            data=df, x=ivs_cat_and_perc[0], y=dvs_all[1], palette=pallette, inner='quartile', ax=axs[0, 1]
        )
        violin_plot = sns.violinplot(
            data=df, x=ivs_cat_and_perc[1], y=dvs_all[0], palette=pallette, inner='quartile', ax=axs[1, 0]
        )
        violin_plot = sns.violinplot(
            data=df, x=ivs_cat_and_perc[1], y=dvs_all[1], palette=pallette, inner='quartile', ax=axs[1, 1]
        )
    if df_name == 'df_jobs':
        violin_plot = sns.violinplot(
            data=df, x=ivs_cat_and_perc[0], y=dvs_all[2], palette=pallette, inner='quartile', ax=axs[0, 0]
        )
        violin_plot = sns.violinplot(
            data=df, x=ivs_cat_and_perc[0], y=dvs_all[3], palette=pallette, inner='quartile', ax=axs[0, 1]
        )
        violin_plot = sns.violinplot(
            data=df, x=ivs_cat_and_perc[1], y=dvs_all[2], palette=pallette, inner='quartile', ax=axs[1, 0]
        )
        violin_plot = sns.violinplot(
            data=df, x=ivs_cat_and_perc[1], y=dvs_all[3], palette=pallette, inner='quartile', ax=axs[1, 1]
        )

    return violin_plot

# %%
# Make violin plots
close_plots()
for df_name, df in dataframes.items():
    print(f'{"+"*20} {df_name.upper()} {"+"*20}\n')

    if df_name == 'df_manual':
        title_prefix = 'Manually Annotated Dataset'
    elif df_name == 'df_jobs':
        title_prefix = 'Classifier Labeled'

    fig, axs = plt.subplots(2, 2)
    fig.suptitle(f'{title_prefix} Distribution of Warmth and Competence Scores')

    violin_plot = make_violin_plot(df, df_name, ivs_cat_and_perc, dvs_all)

    fig = violin_plot.get_figure()

    for image_save_format in ['eps', 'png', 'svg']:
        fig.savefig(
            f'{plot_save_path}{df_name} - {title_prefix} Violin Plot.{image_save_format}',
            format=image_save_format, dpi=3000, bbox_inches='tight'
        )
    show_and_close_plots()

# %%
pallette = ['C2', 'C5']
fig, axs = plt.subplots(2, 2)
violin_plot = sns.violinplot(
    data=df_manual, x=dvs[0], y='Gender_Female_% per Sector', palette=pallette, inner='quartile', ax=axs[0, 0]
)
violin_plot = sns.violinplot(
    data=df_manual, x='Warmth', y='Gender_Male_% per Sector', palette=pallette, inner='quartile', ax=axs[0, 1]
)
violin_plot = sns.violinplot(
    data=df_manual, x='Competence', y='Age_Older_% per Sector', palette=pallette, inner='quartile', ax=axs[1, 0]
)
violin_plot = sns.violinplot(
    data=df_manual, x='Competence', y='Age_Younger_% per Sector', palette=pallette, inner='quartile', ax=axs[1, 1]
)

for ax in axs.reshape(-1):
    ax.set_ylabel(' '.join(ax.get_ylabel().split('_')[-2:]))

# %% [markdown]
# # Tables

# %%
def save_desc_excel(
    df_desc,
    index_var,
    file_save_path,
    sheet_name=None,
    startrow=None,
    startcol=None,
):
    if sheet_name is None:
        sheet_name = 'All'
    if startrow is None:
        startrow = 1
    if startcol is None:
        startcol = 1

    # index = df_desc.index.to_frame().reset_index(drop=True)
    df_desc = df_desc.reset_index(drop=False, col_level=1, col_fill=f'{title_prefix} Job Advertisements') 

    # Define last rows and cols locs
    header_range = len(df_desc.columns.levels)
    endrow = startrow + header_range + df_desc.shape[0]
    endcol = startcol + df_desc.shape[1]

    # Write
    writer = pd.ExcelWriter(f'{file_save_path}.xlsx', engine='xlsxwriter')
    df_desc.to_excel(writer, sheet_name=sheet_name, merge_cells=True, startrow=startrow, startcol=startcol)
    workbook  = writer.book
    worksheet = writer.sheets[sheet_name]
    worksheet.set_row(startrow + header_range, None, None, {'hidden': True}) # hide the empty row that appears after the headers
    worksheet.set_column(startrow, 1, None, None, {'hidden': True}) # hide the index column

    # MAIN BODY
    # Format column headers
    for i, (col_num, col_value) in tqdm_product(range(header_range), (enumerate(df_desc.columns.values))):
        row_to_write = startrow + i
        col_to_write = startcol + 1 + col_num # 1 is for index
        header_formats = {'bold': False, 'font_name': 'Times New Roman', 'font_size': 12, 'font_color': 'black', 'align': 'center', 'top': True, 'bottom': True, 'left': False, 'right': False}

        if col_value[i] in ['n', 'M', 'SD']:
            header_formats |= {'italic': True}

        if col_value[i] == '95% Conf.':
            worksheet.set_column(col_to_write, col_to_write, 8.5)

        if col_value[i] == index_var:
            worksheet.set_column(col_to_write, col_to_write, 10)
            header_formats |= {'text_wrap': True}
            worksheet.merge_range(row_to_write, col_to_write, header_range, col_to_write, index_var, workbook.add_format(header_formats))
        else:
            worksheet.write(row_to_write, col_to_write, col_value[i], workbook.add_format(header_formats))

    # Format body columns
    body_max_row_idx, body_max_col_idx = df_desc.shape

    for c, r in tqdm_product(range(body_max_col_idx), range(body_max_row_idx)):
        row_to_write = startrow + header_range + 1 + r # 1 is for the hidden empty column under the header
        col_to_write = startcol + 1 + c # 1 is for index
        body_formats = {'num_format': '0.00', 'font_name': 'Times New Roman', 'font_size': 12, 'text_wrap': True, 'left': False, 'right': False}

        if r == body_max_row_idx-1:
            body_formats |= {'bottom': True}

        worksheet.write(row_to_write, col_to_write, df_desc.iloc[r, c], workbook.add_format(body_formats))

    writer.close()

# %%
def make_df_desc(df, df_name, vars_list, var_name, index_var, sentence_level=False, continous_var_names_list=None):

    if continous_var_names_list is None:
        continous_var_names_list = ['Probabilities', 'Percentages']

    if df_name == 'df_manual':
        title_prefix = 'Manually Annotated Dataset'
    elif df_name == 'df_jobs':
        title_prefix = 'Classifier Labeled'

    if sentence_level == False:
        level = 'Job Advertisement'
        df = df.groupby('Job ID').first()
    if sentence_level == True:
        level = 'Sentence'

    # Warmth and Competence Categorical df
    if len(set(var_name.split()).intersection(continous_var_names_list)) == 0:
        df_cat = rp.summary_cat(df[vars_list], ascending= True).round(2)
        df_cat['Variable'] = df_cat['Variable'].replace('', np.nan).fillna(method='ffill')
        df_cat = df_cat.loc[df_cat['Outcome'] == 1].drop(columns=['Outcome'])
        totals = pd.DataFrame(df_cat.sum(numeric_only=True)).transpose()
        totals.insert(0, 'Variable', 'Total')
        df_cat = df_cat.fillna('')
        df_cat = pd.concat([df_cat, totals], axis='index', ignore_index=True)

    # Warmth and Competence Continuous df
    df_cont = rp.summary_cont(df[vars_list], conf = 0.95, decimals = 2)

    # Merged df
    if len(set(var_name.split()).intersection(continous_var_names_list)) == 0:
        df_desc = df_cat.merge(df_cont, on='Variable', how='outer')
        df_desc = df_desc.fillna('')
    else:
        df_desc = df_cont

    # Rename variable columns
    df_desc['Variable'] = df_desc['Variable'].apply(
        lambda var_name: f'{var_name.split("_")[1]}-dominated'.replace('_', ' ').strip()
        if '_' in var_name and 'Mixed' not in var_name and '%' not in var_name
        else f'{var_name.split("_")[1]} Gender'.replace('_', ' ')
        if '_' in var_name and 'Mixed' in var_name and '%' not in var_name
        else " ".join(var_name.split("_")[1:])
        if '_' in var_name and 'Mixed' not in var_name and '%' in var_name
        else var_name
    )

    # Clean up df and set index
    if len(set(var_name.split()).intersection(continous_var_names_list)) == 0:
        drop_columns = ['N', 'SE', '95% Conf.', 'Interval']
        rename_dict = {'Variable': index_var, 'Count': 'n', 'Percent': '%', 'Mean': 'M'}
    else:
        drop_columns = ['N', 'SE']
        rename_dict = {'Variable': index_var, 'Mean': 'M', 'SD': 'SD', '95% Conf. Int.': '95% CI'}

    df_desc = df_desc.drop(columns=drop_columns)
    df_desc = df_desc.rename(columns=rename_dict)
    df_desc = df_desc.set_index(keys=[index_var], drop=True)

    # Make into MultiIndex
    df_desc.columns = pd.MultiIndex.from_product([[level], df_desc.columns])

    return df_desc

# %%
vars_dict = {
    'Categorical Gender': ivs_gender_dummy,
    'Categorical Age': ivs_age_dummy,
    'Gender Percentages per Sector (%)': ivs_gender_perc,
    'Age Percentages per Sector (%)': ivs_age_perc,
    'Categorical Warmth and Competence': dvs,
    # HACK
    # 'Warmth and Competence Probabilities': dvs_prob,
}

# %%
for (df_name, df), (var_name, vars_list) in tqdm_product(dataframes.items(), vars_dict.items()):

    if df_name == 'df_manual':
        title_prefix = 'Manually Annotated Dataset'
    elif df_name == 'df_jobs' and 'Warmth and Competence' not in var_name:
        title_prefix = 'Collected Dataset'
    elif df_name == 'df_jobs':
        title_prefix = 'Classifier Labeled'

    # Set index varaible name
    if 'Warmth and Competence' in var_name:
        index_var = 'Stereotype-related frames'
    elif 'Percentages' in var_name:
        index_var = 'Percentages per Sector'
    else:
        index_var = 'Sectors'

    # Categorical DF on job ad level
    df_desc_cat_jobad = make_df_desc(df, df_name, vars_list=vars_list, var_name=var_name, index_var=index_var, sentence_level=False)

    # Categorical DF on sentence level
    df_desc_cat_sent = make_df_desc(df, df_name, vars_list=vars_list, var_name=var_name, index_var=index_var, sentence_level=True)

    # Merge Categorical dfs
    df_desc_cat = df_desc_cat_jobad.merge(df_desc_cat_sent, on=index_var)

    # Continuous DF on job ad level
    df_desc_cont_jobad = make_df_desc(df, df_name, vars_list=vars_list, var_name=var_name, index_var=index_var, sentence_level=False)

    # Continuous DF on sentence level
    df_desc_cont_sent = make_df_desc(df, df_name, vars_list=vars_list, var_name=var_name, index_var=index_var, sentence_level=True)

    # Merge Continuous dfs
    df_desc_cont = df_desc_cont_jobad.merge(df_desc_cont_sent, on=index_var)

    # Collect dfs in list
    df_desc_list = [df_desc_cat, df_desc_cont]

    for df_desc in df_desc_list:
        levels_with_title = [[f'{title_prefix} Job Advertisements']]
        # Add title prefix
        levels_with_title.extend(
            list(df_desc.columns.get_level_values(i).unique())
                for i in range(len(df_desc.columns.levels))
        )
        # levels_with_title.insert(0, )
        if 'Warmth and Competence' not in var_name:
            levels_with_title.insert(1, [var_name])

        # Make into MultiIndex
        df_desc.columns = pd.MultiIndex.from_product(levels_with_title)

        # Save Tables
        # File save path
        file_save_path = f'{table_save_path}{df_name} {title_prefix} {var_name} - Job Advertisement Descriptives'
        # CSV
        df_desc.to_csv(f'{file_save_path}.csv', index=True)
        # PKL
        df_desc.to_pickle(f'{file_save_path}.pkl')
        # TEX
        with pd.option_context('max_colwidth', 10000000000):
            df_desc.style.to_latex(
                f'{file_save_path}.tex',
                convert_css=True,
                environment='longtable',
                # escape=True,
                # multicolumn=True,
                multicol_align='c',
                position='H',
                caption=f'{var_name} Descriptives', label='Descriptives'
            )
        # MD
        df_desc.to_markdown(f'{file_save_path}.md', index=True)
        # EXCEL
        save_desc_excel(df_desc, index_var, file_save_path)
